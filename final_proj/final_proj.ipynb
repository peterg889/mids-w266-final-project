# %%
from __future__ import print_function
from __future__ import division
from importlib import reload

from nltk.tokenize.treebank import TreebankWordTokenizer
import collections
import nltk
import numpy as np
import glob
import math

import pandas as pd
import tensorflow as tf
import os, sys, re, json, time, datetime, shutil

# Helper libraries
from w266_common import utils, vocabulary
from w266_common import patched_numpy_io
# Out:
# /home/peterg/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# ### Constants

# %%
KID_APPROPRIATE = 1
KID_INAPPROPRIATE = 0

# %% [markdown]
# ### Grab Data

# %%
book_files = glob.glob('/home/peterg/2018-spring-main/assignment/final_proj/books/*.txt')
fourchan_files = glob.glob('/home/peterg/2018-spring-main/assignment/final_proj/4chan/*.txt')

# %%
pos_examples, neg_examples = [], []

# positive (appropriate for kids) examples come from 
# the children's bookshelf of project Gutenberg
for book in book_files[:60]:
    with open(book, "r") as pos_file:
        for line in pos_file:
            pos_examples.append(line)

# negative (inapprorpiate for kids) training examples come
# from the "shit 4chan says" board on 4chan.org
single_4chan_file = ["/home/peterg/2018-spring-main/assignment/final_proj/4chan/4chan_s4s.txt",]
for board in single_4chan_file:
    with open(board, 'r') as neg_file:
        for line in neg_file:
            neg_examples.append(line)

print(len(pos_examples), len(neg_examples))
# Out:
# 154277 2760399

# %% [markdown]
# ### Tokenization

# %%
tokenizer = TreebankWordTokenizer()

# the number of positive and negative examples to pull for training
num_sents = 250000

pos_tokens = [tokenizer.tokenize(x) for x in pos_examples[:num_sents]]
neg_tokens = [tokenizer.tokenize(x) for x in neg_examples[:num_sents]]

# %%
print(pos_examples[:5])
print(neg_examples[:5])
# Out:
# ['      THE SONG OF HIAWATHA       Henry W. Longfellow CONTENTS Introductory Note Introduction I.\n', 'The Peace-Pipe II.\n', 'The Four Winds III.\n', "Hiawatha's Childhood IV.\n", "Hiawatha and Mudjekeewis V.    Hiawatha's Fasting VI.\n"]
# ["'I only browse on iphone\n", " (check your desktop privilege) How do I create memes on mobile? Does anyone know of an app that is similar to ms paint? Any basic art app that is free and good?'\n", "'( ͡° ͜ʖ ͡°)'\n", "'epin; simply ebin'\n", "'shit not again'\n"]

# %% [markdown]
# ### Canonicalization

# %%
pos_tokens_canonical = [utils.canonicalize_words(x) for x in pos_tokens]
neg_tokens_canonical = [utils.canonicalize_words(x) for x in neg_tokens]

# %% [markdown]
# ### Generate Vocabulary

# %%
all_tokens_canonical = pos_tokens_canonical + neg_tokens_canonical

all_tokens_flattened = [] 
for sublist in all_tokens_canonical:
    for item in sublist:
        all_tokens_flattened.append(item)

vocab = vocabulary.Vocabulary(all_tokens_flattened, size=70000)  # size=None means unlimited
print("Vocabulary size: {:,}".format(vocab.size))


# print("Vocabulary dict: ", vocab.word_to_id)
# x_ids = vocab.words_to_ids(all_tokens_flattened)
# print("x_ids =", x_ids)
# x_tokens_recovered = vocab.ids_to_words(x_ids)
# x_tokens_recovered
# Out:
# Vocabulary size: 70,000

# %% [markdown]
# ### Generate training set

# %%
def pad_array(array, pad_len):
    length = len(array)
    if length <= pad_len:
        delta = pad_len - length
        for i in range(delta):
            array.append(0)
            
        return array, length
    if length > pad_len:
        return array[:pad_len], length

# %%
pos_ids = [vocab.words_to_ids(x) for x in pos_tokens_canonical]
neg_ids = [vocab.words_to_ids(x) for x in neg_tokens_canonical]

train_x, train_ns, train_y = [], [], []

pad_len = 40

train_frac = 0.5
dev_frac = 0.2

# train_frac + dev_frac must be <= 1
assert(train_frac + dev_frac <= 1.0)

num_sents = math.floor(len(pos_ids) * train_frac)
num_dev_sents = math.floor(len(pos_ids) * dev_frac)

# add one positive and one negative example
for i in range(num_sents):
    if i % 10000 == 0:
        print("Done with", i)
    padded, orig_len = pad_array(pos_ids[i],pad_len)
    train_x.append(padded)
    train_ns.append(orig_len)
    train_y.append(KID_APPROPRIATE)
    
    padded, orig_len = pad_array(neg_ids[i],pad_len)
    train_x.append(padded)
    train_ns.append(orig_len)
    train_y.append(KID_INAPPROPRIATE)
    
    
dev_x, dev_ns, dev_y = [], [], []

# take dev examples from the back half of the array
for i in range(num_dev_sents):
    if i % 10000 == 0:
        print("Done with", i)
    padded, orig_len = pad_array(pos_ids[-i],pad_len)
    dev_x.append(padded)
    dev_ns.append(orig_len)
    dev_y.append(KID_APPROPRIATE)
    
    padded, orig_len = pad_array(neg_ids[-i],pad_len)
    dev_x.append(padded)
    dev_ns.append(orig_len)
    dev_y.append(KID_INAPPROPRIATE)

# print(train_x[:3])
# print(vocab.ids_to_words(train_x[1]))
# print(train_ns[:3])
# print(train_y[:3])

batches = len(train_x)
max_len = pad_len
# Out:
# Done with 0
# Done with 10000
# Done with 20000
# Done with 30000
# Done with 40000
# Done with 50000
# Done with 60000
# Done with 70000
# Done with 0
# Done with 10000
# Done with 20000
# Done with 30000

# %%
train_x_np = np.array(train_x)
train_ns_np = np.array(train_ns)
train_y_np = np.array(train_y)

dev_x_np = np.array(dev_x)
dev_ns_np = np.array(dev_ns)
dev_y_np = np.array(dev_y)

# %%
import models; reload(models)
x, ns, y = train_x_np, train_ns_np, train_y_np
batch_size = 32


# Specify model hyperparameters as used by model_fn
model_params = dict(V=vocab.size, embed_dim=90, hidden_dims=[50,25], num_classes=2,
                    encoder_type='bow',
                    lr=0.1, optimizer='adagrad', beta=0.01)
model_fn = models.classifier_model_fn

total_batches = 0
total_examples = 0
total_loss = 0
loss_ema = np.log(2)  # track exponential-moving-average of loss
ema_decay = np.exp(-1/10)  # decay parameter for moving average = np.exp(-1/history_length)
with tf.Graph().as_default(), tf.Session() as sess:
    ##
    # Construct the graph here. No session.run calls - just wiring up Tensors.
    ##
    # Add placeholders so we can feed in data.
    x_ph_  = tf.placeholder(tf.int32, shape=[None, x.shape[1]])  # [batch_size, max_len]
    ns_ph_ = tf.placeholder(tf.int32, shape=[None])              # [batch_size]
    y_ph_  = tf.placeholder(tf.int32, shape=[None])              # [batch_size]
    
    # Construct the graph using model_fn
    features = {"ids": x_ph_, "ns": ns_ph_}  # note that values are Tensors
    estimator_spec = model_fn(features, labels=y_ph_, mode=tf.estimator.ModeKeys.TRAIN,
                              params=model_params)
    loss_     = estimator_spec.loss
    train_op_ = estimator_spec.train_op
    
    ##
    # Done constructing the graph, now we can make session.run calls.
    ##
    sess.run(tf.global_variables_initializer())
    
    # Run a single epoch
    t0 = time.time()
    for (bx, bns, by) in utils.multi_batch_generator(batch_size, x, ns, y):
        # feed NumPy arrays into the placeholder Tensors
        feed_dict = {x_ph_: bx, ns_ph_: bns, y_ph_: by}
        batch_loss, _ = sess.run([loss_, train_op_], feed_dict=feed_dict)
        
        # Compute some statistics
        total_batches += 1
        total_examples += len(bx)
        total_loss += batch_loss * len(bx)  # re-scale, since batch loss is mean
        # Compute moving average to smooth out noisy per-batch loss
        loss_ema = ema_decay * loss_ema + (1 - ema_decay) * batch_loss
        
        if (total_batches % 25 == 0):
            print("{:5,} examples, moving-average loss {:.2f}".format(total_examples, 
                                                                      loss_ema))    
    print("Completed one epoch in {:s}".format(utils.pretty_timedelta(since=t0)))
# Out:
#   800 examples, moving-average loss 1.18
# 1,600 examples, moving-average loss 0.83
# 2,400 examples, moving-average loss 0.80
# 3,200 examples, moving-average loss 0.70
# 4,000 examples, moving-average loss 0.74
# 4,800 examples, moving-average loss 0.58
# 5,600 examples, moving-average loss 0.52
# 6,400 examples, moving-average loss 0.51
# 7,200 examples, moving-average loss 0.42
# 8,000 examples, moving-average loss 0.37
# 8,800 examples, moving-average loss 0.35
# 9,600 examples, moving-average loss 0.33
# 10,400 examples, moving-average loss 0.33
# 11,200 examples, moving-average loss 0.35
# 12,000 examples, moving-average loss 0.28
# 12,800 examples, moving-average loss 0.34
# 13,600 examples, moving-average loss 0.33
# 14,400 examples, moving-average loss 0.25
# 15,200 examples, moving-average loss 0.27
# 16,000 examples, moving-average loss 0.21
# 16,800 examples, moving-average loss 0.22
# 17,600 examples, moving-average loss 0.21
# 18,400 examples, moving-average loss 0.19
# 19,200 examples, moving-average loss 0.19
# 20,000 examples, moving-average loss 0.19
# 20,800 examples, moving-average loss 0.18
# 21,600 examples, moving-average loss 0.20
# 22,400 examples, moving-average loss 0.22
# 23,200 examples, moving-average loss 0.18
# 24,000 examples, moving-average loss 0.17
# 24,800 examples, moving-average loss 0.29
# 25,600 examples, moving-average loss 0.24
# 26,400 examples, moving-average loss 0.19
# 27,200 examples, moving-average loss 0.22
# 28,000 examples, moving-average loss 0.17
# 28,800 examples, moving-average loss 0.16
# 29,600 examples, moving-average loss 0.15
# 30,400 examples, moving-average loss 0.16
# 31,200 examples, moving-average loss 0.17
# 32,000 examples, moving-average loss 0.20
# 32,800 examples, moving-average loss 0.18
# 33,600 examples, moving-average loss 0.18
# 34,400 examples, moving-average loss 0.19
# 35,200 examples, moving-average loss 0.20
# 36,000 examples, moving-average loss 0.21
# 36,800 examples, moving-average loss 0.14
# 37,600 examples, moving-average loss 0.15
# 38,400 examples, moving-average loss 0.15
# 39,200 examples, moving-average loss 0.16
# 40,000 examples, moving-average loss 0.13
# 40,800 examples, moving-average loss 0.14
# 41,600 examples, moving-average loss 0.22
# 42,400 examples, moving-average loss 0.17
# 43,200 examples, moving-average loss 0.15
# 44,000 examples, moving-average loss 0.16
# 44,800 examples, moving-average loss 0.16
# 45,600 examples, moving-average loss 0.16
# 46,400 examples, moving-average loss 0.19
# 47,200 examples, moving-average loss 0.19
# 48,000 examples, moving-average loss 0.22
# 48,800 examples, moving-average loss 0.18
# 49,600 examples, moving-average loss 0.15
# 50,400 examples, moving-average loss 0.23
# 51,200 examples, moving-average loss 0.16
# 52,000 examples, moving-average loss 0.15
# 52,800 examples, moving-average loss 0.13
# 53,600 examples, moving-average loss 0.14
# 54,400 examples, moving-average loss 0.13
# 55,200 examples, moving-average loss 0.15
# 56,000 examples, moving-average loss 0.15
# 56,800 examples, moving-average loss 0.13
# 57,600 examples, moving-average loss 0.13
# 58,400 examples, moving-average loss 0.14
# 59,200 examples, moving-average loss 0.17
# 60,000 examples, moving-average loss 0.20
# 60,800 examples, moving-average loss 0.18
# 61,600 examples, moving-average loss 0.18
# 62,400 examples, moving-average loss 0.16
# 63,200 examples, moving-average loss 0.20
# 64,000 examples, moving-average loss 0.19
# 64,800 examples, moving-average loss 0.17
# 65,600 examples, moving-average loss 0.21
# 66,400 examples, moving-average loss 0.23
# 67,200 examples, moving-average loss 0.26
# 68,000 examples, moving-average loss 0.27
# 68,800 examples, moving-average loss 0.23
# 69,600 examples, moving-average loss 0.22
# 70,400 examples, moving-average loss 0.20
# 71,200 examples, moving-average loss 0.19
# 72,000 examples, moving-average loss 0.15
# 72,800 examples, moving-average loss 0.19
# 73,600 examples, moving-average loss 0.17
# 74,400 examples, moving-average loss 0.17
# 75,200 examples, moving-average loss 0.15
# 76,000 examples, moving-average loss 0.13
# 76,800 examples, moving-average loss 0.19
# 77,600 examples, moving-average loss 0.17
# 78,400 examples, moving-average loss 0.16
# 79,200 examples, moving-average loss 0.15
# 80,000 examples, moving-average loss 0.13
# 80,800 examples, moving-average loss 0.13
# 81,600 examples, moving-average loss 0.14
# 82,400 examples, moving-average loss 0.14
# 83,200 examples, moving-average loss 0.14
# 84,000 examples, moving-average loss 0.15
# 84,800 examples, moving-average loss 0.16
# 85,600 examples, moving-average loss 0.12
# 86,400 examples, moving-average loss 0.15
# 87,200 examples, moving-average loss 0.13
# 88,000 examples, moving-average loss 0.16
# 88,800 examples, moving-average loss 0.14
# 89,600 examples, moving-average loss 0.19
# 90,400 examples, moving-average loss 0.15
# 91,200 examples, moving-average loss 0.17
# 92,000 examples, moving-average loss 0.16
# 92,800 examples, moving-average loss 0.14
# 93,600 examples, moving-average loss 0.13
# 94,400 examples, moving-average loss 0.11
# 95,200 examples, moving-average loss 0.12
# 96,000 examples, moving-average loss 0.13
# 96,800 examples, moving-average loss 0.15
# 97,600 examples, moving-average loss 0.13
# 98,400 examples, moving-average loss 0.14
# 99,200 examples, moving-average loss 0.14
# 100,000 examples, moving-average loss 0.13
# 100,800 examples, moving-average loss 0.16
# 101,600 examples, moving-average loss 0.14
# 102,400 examples, moving-average loss 0.14
# 103,200 examples, moving-average loss 0.13
# 104,000 examples, moving-average loss 0.12
# 104,800 examples, moving-average loss 0.12
# 105,600 examples, moving-average loss 0.19
# 106,400 examples, moving-average loss 0.17
# 107,200 examples, moving-average loss 0.17
# 108,000 examples, moving-average loss 0.15
# 108,800 examples, moving-average loss 0.15
# 109,600 examples, moving-average loss 0.13
# 110,400 examples, moving-average loss 0.16
# 111,200 examples, moving-average loss 0.16
# 112,000 examples, moving-average loss 0.13
# 112,800 examples, moving-average loss 0.13
# 113,600 examples, moving-average loss 0.15
# 114,400 examples, moving-average loss 0.13
# 115,200 examples, moving-average loss 0.12
# 116,000 examples, moving-average loss 0.23
# 116,800 examples, moving-average loss 0.16
# 117,600 examples, moving-average loss 0.17
# 118,400 examples, moving-average loss 0.15
# 119,200 examples, moving-average loss 0.15
# 120,000 examples, moving-average loss 0.12
# 120,800 examples, moving-average loss 0.12
# 121,600 examples, moving-average loss 0.22
# 122,400 examples, moving-average loss 0.16
# 123,200 examples, moving-average loss 0.16
# 124,000 examples, moving-average loss 0.13
# 124,800 examples, moving-average loss 0.12
# 125,600 examples, moving-average loss 0.14
# 126,400 examples, moving-average loss 0.14
# 127,200 examples, moving-average loss 0.15
# 128,000 examples, moving-average loss 0.14
# 128,800 examples, moving-average loss 0.12
# 129,600 examples, moving-average loss 0.16
# 130,400 examples, moving-average loss 0.15
# 131,200 examples, moving-average loss 0.15
# 132,000 examples, moving-average loss 0.14
# 132,800 examples, moving-average loss 0.13
# 133,600 examples, moving-average loss 0.16
# 134,400 examples, moving-average loss 0.13
# 135,200 examples, moving-average loss 0.17
# 136,000 examples, moving-average loss 0.13
# 136,800 examples, moving-average loss 0.13
# 137,600 examples, moving-average loss 0.14
# 138,400 examples, moving-average loss 0.12
# 139,200 examples, moving-average loss 0.16
# 140,000 examples, moving-average loss 0.22
# 140,800 examples, moving-average loss 0.19
# 141,600 examples, moving-average loss 0.19
# 142,400 examples, moving-average loss 0.20
# 143,200 examples, moving-average loss 0.18
# 144,000 examples, moving-average loss 0.19
# 144,800 examples, moving-average loss 0.22
# 145,600 examples, moving-average loss 0.20
# 146,400 examples, moving-average loss 0.21
# 147,200 examples, moving-average loss 0.19
# 148,000 examples, moving-average loss 0.13
# 148,800 examples, moving-average loss 0.15
# 149,600 examples, moving-average loss 0.14
# 150,400 examples, moving-average loss 0.26
# 151,200 examples, moving-average loss 0.19
# 152,000 examples, moving-average loss 0.18
# 152,800 examples, moving-average loss 0.15
# 153,600 examples, moving-average loss 0.20
# Completed one epoch in 0:01:24

# %%
import models; reload(models)

# Specify model hyperparameters as used by model_fn
model_params = dict(V=vocab.size, embed_dim=70, hidden_dims=[75,50,25], num_classes=2,
                    encoder_type='bow',
                    lr=0.1, optimizer='adagrad', beta=0.01)

checkpoint_dir = "/tmp/tf_bow_sst_" + datetime.datetime.now().strftime("%Y%m%d-%H%M")
if os.path.isdir(checkpoint_dir):
    shutil.rmtree(checkpoint_dir)
# Write vocabulary to file, so TensorBoard can label embeddings.
# creates checkpoint_dir/projector_config.pbtxt and checkpoint_dir/metadata.tsv
vocab.write_projector_config(checkpoint_dir, "Encoder/Embedding_Layer/W_embed")

model = tf.estimator.Estimator(model_fn=models.classifier_model_fn, 
                               params=model_params,
                               model_dir=checkpoint_dir)
print("")
print("To view training (once it starts), run:\n")
print("    tensorboard --logdir='{:s}' --port 6006".format(checkpoint_dir))
print("\nThen in your browser, open: http://localhost:6006")
# Out:
# Vocabulary (70,000 words) written to '/tmp/tf_bow_sst_20180327-2137/metadata.tsv'
# Projector config written to /tmp/tf_bow_sst_20180327-2137/projector_config.pbtxt
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tf_bow_sst_20180327-2137', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f2db998cf60>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
#
# To view training (once it starts), run:
#
#     tensorboard --logdir='/tmp/tf_bow_sst_20180327-2137' --port 6006
#
# Then in your browser, open: http://localhost:6006

# %% [markdown]
# ### Training

# %%
# Training params, just used in this cell for the input_fn-s
train_params = dict(batch_size=32, total_epochs=20, eval_every=5)
assert(train_params['total_epochs'] % train_params['eval_every'] == 0)

# Construct and train the model, saving checkpoints to the directory above.
# Input function for training set batches
# Do 'eval_every' epochs at once, followed by evaluating on the dev set.
# NOTE: use patch_numpy_io.numpy_input_fn instead of tf.estimator.inputs.numpy_input_fn
train_input_fn = patched_numpy_io.numpy_input_fn(
                    x={"ids": train_x_np, "ns": train_ns_np}, y=train_y_np,
                    batch_size=train_params['batch_size'], 
                    num_epochs=train_params['eval_every'], shuffle=True, seed=42
                 )

# %%
# Input function for dev set batches. As above, but:
# - Don't randomize order
# - Iterate exactly once (one epoch)
dev_input_fn = tf.estimator.inputs.numpy_input_fn(
                    x={"ids": dev_x_np, "ns": dev_ns_np}, y=dev_y_np,
                    batch_size=128, num_epochs=1, shuffle=False
                )

for _ in range(train_params['total_epochs'] // train_params['eval_every']):
    # Train for a few epochs, then evaluate on dev
    model.train(input_fn=train_input_fn)
    eval_metrics = model.evaluate(input_fn=dev_input_fn, name="dev")
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tf_bow_sst_20180327-2137/model.ckpt.
# INFO:tensorflow:loss = 1.82126, step = 1
# INFO:tensorflow:global_step/sec: 59.9164
# INFO:tensorflow:loss = 0.73191, step = 101 (1.672 sec)
# INFO:tensorflow:global_step/sec: 71.2278
# INFO:tensorflow:loss = 0.418399, step = 201 (1.404 sec)
# INFO:tensorflow:global_step/sec: 68.7876
# INFO:tensorflow:loss = 0.292477, step = 301 (1.454 sec)
# INFO:tensorflow:global_step/sec: 64.8233
# INFO:tensorflow:loss = 0.26894, step = 401 (1.544 sec)
# INFO:tensorflow:global_step/sec: 62.5292
# INFO:tensorflow:loss = 0.218901, step = 501 (1.598 sec)
# INFO:tensorflow:global_step/sec: 70.955
# INFO:tensorflow:loss = 0.179217, step = 601 (1.409 sec)
# INFO:tensorflow:global_step/sec: 70.9919
# INFO:tensorflow:loss = 0.33531, step = 701 (1.408 sec)
# INFO:tensorflow:global_step/sec: 71.4076
# INFO:tensorflow:loss = 0.13961, step = 801 (1.401 sec)
# INFO:tensorflow:global_step/sec: 70.3332
# INFO:tensorflow:loss = 0.147802, step = 901 (1.422 sec)
# INFO:tensorflow:global_step/sec: 67.3867
# INFO:tensorflow:loss = 0.371534, step = 1001 (1.484 sec)
# INFO:tensorflow:global_step/sec: 67.8627
# INFO:tensorflow:loss = 0.316922, step = 1101 (1.473 sec)
# INFO:tensorflow:global_step/sec: 68.7737
# INFO:tensorflow:loss = 0.437693, step = 1201 (1.455 sec)
# INFO:tensorflow:global_step/sec: 66.0341
# INFO:tensorflow:loss = 0.388264, step = 1301 (1.513 sec)
# INFO:tensorflow:global_step/sec: 68.2565
# INFO:tensorflow:loss = 0.168886, step = 1401 (1.467 sec)
# INFO:tensorflow:global_step/sec: 70.0689
# INFO:tensorflow:loss = 0.1561, step = 1501 (1.426 sec)
# INFO:tensorflow:global_step/sec: 67.4296
# INFO:tensorflow:loss = 0.198975, step = 1601 (1.483 sec)
# INFO:tensorflow:global_step/sec: 68.0766
# INFO:tensorflow:loss = 0.209753, step = 1701 (1.469 sec)
# INFO:tensorflow:global_step/sec: 66.0528
# INFO:tensorflow:loss = 0.105228, step = 1801 (1.515 sec)
# INFO:tensorflow:global_step/sec: 68.0576
# INFO:tensorflow:loss = 0.265295, step = 1901 (1.468 sec)
# INFO:tensorflow:global_step/sec: 69.3385
# INFO:tensorflow:loss = 0.104504, step = 2001 (1.444 sec)
# INFO:tensorflow:global_step/sec: 66.3354
# INFO:tensorflow:loss = 0.359374, step = 2101 (1.508 sec)
# INFO:tensorflow:global_step/sec: 65.7044
# INFO:tensorflow:loss = 0.142825, step = 2201 (1.521 sec)
# INFO:tensorflow:global_step/sec: 60.9426
# INFO:tensorflow:loss = 0.13091, step = 2301 (1.641 sec)
# INFO:tensorflow:global_step/sec: 66.8453
# INFO:tensorflow:loss = 0.126598, step = 2401 (1.496 sec)
# INFO:tensorflow:global_step/sec: 66.0124
# INFO:tensorflow:loss = 0.143346, step = 2501 (1.514 sec)
# INFO:tensorflow:global_step/sec: 65.352
# INFO:tensorflow:loss = 0.255484, step = 2601 (1.531 sec)
# INFO:tensorflow:global_step/sec: 67.005
# INFO:tensorflow:loss = 0.275367, step = 2701 (1.491 sec)
# INFO:tensorflow:global_step/sec: 67.9475
# INFO:tensorflow:loss = 0.175111, step = 2801 (1.471 sec)
# INFO:tensorflow:global_step/sec: 63.7605
# INFO:tensorflow:loss = 0.124465, step = 2901 (1.570 sec)
# INFO:tensorflow:global_step/sec: 68.589
# INFO:tensorflow:loss = 0.151604, step = 3001 (1.457 sec)
# INFO:tensorflow:global_step/sec: 67.18
# INFO:tensorflow:loss = 0.116654, step = 3101 (1.490 sec)
# INFO:tensorflow:global_step/sec: 68.1429
# INFO:tensorflow:loss = 0.107525, step = 3201 (1.466 sec)
# INFO:tensorflow:global_step/sec: 67.5106
# INFO:tensorflow:loss = 0.141541, step = 3301 (1.481 sec)
# INFO:tensorflow:global_step/sec: 62.0096
# INFO:tensorflow:loss = 0.113742, step = 3401 (1.614 sec)
# INFO:tensorflow:global_step/sec: 60.5823
# INFO:tensorflow:loss = 0.178776, step = 3501 (1.651 sec)
# INFO:tensorflow:global_step/sec: 57.1393
# INFO:tensorflow:loss = 0.371738, step = 3601 (1.750 sec)
# INFO:tensorflow:global_step/sec: 62.6072
# INFO:tensorflow:loss = 0.192308, step = 3701 (1.598 sec)
# INFO:tensorflow:global_step/sec: 62.6643
# INFO:tensorflow:loss = 0.138419, step = 3801 (1.595 sec)
# INFO:tensorflow:global_step/sec: 57.7
# INFO:tensorflow:loss = 0.118126, step = 3901 (1.732 sec)
# INFO:tensorflow:global_step/sec: 65.8425
# INFO:tensorflow:loss = 0.314851, step = 4001 (1.520 sec)
# INFO:tensorflow:global_step/sec: 65.5703
# INFO:tensorflow:loss = 0.11581, step = 4101 (1.524 sec)
# INFO:tensorflow:global_step/sec: 69.9994
# INFO:tensorflow:loss = 0.1406, step = 4201 (1.429 sec)
# INFO:tensorflow:global_step/sec: 70.0322
# INFO:tensorflow:loss = 0.124192, step = 4301 (1.427 sec)
# INFO:tensorflow:global_step/sec: 69.6925
# INFO:tensorflow:loss = 0.0937034, step = 4401 (1.435 sec)
# INFO:tensorflow:global_step/sec: 66.0007
# INFO:tensorflow:loss = 0.0980944, step = 4501 (1.515 sec)
# INFO:tensorflow:global_step/sec: 69.5071
# INFO:tensorflow:loss = 0.1015, step = 4601 (1.440 sec)
# INFO:tensorflow:global_step/sec: 65.525
# INFO:tensorflow:loss = 0.135445, step = 4701 (1.524 sec)
# INFO:tensorflow:global_step/sec: 70.8967
# INFO:tensorflow:loss = 0.154938, step = 4801 (1.411 sec)
# INFO:tensorflow:global_step/sec: 66.3701
# INFO:tensorflow:loss = 0.144878, step = 4901 (1.507 sec)
# INFO:tensorflow:global_step/sec: 69.7781
# INFO:tensorflow:loss = 0.542961, step = 5001 (1.433 sec)
# INFO:tensorflow:global_step/sec: 70.4604
# INFO:tensorflow:loss = 0.106172, step = 5101 (1.419 sec)
# INFO:tensorflow:global_step/sec: 66.6868
# INFO:tensorflow:loss = 0.141061, step = 5201 (1.499 sec)
# INFO:tensorflow:global_step/sec: 67.6233
# INFO:tensorflow:loss = 0.0937187, step = 5301 (1.479 sec)
# INFO:tensorflow:global_step/sec: 66.7279
# INFO:tensorflow:loss = 0.109971, step = 5401 (1.500 sec)
# INFO:tensorflow:global_step/sec: 64.506
# INFO:tensorflow:loss = 0.21654, step = 5501 (1.550 sec)
# INFO:tensorflow:global_step/sec: 64.3955
# INFO:tensorflow:loss = 0.106976, step = 5601 (1.554 sec)
# INFO:tensorflow:global_step/sec: 63.6418
# INFO:tensorflow:loss = 0.132935, step = 5701 (1.570 sec)
# INFO:tensorflow:global_step/sec: 65.7706
# INFO:tensorflow:loss = 0.178488, step = 5801 (1.520 sec)
# INFO:tensorflow:global_step/sec: 66.0526
# INFO:tensorflow:loss = 0.127151, step = 5901 (1.515 sec)
# INFO:tensorflow:global_step/sec: 60.8505
# INFO:tensorflow:loss = 0.165327, step = 6001 (1.643 sec)
# INFO:tensorflow:global_step/sec: 68.6441
# INFO:tensorflow:loss = 0.103905, step = 6101 (1.458 sec)
# INFO:tensorflow:global_step/sec: 66.1936
# INFO:tensorflow:loss = 0.134847, step = 6201 (1.511 sec)
# INFO:tensorflow:global_step/sec: 66.7643
# INFO:tensorflow:loss = 0.211952, step = 6301 (1.497 sec)
# INFO:tensorflow:global_step/sec: 66.3928
# INFO:tensorflow:loss = 0.110193, step = 6401 (1.506 sec)
# INFO:tensorflow:global_step/sec: 66.7337
# INFO:tensorflow:loss = 0.120191, step = 6501 (1.499 sec)
# INFO:tensorflow:global_step/sec: 65.7547
# INFO:tensorflow:loss = 0.0953103, step = 6601 (1.521 sec)
# INFO:tensorflow:global_step/sec: 61.3142
# INFO:tensorflow:loss = 0.102151, step = 6701 (1.630 sec)
# INFO:tensorflow:global_step/sec: 65.611
# INFO:tensorflow:loss = 0.108636, step = 6801 (1.525 sec)
# INFO:tensorflow:global_step/sec: 58.9357
# INFO:tensorflow:loss = 0.120933, step = 6901 (1.697 sec)
# INFO:tensorflow:global_step/sec: 61.9007
# INFO:tensorflow:loss = 0.104037, step = 7001 (1.616 sec)
# INFO:tensorflow:global_step/sec: 59.0752
# INFO:tensorflow:loss = 0.101138, step = 7101 (1.693 sec)
# INFO:tensorflow:global_step/sec: 67.7449
# INFO:tensorflow:loss = 0.308908, step = 7201 (1.475 sec)
# INFO:tensorflow:global_step/sec: 66.7686
# INFO:tensorflow:loss = 0.0962265, step = 7301 (1.498 sec)
# INFO:tensorflow:global_step/sec: 66.6323
# INFO:tensorflow:loss = 0.147247, step = 7401 (1.501 sec)
# INFO:tensorflow:global_step/sec: 63.9779
# INFO:tensorflow:loss = 0.113655, step = 7501 (1.564 sec)
# INFO:tensorflow:global_step/sec: 66.8386
# INFO:tensorflow:loss = 0.0887105, step = 7601 (1.494 sec)
# INFO:tensorflow:global_step/sec: 66.6967
# INFO:tensorflow:loss = 0.388592, step = 7701 (1.500 sec)
# INFO:tensorflow:global_step/sec: 68.1988
# INFO:tensorflow:loss = 0.106455, step = 7801 (1.467 sec)
# INFO:tensorflow:global_step/sec: 67.9874
# INFO:tensorflow:loss = 0.156567, step = 7901 (1.472 sec)
# INFO:tensorflow:global_step/sec: 66.8096
# INFO:tensorflow:loss = 0.164492, step = 8001 (1.495 sec)
# INFO:tensorflow:global_step/sec: 63.5125
# INFO:tensorflow:loss = 0.128455, step = 8101 (1.575 sec)
# INFO:tensorflow:global_step/sec: 68.9204
# INFO:tensorflow:loss = 0.122467, step = 8201 (1.451 sec)
# INFO:tensorflow:global_step/sec: 67.0065
# INFO:tensorflow:loss = 0.306516, step = 8301 (1.491 sec)
# INFO:tensorflow:global_step/sec: 68.3291
# INFO:tensorflow:loss = 0.118575, step = 8401 (1.464 sec)
# INFO:tensorflow:global_step/sec: 67.3678
# INFO:tensorflow:loss = 0.127384, step = 8501 (1.485 sec)
# INFO:tensorflow:global_step/sec: 63.0802
# INFO:tensorflow:loss = 0.291643, step = 8601 (1.584 sec)
# INFO:tensorflow:global_step/sec: 61.8418
# INFO:tensorflow:loss = 0.0927649, step = 8701 (1.618 sec)
# INFO:tensorflow:global_step/sec: 62.7107
# INFO:tensorflow:loss = 0.16933, step = 8801 (1.595 sec)
# INFO:tensorflow:global_step/sec: 59.2764
# INFO:tensorflow:loss = 0.0947926, step = 8901 (1.686 sec)
# INFO:tensorflow:global_step/sec: 68.4779
# INFO:tensorflow:loss = 0.110266, step = 9001 (1.461 sec)
# INFO:tensorflow:global_step/sec: 68.5699
# INFO:tensorflow:loss = 0.109463, step = 9101 (1.458 sec)
# INFO:tensorflow:global_step/sec: 66.9974
# INFO:tensorflow:loss = 0.104234, step = 9201 (1.492 sec)
# INFO:tensorflow:global_step/sec: 68.2664
# INFO:tensorflow:loss = 0.104887, step = 9301 (1.465 sec)
# INFO:tensorflow:global_step/sec: 65.3132
# INFO:tensorflow:loss = 0.108965, step = 9401 (1.531 sec)
# INFO:tensorflow:global_step/sec: 63.0092
# INFO:tensorflow:loss = 0.138684, step = 9501 (1.589 sec)
# INFO:tensorflow:global_step/sec: 64.5101
# INFO:tensorflow:loss = 0.38374, step = 9601 (1.549 sec)
# INFO:tensorflow:global_step/sec: 67.3985
# INFO:tensorflow:loss = 0.11165, step = 9701 (1.483 sec)
# INFO:tensorflow:global_step/sec: 69.5895
# INFO:tensorflow:loss = 0.161166, step = 9801 (1.437 sec)
# INFO:tensorflow:global_step/sec: 70.2712
# INFO:tensorflow:loss = 0.0899771, step = 9901 (1.423 sec)
# INFO:tensorflow:global_step/sec: 68.5568
# INFO:tensorflow:loss = 0.106364, step = 10001 (1.459 sec)
# INFO:tensorflow:global_step/sec: 67.1329
# INFO:tensorflow:loss = 0.0972086, step = 10101 (1.490 sec)
# INFO:tensorflow:global_step/sec: 68.4955
# INFO:tensorflow:loss = 0.109074, step = 10201 (1.460 sec)
# INFO:tensorflow:global_step/sec: 69.9549
# INFO:tensorflow:loss = 0.0927803, step = 10301 (1.431 sec)
# INFO:tensorflow:global_step/sec: 67.874
# INFO:tensorflow:loss = 0.101485, step = 10401 (1.472 sec)
# INFO:tensorflow:global_step/sec: 68.3934
# INFO:tensorflow:loss = 0.111212, step = 10501 (1.462 sec)
# INFO:tensorflow:global_step/sec: 66.2643
# INFO:tensorflow:loss = 0.0927162, step = 10601 (1.510 sec)
# INFO:tensorflow:global_step/sec: 69.1752
# INFO:tensorflow:loss = 0.167619, step = 10701 (1.444 sec)
# INFO:tensorflow:global_step/sec: 71.451
# INFO:tensorflow:loss = 0.177189, step = 10801 (1.400 sec)
# INFO:tensorflow:global_step/sec: 59.7039
# INFO:tensorflow:loss = 0.190851, step = 10901 (1.678 sec)
# INFO:tensorflow:global_step/sec: 62.0684
# INFO:tensorflow:loss = 0.14675, step = 11001 (1.611 sec)
# INFO:tensorflow:global_step/sec: 58.049
# INFO:tensorflow:loss = 0.0998137, step = 11101 (1.723 sec)
# INFO:tensorflow:global_step/sec: 57.0521
# INFO:tensorflow:loss = 0.107635, step = 11201 (1.752 sec)
# INFO:tensorflow:global_step/sec: 53.9234
# INFO:tensorflow:loss = 0.114015, step = 11301 (1.854 sec)
# INFO:tensorflow:global_step/sec: 58.6637
# INFO:tensorflow:loss = 0.0924813, step = 11401 (1.705 sec)
# INFO:tensorflow:global_step/sec: 58.9871
# INFO:tensorflow:loss = 0.12554, step = 11501 (1.695 sec)
# INFO:tensorflow:global_step/sec: 57.6924
# INFO:tensorflow:loss = 0.104282, step = 11601 (1.734 sec)
# INFO:tensorflow:global_step/sec: 57.7811
# INFO:tensorflow:loss = 0.0941348, step = 11701 (1.730 sec)
# INFO:tensorflow:global_step/sec: 54.364
# INFO:tensorflow:loss = 0.0866424, step = 11801 (1.840 sec)
# INFO:tensorflow:global_step/sec: 56.5825
# INFO:tensorflow:loss = 0.108716, step = 11901 (1.767 sec)
# INFO:tensorflow:global_step/sec: 56.837
# INFO:tensorflow:loss = 0.0987752, step = 12001 (1.760 sec)
# INFO:tensorflow:global_step/sec: 64.546
# INFO:tensorflow:loss = 0.111905, step = 12101 (1.546 sec)
# INFO:tensorflow:global_step/sec: 70.3403
# INFO:tensorflow:loss = 0.141653, step = 12201 (1.423 sec)
# INFO:tensorflow:global_step/sec: 65.6686
# INFO:tensorflow:loss = 0.0961108, step = 12301 (1.522 sec)
# INFO:tensorflow:global_step/sec: 61.314
# INFO:tensorflow:loss = 0.132265, step = 12401 (1.630 sec)
# INFO:tensorflow:global_step/sec: 58.5421
# INFO:tensorflow:loss = 0.0919967, step = 12501 (1.708 sec)
# INFO:tensorflow:global_step/sec: 66.1246
# INFO:tensorflow:loss = 0.102542, step = 12601 (1.512 sec)
# INFO:tensorflow:global_step/sec: 65.9129
# INFO:tensorflow:loss = 0.104782, step = 12701 (1.518 sec)
# INFO:tensorflow:global_step/sec: 69.0043
# INFO:tensorflow:loss = 0.14993, step = 12801 (1.451 sec)
# INFO:tensorflow:global_step/sec: 63.9767
# INFO:tensorflow:loss = 0.15265, step = 12901 (1.562 sec)
# INFO:tensorflow:global_step/sec: 69.0106
# INFO:tensorflow:loss = 0.13428, step = 13001 (1.448 sec)
# INFO:tensorflow:global_step/sec: 67.5082
# INFO:tensorflow:loss = 0.257003, step = 13101 (1.481 sec)
# INFO:tensorflow:global_step/sec: 69.6288
# INFO:tensorflow:loss = 0.127506, step = 13201 (1.437 sec)
# INFO:tensorflow:global_step/sec: 65.3871
# INFO:tensorflow:loss = 0.120813, step = 13301 (1.530 sec)
# INFO:tensorflow:global_step/sec: 68.7626
# INFO:tensorflow:loss = 0.110572, step = 13401 (1.454 sec)
# INFO:tensorflow:global_step/sec: 67.8037
# INFO:tensorflow:loss = 0.117078, step = 13501 (1.473 sec)
# INFO:tensorflow:global_step/sec: 69.3659
# INFO:tensorflow:loss = 0.0923601, step = 13601 (1.443 sec)
# INFO:tensorflow:global_step/sec: 60.2121
# INFO:tensorflow:loss = 0.127151, step = 13701 (1.661 sec)
# INFO:tensorflow:global_step/sec: 63.1971
# INFO:tensorflow:loss = 0.0956888, step = 13801 (1.584 sec)
# INFO:tensorflow:global_step/sec: 65.2482
# INFO:tensorflow:loss = 0.0917486, step = 13901 (1.530 sec)
# INFO:tensorflow:global_step/sec: 68.1934
# INFO:tensorflow:loss = 0.0959187, step = 14001 (1.467 sec)
# INFO:tensorflow:global_step/sec: 70.7071
# INFO:tensorflow:loss = 0.106319, step = 14101 (1.414 sec)
# INFO:tensorflow:global_step/sec: 70.3826
# INFO:tensorflow:loss = 0.0891239, step = 14201 (1.421 sec)
# INFO:tensorflow:global_step/sec: 69.8769
# INFO:tensorflow:loss = 0.0922087, step = 14301 (1.430 sec)
# INFO:tensorflow:global_step/sec: 60.3549
# INFO:tensorflow:loss = 0.107616, step = 14401 (1.658 sec)
# INFO:tensorflow:global_step/sec: 66.647
# INFO:tensorflow:loss = 0.0878828, step = 14501 (1.502 sec)
# INFO:tensorflow:global_step/sec: 61.1864
# INFO:tensorflow:loss = 0.0919254, step = 14601 (1.633 sec)
# INFO:tensorflow:global_step/sec: 62.2781
# INFO:tensorflow:loss = 0.0890288, step = 14701 (1.606 sec)
# INFO:tensorflow:global_step/sec: 65.9423
# INFO:tensorflow:loss = 0.134208, step = 14801 (1.515 sec)
# INFO:tensorflow:global_step/sec: 66.5486
# INFO:tensorflow:loss = 0.104079, step = 14901 (1.503 sec)
# INFO:tensorflow:global_step/sec: 66.8902
# INFO:tensorflow:loss = 0.0934728, step = 15001 (1.496 sec)
# INFO:tensorflow:global_step/sec: 68.6957
# INFO:tensorflow:loss = 0.352846, step = 15101 (1.457 sec)
# INFO:tensorflow:global_step/sec: 63.1187
# INFO:tensorflow:loss = 0.101707, step = 15201 (1.585 sec)
# INFO:tensorflow:global_step/sec: 64.8313
# INFO:tensorflow:loss = 0.0916807, step = 15301 (1.541 sec)
# INFO:tensorflow:global_step/sec: 69.3509
# INFO:tensorflow:loss = 0.15319, step = 15401 (1.441 sec)
# INFO:tensorflow:global_step/sec: 71.2204
# INFO:tensorflow:loss = 0.106144, step = 15501 (1.404 sec)
# INFO:tensorflow:global_step/sec: 74.1717
# INFO:tensorflow:loss = 0.114246, step = 15601 (1.348 sec)
# INFO:tensorflow:global_step/sec: 64.8052
# INFO:tensorflow:loss = 0.114306, step = 15701 (1.543 sec)
# INFO:tensorflow:global_step/sec: 63.9238
# INFO:tensorflow:loss = 0.103211, step = 15801 (1.568 sec)
# INFO:tensorflow:global_step/sec: 65.3343
# INFO:tensorflow:loss = 0.0938747, step = 15901 (1.528 sec)
# INFO:tensorflow:global_step/sec: 69.415
# INFO:tensorflow:loss = 0.101105, step = 16001 (1.441 sec)
# INFO:tensorflow:global_step/sec: 68.0903
# INFO:tensorflow:loss = 0.0911367, step = 16101 (1.468 sec)
# INFO:tensorflow:global_step/sec: 71.2615
# INFO:tensorflow:loss = 0.0909821, step = 16201 (1.403 sec)
# INFO:tensorflow:global_step/sec: 68.163
# INFO:tensorflow:loss = 0.0953891, step = 16301 (1.467 sec)
# INFO:tensorflow:global_step/sec: 67.4373
# INFO:tensorflow:loss = 0.0907062, step = 16401 (1.483 sec)
# INFO:tensorflow:global_step/sec: 69.4134
# INFO:tensorflow:loss = 0.112035, step = 16501 (1.441 sec)
# INFO:tensorflow:global_step/sec: 67.013
# INFO:tensorflow:loss = 0.094587, step = 16601 (1.492 sec)
# INFO:tensorflow:global_step/sec: 69.3807
# INFO:tensorflow:loss = 0.0920861, step = 16701 (1.441 sec)
# INFO:tensorflow:global_step/sec: 69.8942
# INFO:tensorflow:loss = 0.102028, step = 16801 (1.431 sec)
# INFO:tensorflow:global_step/sec: 69.21
# INFO:tensorflow:loss = 0.0951169, step = 16901 (1.445 sec)
# INFO:tensorflow:global_step/sec: 70.4526
# INFO:tensorflow:loss = 0.0951219, step = 17001 (1.419 sec)
# INFO:tensorflow:global_step/sec: 64.4283
# INFO:tensorflow:loss = 0.0940232, step = 17101 (1.554 sec)
# INFO:tensorflow:global_step/sec: 61.0432
# INFO:tensorflow:loss = 0.0928903, step = 17201 (1.638 sec)
# INFO:tensorflow:global_step/sec: 68.3677
# INFO:tensorflow:loss = 0.0983105, step = 17301 (1.462 sec)
# INFO:tensorflow:global_step/sec: 66.4525
# INFO:tensorflow:loss = 0.0883767, step = 17401 (1.506 sec)
# INFO:tensorflow:global_step/sec: 68.3418
# INFO:tensorflow:loss = 0.121454, step = 17501 (1.461 sec)
# INFO:tensorflow:global_step/sec: 67.6507
# INFO:tensorflow:loss = 0.103661, step = 17601 (1.478 sec)
# INFO:tensorflow:global_step/sec: 72.1595
# INFO:tensorflow:loss = 0.0972475, step = 17701 (1.386 sec)
# INFO:tensorflow:global_step/sec: 67.1594
# INFO:tensorflow:loss = 0.110864, step = 17801 (1.490 sec)
# INFO:tensorflow:global_step/sec: 63.6159
# INFO:tensorflow:loss = 0.275075, step = 17901 (1.571 sec)
# INFO:tensorflow:global_step/sec: 64.7209
# INFO:tensorflow:loss = 0.138285, step = 18001 (1.545 sec)
# INFO:tensorflow:global_step/sec: 65.5767
# INFO:tensorflow:loss = 0.0981251, step = 18101 (1.525 sec)
# INFO:tensorflow:global_step/sec: 69.3968
# INFO:tensorflow:loss = 0.0953281, step = 18201 (1.441 sec)
# INFO:tensorflow:global_step/sec: 67.3671
# INFO:tensorflow:loss = 0.124494, step = 18301 (1.485 sec)
# INFO:tensorflow:global_step/sec: 65.9901
# INFO:tensorflow:loss = 0.0938338, step = 18401 (1.516 sec)
# INFO:tensorflow:global_step/sec: 71.7284
# INFO:tensorflow:loss = 0.124689, step = 18501 (1.393 sec)
# INFO:tensorflow:global_step/sec: 65.3351
# INFO:tensorflow:loss = 0.0964308, step = 18601 (1.530 sec)
# INFO:tensorflow:global_step/sec: 67.6444
# INFO:tensorflow:loss = 0.0936495, step = 18701 (1.478 sec)
# INFO:tensorflow:global_step/sec: 70.1116
# INFO:tensorflow:loss = 0.0884963, step = 18801 (1.427 sec)
# INFO:tensorflow:global_step/sec: 68.7069
# INFO:tensorflow:loss = 0.0926552, step = 18901 (1.456 sec)
# INFO:tensorflow:global_step/sec: 72.7043
# INFO:tensorflow:loss = 0.130412, step = 19001 (1.376 sec)
# INFO:tensorflow:global_step/sec: 68.967
# INFO:tensorflow:loss = 0.101935, step = 19101 (1.448 sec)
# INFO:tensorflow:global_step/sec: 71.7375
# INFO:tensorflow:loss = 0.105137, step = 19201 (1.396 sec)
# INFO:tensorflow:global_step/sec: 60.3341
# INFO:tensorflow:loss = 0.121447, step = 19301 (1.659 sec)
# INFO:tensorflow:global_step/sec: 63.011
# INFO:tensorflow:loss = 0.0993658, step = 19401 (1.585 sec)
# INFO:tensorflow:global_step/sec: 62.8016
# INFO:tensorflow:loss = 0.0891055, step = 19501 (1.594 sec)
# INFO:tensorflow:global_step/sec: 55.648
# INFO:tensorflow:loss = 0.0972563, step = 19601 (1.797 sec)
# INFO:tensorflow:global_step/sec: 57.9679
# INFO:tensorflow:loss = 0.138455, step = 19701 (1.721 sec)
# INFO:tensorflow:global_step/sec: 68.2956
# INFO:tensorflow:loss = 0.107211, step = 19801 (1.464 sec)
# INFO:tensorflow:global_step/sec: 67.6998
# INFO:tensorflow:loss = 0.159425, step = 19901 (1.479 sec)
# INFO:tensorflow:global_step/sec: 68.933
# INFO:tensorflow:loss = 0.0925673, step = 20001 (1.451 sec)
# INFO:tensorflow:global_step/sec: 67.8475
# INFO:tensorflow:loss = 0.0895633, step = 20101 (1.472 sec)
# INFO:tensorflow:global_step/sec: 70.762
# INFO:tensorflow:loss = 0.0863751, step = 20201 (1.413 sec)
# INFO:tensorflow:global_step/sec: 68.2771
# INFO:tensorflow:loss = 0.0899493, step = 20301 (1.465 sec)
# INFO:tensorflow:global_step/sec: 63.9071
# INFO:tensorflow:loss = 0.149347, step = 20401 (1.566 sec)
# INFO:tensorflow:global_step/sec: 59.4038
# INFO:tensorflow:loss = 0.446259, step = 20501 (1.683 sec)
# INFO:tensorflow:global_step/sec: 58.0886
# INFO:tensorflow:loss = 0.111338, step = 20601 (1.722 sec)
# INFO:tensorflow:global_step/sec: 58.404
# INFO:tensorflow:loss = 0.127556, step = 20701 (1.711 sec)
# INFO:tensorflow:global_step/sec: 61.0749
# INFO:tensorflow:loss = 0.147426, step = 20801 (1.638 sec)
# INFO:tensorflow:global_step/sec: 59.8872
# INFO:tensorflow:loss = 0.105774, step = 20901 (1.669 sec)
# INFO:tensorflow:global_step/sec: 67.9569
# INFO:tensorflow:loss = 0.103471, step = 21001 (1.472 sec)
# INFO:tensorflow:global_step/sec: 74.2409
# INFO:tensorflow:loss = 0.11858, step = 21101 (1.346 sec)
# INFO:tensorflow:global_step/sec: 74.3728
# INFO:tensorflow:loss = 0.100419, step = 21201 (1.344 sec)
# INFO:tensorflow:global_step/sec: 77.5322
# INFO:tensorflow:loss = 0.108074, step = 21301 (1.290 sec)
# INFO:tensorflow:global_step/sec: 76.6579
# INFO:tensorflow:loss = 0.0875785, step = 21401 (1.305 sec)
# INFO:tensorflow:global_step/sec: 76.6862
# INFO:tensorflow:loss = 0.0962081, step = 21501 (1.304 sec)
# INFO:tensorflow:global_step/sec: 77.7732
# INFO:tensorflow:loss = 0.0920617, step = 21601 (1.286 sec)
# INFO:tensorflow:global_step/sec: 76.5193
# INFO:tensorflow:loss = 0.297757, step = 21701 (1.307 sec)
# INFO:tensorflow:global_step/sec: 77.2523
# INFO:tensorflow:loss = 0.10086, step = 21801 (1.294 sec)
# INFO:tensorflow:global_step/sec: 58.1859
# INFO:tensorflow:loss = 0.0997921, step = 21901 (1.722 sec)
# INFO:tensorflow:global_step/sec: 58.4464
# INFO:tensorflow:loss = 0.102582, step = 22001 (1.711 sec)
# INFO:tensorflow:global_step/sec: 54.3487
# INFO:tensorflow:loss = 0.0976446, step = 22101 (1.839 sec)
# INFO:tensorflow:global_step/sec: 58.5333
# INFO:tensorflow:loss = 0.0944137, step = 22201 (1.708 sec)
# INFO:tensorflow:global_step/sec: 55.5808
# INFO:tensorflow:loss = 0.107263, step = 22301 (1.798 sec)
# INFO:tensorflow:global_step/sec: 62.0831
# INFO:tensorflow:loss = 0.116138, step = 22401 (1.611 sec)
# INFO:tensorflow:global_step/sec: 58.2846
# INFO:tensorflow:loss = 0.0925853, step = 22501 (1.714 sec)
# INFO:tensorflow:global_step/sec: 69.729
# INFO:tensorflow:loss = 0.27966, step = 22601 (1.434 sec)
# INFO:tensorflow:global_step/sec: 68.3089
# INFO:tensorflow:loss = 0.156797, step = 22701 (1.464 sec)
# INFO:tensorflow:global_step/sec: 69.112
# INFO:tensorflow:loss = 0.127979, step = 22801 (1.447 sec)
# INFO:tensorflow:global_step/sec: 69.1149
# INFO:tensorflow:loss = 0.202108, step = 22901 (1.447 sec)
# INFO:tensorflow:global_step/sec: 70.1143
# INFO:tensorflow:loss = 0.0905497, step = 23001 (1.426 sec)
# INFO:tensorflow:global_step/sec: 67.9211
# INFO:tensorflow:loss = 0.117399, step = 23101 (1.473 sec)
# INFO:tensorflow:global_step/sec: 66.8453
# INFO:tensorflow:loss = 0.094024, step = 23201 (1.497 sec)
# INFO:tensorflow:global_step/sec: 67.6387
# INFO:tensorflow:loss = 0.10701, step = 23301 (1.477 sec)
# INFO:tensorflow:global_step/sec: 70.1124
# INFO:tensorflow:loss = 0.0942407, step = 23401 (1.426 sec)
# INFO:tensorflow:global_step/sec: 72.9648
# INFO:tensorflow:loss = 0.0924959, step = 23501 (1.370 sec)
# INFO:tensorflow:global_step/sec: 66.6921
# INFO:tensorflow:loss = 0.122439, step = 23601 (1.499 sec)
# INFO:tensorflow:global_step/sec: 73.3888
# INFO:tensorflow:loss = 0.0869772, step = 23701 (1.364 sec)
# INFO:tensorflow:global_step/sec: 65.0442
# INFO:tensorflow:loss = 0.108501, step = 23801 (1.537 sec)
# INFO:tensorflow:global_step/sec: 71.0111
# INFO:tensorflow:loss = 0.0987695, step = 23901 (1.407 sec)
# INFO:tensorflow:global_step/sec: 73.4704
# INFO:tensorflow:loss = 0.0952194, step = 24001 (1.360 sec)
# INFO:tensorflow:global_step/sec: 78.6354
# INFO:tensorflow:loss = 0.0864913, step = 24101 (1.272 sec)
# INFO:tensorflow:Saving checkpoints for 24106 into /tmp/tf_bow_sst_20180327-2137/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0927624.
# INFO:tensorflow:Starting evaluation at 2018-03-27-21:43:53
# INFO:tensorflow:Restoring parameters from /tmp/tf_bow_sst_20180327-2137/model.ckpt-24106
# INFO:tensorflow:Finished evaluation at 2018-03-27-21:44:05
# INFO:tensorflow:Saving dict for global step 24106: accuracy = 0.943283, cross_entropy_loss = 0.187837, global_step = 24106, loss = 0.311266
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/tf_bow_sst_20180327-2137/model.ckpt-24106
# INFO:tensorflow:Saving checkpoints for 24107 into /tmp/tf_bow_sst_20180327-2137/model.ckpt.
# INFO:tensorflow:loss = 0.0881441, step = 24107
# INFO:tensorflow:global_step/sec: 53.283
# INFO:tensorflow:loss = 0.0992826, step = 24207 (1.883 sec)
# INFO:tensorflow:global_step/sec: 59.0611
# INFO:tensorflow:loss = 0.0839459, step = 24307 (1.694 sec)
# INFO:tensorflow:global_step/sec: 61.1848
# INFO:tensorflow:loss = 0.1021, step = 24407 (1.633 sec)
# INFO:tensorflow:global_step/sec: 58.1607
# INFO:tensorflow:loss = 0.096521, step = 24507 (1.720 sec)
# INFO:tensorflow:global_step/sec: 59.8408
# INFO:tensorflow:loss = 0.0848337, step = 24607 (1.672 sec)
# INFO:tensorflow:global_step/sec: 57.984
# INFO:tensorflow:loss = 0.0991274, step = 24707 (1.724 sec)
# INFO:tensorflow:global_step/sec: 61.7515
# INFO:tensorflow:loss = 0.365957, step = 24807 (1.618 sec)
# INFO:tensorflow:global_step/sec: 53.9429
# INFO:tensorflow:loss = 0.105823, step = 24907 (1.854 sec)
# INFO:tensorflow:global_step/sec: 60.941
# INFO:tensorflow:loss = 0.108318, step = 25007 (1.642 sec)
# INFO:tensorflow:global_step/sec: 59.7932
# INFO:tensorflow:loss = 0.123394, step = 25107 (1.672 sec)
# INFO:tensorflow:global_step/sec: 59.4485
# INFO:tensorflow:loss = 0.132885, step = 25207 (1.683 sec)
# INFO:tensorflow:global_step/sec: 68.686
# INFO:tensorflow:loss = 0.441686, step = 25307 (1.453 sec)
# INFO:tensorflow:global_step/sec: 68.7219
# INFO:tensorflow:loss = 0.168798, step = 25407 (1.455 sec)
# INFO:tensorflow:global_step/sec: 70.3912
# INFO:tensorflow:loss = 0.143577, step = 25507 (1.421 sec)
# INFO:tensorflow:global_step/sec: 68.1329
# INFO:tensorflow:loss = 0.0987091, step = 25607 (1.467 sec)
# INFO:tensorflow:global_step/sec: 67.4115
# INFO:tensorflow:loss = 0.148809, step = 25707 (1.484 sec)
# INFO:tensorflow:global_step/sec: 68.4227
# INFO:tensorflow:loss = 0.115807, step = 25807 (1.462 sec)
# INFO:tensorflow:global_step/sec: 60.7885
# INFO:tensorflow:loss = 0.0882847, step = 25907 (1.647 sec)
# INFO:tensorflow:global_step/sec: 57.4062
# INFO:tensorflow:loss = 0.220165, step = 26007 (1.742 sec)
# INFO:tensorflow:global_step/sec: 64.6475
# INFO:tensorflow:loss = 0.091044, step = 26107 (1.545 sec)
# INFO:tensorflow:global_step/sec: 68.3
# INFO:tensorflow:loss = 0.116649, step = 26207 (1.464 sec)
# INFO:tensorflow:global_step/sec: 71.7751
# INFO:tensorflow:loss = 0.114036, step = 26307 (1.394 sec)
# INFO:tensorflow:global_step/sec: 70.2422
# INFO:tensorflow:loss = 0.0912751, step = 26407 (1.423 sec)
# INFO:tensorflow:global_step/sec: 68.7495
# INFO:tensorflow:loss = 0.0892555, step = 26507 (1.454 sec)
# INFO:tensorflow:global_step/sec: 70.1044
# INFO:tensorflow:loss = 0.106357, step = 26607 (1.427 sec)
# INFO:tensorflow:global_step/sec: 66.7078
# INFO:tensorflow:loss = 0.109663, step = 26707 (1.500 sec)
# INFO:tensorflow:global_step/sec: 62.5721
# INFO:tensorflow:loss = 0.127803, step = 26807 (1.598 sec)
# INFO:tensorflow:global_step/sec: 52.3534
# INFO:tensorflow:loss = 0.0897607, step = 26907 (1.912 sec)
# INFO:tensorflow:global_step/sec: 55.3312
# INFO:tensorflow:loss = 0.0903876, step = 27007 (1.807 sec)
# INFO:tensorflow:global_step/sec: 58.7389
# INFO:tensorflow:loss = 0.131609, step = 27107 (1.701 sec)
# INFO:tensorflow:global_step/sec: 64.3439
# INFO:tensorflow:loss = 0.108287, step = 27207 (1.553 sec)
# INFO:tensorflow:global_step/sec: 60.6441
# INFO:tensorflow:loss = 0.0965399, step = 27307 (1.649 sec)
# INFO:tensorflow:global_step/sec: 61.8178
# INFO:tensorflow:loss = 0.122574, step = 27407 (1.618 sec)
# INFO:tensorflow:global_step/sec: 59.4145
# INFO:tensorflow:loss = 0.0989147, step = 27507 (1.685 sec)
# INFO:tensorflow:global_step/sec: 58.7573
# INFO:tensorflow:loss = 0.158951, step = 27607 (1.700 sec)
# INFO:tensorflow:global_step/sec: 58.4202
# INFO:tensorflow:loss = 0.443003, step = 27707 (1.712 sec)
# INFO:tensorflow:global_step/sec: 59.7334
# INFO:tensorflow:loss = 0.119641, step = 27807 (1.674 sec)
# INFO:tensorflow:global_step/sec: 62.044
# INFO:tensorflow:loss = 0.0927662, step = 27907 (1.613 sec)
# INFO:tensorflow:global_step/sec: 58.8615
# INFO:tensorflow:loss = 0.094583, step = 28007 (1.696 sec)
# INFO:tensorflow:global_step/sec: 64.1979
# INFO:tensorflow:loss = 0.091258, step = 28107 (1.559 sec)
# INFO:tensorflow:global_step/sec: 67.065
# INFO:tensorflow:loss = 0.0971716, step = 28207 (1.489 sec)
# INFO:tensorflow:global_step/sec: 61.115
# INFO:tensorflow:loss = 0.0928895, step = 28307 (1.638 sec)
# INFO:tensorflow:global_step/sec: 65.9578
# INFO:tensorflow:loss = 0.0987057, step = 28407 (1.515 sec)
# INFO:tensorflow:global_step/sec: 73.8222
# INFO:tensorflow:loss = 0.0931127, step = 28507 (1.356 sec)
# INFO:tensorflow:global_step/sec: 61.1181
# INFO:tensorflow:loss = 0.100138, step = 28607 (1.636 sec)
# INFO:tensorflow:global_step/sec: 69.89
# INFO:tensorflow:loss = 0.0883272, step = 28707 (1.430 sec)
# INFO:tensorflow:global_step/sec: 69.0819
# INFO:tensorflow:loss = 0.088251, step = 28807 (1.447 sec)
# INFO:tensorflow:global_step/sec: 71.7081
# INFO:tensorflow:loss = 0.155378, step = 28907 (1.397 sec)
# INFO:tensorflow:global_step/sec: 69.3826
# INFO:tensorflow:loss = 0.0911945, step = 29007 (1.439 sec)
# INFO:tensorflow:global_step/sec: 68.8552
# INFO:tensorflow:loss = 0.359284, step = 29107 (1.452 sec)
# INFO:tensorflow:global_step/sec: 69.2718
# INFO:tensorflow:loss = 0.0924582, step = 29207 (1.446 sec)
# INFO:tensorflow:global_step/sec: 65.9286
# INFO:tensorflow:loss = 0.0901787, step = 29307 (1.515 sec)
# INFO:tensorflow:global_step/sec: 69.7152
# INFO:tensorflow:loss = 0.0824497, step = 29407 (1.436 sec)
# INFO:tensorflow:global_step/sec: 66.3054
# INFO:tensorflow:loss = 0.0925679, step = 29507 (1.507 sec)
# INFO:tensorflow:global_step/sec: 69.4463
# INFO:tensorflow:loss = 0.110601, step = 29607 (1.439 sec)
# INFO:tensorflow:global_step/sec: 63.4125
# INFO:tensorflow:loss = 0.0985744, step = 29707 (1.578 sec)
# INFO:tensorflow:global_step/sec: 62.6798
# INFO:tensorflow:loss = 0.11693, step = 29807 (1.596 sec)
# INFO:tensorflow:global_step/sec: 57.7982
# INFO:tensorflow:loss = 0.151633, step = 29907 (1.731 sec)
# INFO:tensorflow:global_step/sec: 59.8573
# INFO:tensorflow:loss = 0.116588, step = 30007 (1.670 sec)
# INFO:tensorflow:global_step/sec: 58.4979
# INFO:tensorflow:loss = 0.131104, step = 30107 (1.709 sec)
# INFO:tensorflow:global_step/sec: 63.9187
# INFO:tensorflow:loss = 0.098418, step = 30207 (1.564 sec)
# INFO:tensorflow:global_step/sec: 59.9433
# INFO:tensorflow:loss = 0.121808, step = 30307 (1.671 sec)
# INFO:tensorflow:global_step/sec: 64.2654
# INFO:tensorflow:loss = 0.190324, step = 30407 (1.554 sec)
# INFO:tensorflow:global_step/sec: 65.9783
# INFO:tensorflow:loss = 0.0935137, step = 30507 (1.514 sec)
# INFO:tensorflow:global_step/sec: 70.8368
# INFO:tensorflow:loss = 0.0957123, step = 30607 (1.412 sec)
# INFO:tensorflow:global_step/sec: 69.9326
# INFO:tensorflow:loss = 0.0885761, step = 30707 (1.431 sec)
# INFO:tensorflow:global_step/sec: 72.5772
# INFO:tensorflow:loss = 0.107561, step = 30807 (1.377 sec)
# INFO:tensorflow:global_step/sec: 71.6665
# INFO:tensorflow:loss = 0.0947193, step = 30907 (1.396 sec)
# INFO:tensorflow:global_step/sec: 69.2063
# INFO:tensorflow:loss = 0.110959, step = 31007 (1.445 sec)
# INFO:tensorflow:global_step/sec: 71.9579
# INFO:tensorflow:loss = 0.0969575, step = 31107 (1.390 sec)
# INFO:tensorflow:global_step/sec: 70.5295
# INFO:tensorflow:loss = 0.0923679, step = 31207 (1.419 sec)
# INFO:tensorflow:global_step/sec: 70.2664
# INFO:tensorflow:loss = 0.242645, step = 31307 (1.423 sec)
# INFO:tensorflow:global_step/sec: 71.3951
# INFO:tensorflow:loss = 0.091421, step = 31407 (1.400 sec)
# INFO:tensorflow:global_step/sec: 74.8353
# INFO:tensorflow:loss = 0.092552, step = 31507 (1.335 sec)
# INFO:tensorflow:global_step/sec: 69.945
# INFO:tensorflow:loss = 0.0946198, step = 31607 (1.430 sec)
# INFO:tensorflow:global_step/sec: 66.5789
# INFO:tensorflow:loss = 0.0860565, step = 31707 (1.503 sec)
# INFO:tensorflow:global_step/sec: 67.8811
# INFO:tensorflow:loss = 0.421731, step = 31807 (1.472 sec)
# INFO:tensorflow:global_step/sec: 65.0466
# INFO:tensorflow:loss = 0.0951329, step = 31907 (1.538 sec)
# INFO:tensorflow:global_step/sec: 67.8091
# INFO:tensorflow:loss = 0.105883, step = 32007 (1.474 sec)
# INFO:tensorflow:global_step/sec: 67.589
# INFO:tensorflow:loss = 0.155781, step = 32107 (1.482 sec)
# INFO:tensorflow:global_step/sec: 65.8872
# INFO:tensorflow:loss = 0.111146, step = 32207 (1.516 sec)
# INFO:tensorflow:global_step/sec: 65.3618
# INFO:tensorflow:loss = 0.135073, step = 32307 (1.530 sec)
# INFO:tensorflow:global_step/sec: 57.0805
# INFO:tensorflow:loss = 0.304508, step = 32407 (1.751 sec)
# INFO:tensorflow:global_step/sec: 58.3115
# INFO:tensorflow:loss = 0.130737, step = 32507 (1.717 sec)
# INFO:tensorflow:global_step/sec: 61.0827
# INFO:tensorflow:loss = 0.102515, step = 32607 (1.636 sec)
# INFO:tensorflow:global_step/sec: 61.7995
# INFO:tensorflow:loss = 0.167181, step = 32707 (1.619 sec)
# INFO:tensorflow:global_step/sec: 67.0282
# INFO:tensorflow:loss = 0.0950027, step = 32807 (1.491 sec)
# INFO:tensorflow:global_step/sec: 61.287
# INFO:tensorflow:loss = 0.091853, step = 32907 (1.631 sec)
# INFO:tensorflow:global_step/sec: 69.0114
# INFO:tensorflow:loss = 0.0914278, step = 33007 (1.449 sec)
# INFO:tensorflow:global_step/sec: 69.1819
# INFO:tensorflow:loss = 0.100931, step = 33107 (1.446 sec)
# INFO:tensorflow:global_step/sec: 66.9411
# INFO:tensorflow:loss = 0.0952016, step = 33207 (1.495 sec)
# INFO:tensorflow:global_step/sec: 63.6204
# INFO:tensorflow:loss = 0.0937562, step = 33307 (1.571 sec)
# INFO:tensorflow:global_step/sec: 64.3807
# INFO:tensorflow:loss = 0.107185, step = 33407 (1.554 sec)
# INFO:tensorflow:global_step/sec: 70.2817
# INFO:tensorflow:loss = 0.108274, step = 33507 (1.422 sec)
# INFO:tensorflow:global_step/sec: 69.6025
# INFO:tensorflow:loss = 0.122483, step = 33607 (1.437 sec)
# INFO:tensorflow:global_step/sec: 70.9757
# INFO:tensorflow:loss = 0.390027, step = 33707 (1.408 sec)
# INFO:tensorflow:global_step/sec: 66.7593
# INFO:tensorflow:loss = 0.119732, step = 33807 (1.498 sec)
# INFO:tensorflow:global_step/sec: 63.6373
# INFO:tensorflow:loss = 0.09656, step = 33907 (1.573 sec)
# INFO:tensorflow:global_step/sec: 61.6721
# INFO:tensorflow:loss = 0.0882629, step = 34007 (1.622 sec)
# INFO:tensorflow:global_step/sec: 65.0813
# INFO:tensorflow:loss = 0.102304, step = 34107 (1.535 sec)
# INFO:tensorflow:global_step/sec: 62.1465
# INFO:tensorflow:loss = 0.0936754, step = 34207 (1.609 sec)
# INFO:tensorflow:global_step/sec: 61.4972
# INFO:tensorflow:loss = 0.100197, step = 34307 (1.626 sec)
# INFO:tensorflow:global_step/sec: 68.895
# INFO:tensorflow:loss = 0.0860928, step = 34407 (1.451 sec)
# INFO:tensorflow:global_step/sec: 64.4968
# INFO:tensorflow:loss = 0.0931954, step = 34507 (1.553 sec)
# INFO:tensorflow:global_step/sec: 55.0585
# INFO:tensorflow:loss = 0.103765, step = 34607 (1.815 sec)
# INFO:tensorflow:global_step/sec: 65.8074
# INFO:tensorflow:loss = 0.0917576, step = 34707 (1.520 sec)
# INFO:tensorflow:global_step/sec: 72.015
# INFO:tensorflow:loss = 0.129319, step = 34807 (1.387 sec)
# INFO:tensorflow:global_step/sec: 71.4168
# INFO:tensorflow:loss = 0.152736, step = 34907 (1.401 sec)
# INFO:tensorflow:global_step/sec: 71.965
# INFO:tensorflow:loss = 0.147401, step = 35007 (1.390 sec)
# INFO:tensorflow:global_step/sec: 70.8594
# INFO:tensorflow:loss = 0.128485, step = 35107 (1.410 sec)
# INFO:tensorflow:global_step/sec: 68.0622
# INFO:tensorflow:loss = 0.0951259, step = 35207 (1.469 sec)
# INFO:tensorflow:global_step/sec: 70.6504
# INFO:tensorflow:loss = 0.0954272, step = 35307 (1.416 sec)
# INFO:tensorflow:global_step/sec: 79.4511
# INFO:tensorflow:loss = 0.109165, step = 35407 (1.258 sec)
# INFO:tensorflow:global_step/sec: 72.2559
# INFO:tensorflow:loss = 0.0900132, step = 35507 (1.386 sec)
# INFO:tensorflow:global_step/sec: 69.9884
# INFO:tensorflow:loss = 0.103801, step = 35607 (1.427 sec)
# INFO:tensorflow:global_step/sec: 68.2221
# INFO:tensorflow:loss = 0.090396, step = 35707 (1.467 sec)
# INFO:tensorflow:global_step/sec: 63.0192
# INFO:tensorflow:loss = 0.0892029, step = 35807 (1.588 sec)
# INFO:tensorflow:global_step/sec: 62.4908
# INFO:tensorflow:loss = 0.0855487, step = 35907 (1.599 sec)
# INFO:tensorflow:global_step/sec: 61.0926
# INFO:tensorflow:loss = 0.102542, step = 36007 (1.639 sec)
# INFO:tensorflow:global_step/sec: 57.1931
# INFO:tensorflow:loss = 0.093241, step = 36107 (1.748 sec)
# INFO:tensorflow:global_step/sec: 61.5123
# INFO:tensorflow:loss = 0.112569, step = 36207 (1.627 sec)
# INFO:tensorflow:global_step/sec: 59.7014
# INFO:tensorflow:loss = 0.117711, step = 36307 (1.674 sec)
# INFO:tensorflow:global_step/sec: 53.3643
# INFO:tensorflow:loss = 0.0889232, step = 36407 (1.875 sec)
# INFO:tensorflow:global_step/sec: 50.2579
# INFO:tensorflow:loss = 0.125588, step = 36507 (1.989 sec)
# INFO:tensorflow:global_step/sec: 54.2962
# INFO:tensorflow:loss = 0.0861978, step = 36607 (1.842 sec)
# INFO:tensorflow:global_step/sec: 56.3446
# INFO:tensorflow:loss = 0.0951984, step = 36707 (1.774 sec)
# INFO:tensorflow:global_step/sec: 62.6229
# INFO:tensorflow:loss = 0.103501, step = 36807 (1.595 sec)
# INFO:tensorflow:global_step/sec: 68.9408
# INFO:tensorflow:loss = 0.140321, step = 36907 (1.450 sec)
# INFO:tensorflow:global_step/sec: 70.5491
# INFO:tensorflow:loss = 0.122543, step = 37007 (1.417 sec)
# INFO:tensorflow:global_step/sec: 64.6269
# INFO:tensorflow:loss = 0.13876, step = 37107 (1.550 sec)
# INFO:tensorflow:global_step/sec: 67.4288
# INFO:tensorflow:loss = 0.231522, step = 37207 (1.481 sec)
# INFO:tensorflow:global_step/sec: 71.6581
# INFO:tensorflow:loss = 0.135303, step = 37307 (1.396 sec)
# INFO:tensorflow:global_step/sec: 68.3821
# INFO:tensorflow:loss = 0.124985, step = 37407 (1.462 sec)
# INFO:tensorflow:global_step/sec: 63.2706
# INFO:tensorflow:loss = 0.097107, step = 37507 (1.582 sec)
# INFO:tensorflow:global_step/sec: 57.065
# INFO:tensorflow:loss = 0.101412, step = 37607 (1.752 sec)
# INFO:tensorflow:global_step/sec: 60.2298
# INFO:tensorflow:loss = 0.0992903, step = 37707 (1.660 sec)
# INFO:tensorflow:global_step/sec: 58.6552
# INFO:tensorflow:loss = 0.111195, step = 37807 (1.705 sec)
# INFO:tensorflow:global_step/sec: 62.2082
# INFO:tensorflow:loss = 0.0916614, step = 37907 (1.606 sec)
# INFO:tensorflow:global_step/sec: 70.6831
# INFO:tensorflow:loss = 0.0886774, step = 38007 (1.415 sec)
# INFO:tensorflow:global_step/sec: 54.412
# INFO:tensorflow:loss = 0.0889635, step = 38107 (1.840 sec)
# INFO:tensorflow:global_step/sec: 65.6048
# INFO:tensorflow:loss = 0.102613, step = 38207 (1.521 sec)
# INFO:tensorflow:global_step/sec: 69.9846
# INFO:tensorflow:loss = 0.0889075, step = 38307 (1.429 sec)
# INFO:tensorflow:global_step/sec: 72.7944
# INFO:tensorflow:loss = 0.090398, step = 38407 (1.373 sec)
# INFO:tensorflow:global_step/sec: 69.845
# INFO:tensorflow:loss = 0.101877, step = 38507 (1.433 sec)
# INFO:tensorflow:global_step/sec: 68.2565
# INFO:tensorflow:loss = 0.0860198, step = 38607 (1.464 sec)
# INFO:tensorflow:global_step/sec: 70.6225
# INFO:tensorflow:loss = 0.0893166, step = 38707 (1.415 sec)
# INFO:tensorflow:global_step/sec: 72.3258
# INFO:tensorflow:loss = 0.0849831, step = 38807 (1.383 sec)
# INFO:tensorflow:global_step/sec: 70.9601
# INFO:tensorflow:loss = 0.147273, step = 38907 (1.411 sec)
# INFO:tensorflow:global_step/sec: 68.1094
# INFO:tensorflow:loss = 0.0918738, step = 39007 (1.467 sec)
# INFO:tensorflow:global_step/sec: 69.3169
# INFO:tensorflow:loss = 0.0905298, step = 39107 (1.443 sec)
# INFO:tensorflow:global_step/sec: 69.2484
# INFO:tensorflow:loss = 0.354843, step = 39207 (1.443 sec)
# INFO:tensorflow:global_step/sec: 68.5495
# INFO:tensorflow:loss = 0.0937665, step = 39307 (1.459 sec)
# INFO:tensorflow:global_step/sec: 68.6106
# INFO:tensorflow:loss = 0.0852904, step = 39407 (1.458 sec)
# INFO:tensorflow:global_step/sec: 64.1346
# INFO:tensorflow:loss = 0.146407, step = 39507 (1.558 sec)
# INFO:tensorflow:global_step/sec: 63.7334
# INFO:tensorflow:loss = 0.0979332, step = 39607 (1.571 sec)
# INFO:tensorflow:global_step/sec: 61.3595
# INFO:tensorflow:loss = 0.119328, step = 39707 (1.629 sec)
# INFO:tensorflow:global_step/sec: 68.6603
# INFO:tensorflow:loss = 0.111864, step = 39807 (1.456 sec)
# INFO:tensorflow:global_step/sec: 67.4671
# INFO:tensorflow:loss = 0.0948744, step = 39907 (1.481 sec)
# INFO:tensorflow:global_step/sec: 71.5915
# INFO:tensorflow:loss = 0.101733, step = 40007 (1.397 sec)
# INFO:tensorflow:global_step/sec: 69.148
# INFO:tensorflow:loss = 0.0984707, step = 40107 (1.446 sec)
# INFO:tensorflow:global_step/sec: 67.1429
# INFO:tensorflow:loss = 0.0896913, step = 40207 (1.490 sec)
# INFO:tensorflow:global_step/sec: 60.1121
# INFO:tensorflow:loss = 0.0873386, step = 40307 (1.662 sec)
# INFO:tensorflow:global_step/sec: 67.1372
# INFO:tensorflow:loss = 0.0919023, step = 40407 (1.490 sec)
# INFO:tensorflow:global_step/sec: 65.9005
# INFO:tensorflow:loss = 0.089865, step = 40507 (1.518 sec)
# INFO:tensorflow:global_step/sec: 56.8294
# INFO:tensorflow:loss = 0.109724, step = 40607 (1.760 sec)
# INFO:tensorflow:global_step/sec: 67.9237
# INFO:tensorflow:loss = 0.0932385, step = 40707 (1.471 sec)
# INFO:tensorflow:global_step/sec: 66.8155
# INFO:tensorflow:loss = 0.0895199, step = 40807 (1.497 sec)
# INFO:tensorflow:global_step/sec: 61.627
# INFO:tensorflow:loss = 0.0928513, step = 40907 (1.622 sec)
# INFO:tensorflow:global_step/sec: 69.1186
# INFO:tensorflow:loss = 0.100634, step = 41007 (1.446 sec)
# INFO:tensorflow:global_step/sec: 66.816
# INFO:tensorflow:loss = 0.0948818, step = 41107 (1.497 sec)
# INFO:tensorflow:global_step/sec: 66.6894
# INFO:tensorflow:loss = 0.0960813, step = 41207 (1.499 sec)
# INFO:tensorflow:global_step/sec: 68.6018
# INFO:tensorflow:loss = 0.0871315, step = 41307 (1.458 sec)
# INFO:tensorflow:global_step/sec: 70.4233
# INFO:tensorflow:loss = 0.0937586, step = 41407 (1.420 sec)
# INFO:tensorflow:global_step/sec: 67.4795
# INFO:tensorflow:loss = 0.0885613, step = 41507 (1.483 sec)
# INFO:tensorflow:global_step/sec: 66.4095
# INFO:tensorflow:loss = 0.151837, step = 41607 (1.505 sec)
# INFO:tensorflow:global_step/sec: 66.6389
# INFO:tensorflow:loss = 0.104997, step = 41707 (1.501 sec)
# INFO:tensorflow:global_step/sec: 65.6822
# INFO:tensorflow:loss = 0.0961117, step = 41807 (1.523 sec)
# INFO:tensorflow:global_step/sec: 67.0499
# INFO:tensorflow:loss = 0.0983595, step = 41907 (1.490 sec)
# INFO:tensorflow:global_step/sec: 64.042
# INFO:tensorflow:loss = 0.250572, step = 42007 (1.561 sec)
# INFO:tensorflow:global_step/sec: 61.539
# INFO:tensorflow:loss = 0.131857, step = 42107 (1.627 sec)
# INFO:tensorflow:global_step/sec: 65.8038
# INFO:tensorflow:loss = 0.0912244, step = 42207 (1.519 sec)
# INFO:tensorflow:global_step/sec: 62.9576
# INFO:tensorflow:loss = 0.093781, step = 42307 (1.587 sec)
# INFO:tensorflow:global_step/sec: 65.1246
# INFO:tensorflow:loss = 0.122435, step = 42407 (1.535 sec)
# INFO:tensorflow:global_step/sec: 69.6849
# INFO:tensorflow:loss = 0.0914017, step = 42507 (1.435 sec)
# INFO:tensorflow:global_step/sec: 71.4182
# INFO:tensorflow:loss = 0.121549, step = 42607 (1.401 sec)
# INFO:tensorflow:global_step/sec: 69.7677
# INFO:tensorflow:loss = 0.0931488, step = 42707 (1.432 sec)
# INFO:tensorflow:global_step/sec: 67.1235
# INFO:tensorflow:loss = 0.0993722, step = 42807 (1.490 sec)
# INFO:tensorflow:global_step/sec: 67.7152
# INFO:tensorflow:loss = 0.0853139, step = 42907 (1.478 sec)
# INFO:tensorflow:global_step/sec: 64.662
# INFO:tensorflow:loss = 0.0906394, step = 43007 (1.547 sec)
# INFO:tensorflow:global_step/sec: 62.6774
# INFO:tensorflow:loss = 0.130835, step = 43107 (1.594 sec)
# INFO:tensorflow:global_step/sec: 66.6474
# INFO:tensorflow:loss = 0.0961762, step = 43207 (1.501 sec)
# INFO:tensorflow:global_step/sec: 66.1815
# INFO:tensorflow:loss = 0.102627, step = 43307 (1.509 sec)
# INFO:tensorflow:global_step/sec: 73.024
# INFO:tensorflow:loss = 0.106839, step = 43407 (1.369 sec)
# INFO:tensorflow:global_step/sec: 69.7154
# INFO:tensorflow:loss = 0.0931067, step = 43507 (1.435 sec)
# INFO:tensorflow:global_step/sec: 66.5508
# INFO:tensorflow:loss = 0.0915351, step = 43607 (1.502 sec)
# INFO:tensorflow:global_step/sec: 69.0417
# INFO:tensorflow:loss = 0.0893, step = 43707 (1.450 sec)
# INFO:tensorflow:global_step/sec: 62.0547
# INFO:tensorflow:loss = 0.141475, step = 43807 (1.613 sec)
# INFO:tensorflow:global_step/sec: 69.6137
# INFO:tensorflow:loss = 0.1064, step = 43907 (1.435 sec)
# INFO:tensorflow:global_step/sec: 62.9689
# INFO:tensorflow:loss = 0.127866, step = 44007 (1.587 sec)
# INFO:tensorflow:global_step/sec: 69.1534
# INFO:tensorflow:loss = 0.0904511, step = 44107 (1.447 sec)
# INFO:tensorflow:global_step/sec: 62.3569
# INFO:tensorflow:loss = 0.0862751, step = 44207 (1.604 sec)
# INFO:tensorflow:global_step/sec: 69.1528
# INFO:tensorflow:loss = 0.0862283, step = 44307 (1.445 sec)
# INFO:tensorflow:global_step/sec: 70.3627
# INFO:tensorflow:loss = 0.0879249, step = 44407 (1.421 sec)
# INFO:tensorflow:global_step/sec: 70.2402
# INFO:tensorflow:loss = 0.13463, step = 44507 (1.425 sec)
# INFO:tensorflow:global_step/sec: 70.1964
# INFO:tensorflow:loss = 0.434858, step = 44607 (1.424 sec)
# INFO:tensorflow:global_step/sec: 71.2343
# INFO:tensorflow:loss = 0.11639, step = 44707 (1.403 sec)
# INFO:tensorflow:global_step/sec: 70.4429
# INFO:tensorflow:loss = 0.115523, step = 44807 (1.419 sec)
# INFO:tensorflow:global_step/sec: 73.9609
# INFO:tensorflow:loss = 0.145194, step = 44907 (1.352 sec)
# INFO:tensorflow:global_step/sec: 71.8565
# INFO:tensorflow:loss = 0.100305, step = 45007 (1.393 sec)
# INFO:tensorflow:global_step/sec: 69.7997
# INFO:tensorflow:loss = 0.0934098, step = 45107 (1.432 sec)
# INFO:tensorflow:global_step/sec: 65.3474
# INFO:tensorflow:loss = 0.112483, step = 45207 (1.530 sec)
# INFO:tensorflow:global_step/sec: 70.7563
# INFO:tensorflow:loss = 0.0999149, step = 45307 (1.413 sec)
# INFO:tensorflow:global_step/sec: 67.4412
# INFO:tensorflow:loss = 0.107309, step = 45407 (1.485 sec)
# INFO:tensorflow:global_step/sec: 60.6728
# INFO:tensorflow:loss = 0.0861677, step = 45507 (1.648 sec)
# INFO:tensorflow:global_step/sec: 56.993
# INFO:tensorflow:loss = 0.0944048, step = 45607 (1.756 sec)
# INFO:tensorflow:global_step/sec: 51.3743
# INFO:tensorflow:loss = 0.0927723, step = 45707 (1.946 sec)
# INFO:tensorflow:global_step/sec: 55.2747
# INFO:tensorflow:loss = 0.161229, step = 45807 (1.808 sec)
# INFO:tensorflow:global_step/sec: 64.4045
# INFO:tensorflow:loss = 0.0949272, step = 45907 (1.551 sec)
# INFO:tensorflow:global_step/sec: 68.212
# INFO:tensorflow:loss = 0.0956443, step = 46007 (1.468 sec)
# INFO:tensorflow:global_step/sec: 63.7709
# INFO:tensorflow:loss = 0.0998407, step = 46107 (1.567 sec)
# INFO:tensorflow:global_step/sec: 67.8445
# INFO:tensorflow:loss = 0.100112, step = 46207 (1.475 sec)
# INFO:tensorflow:global_step/sec: 71.0913
# INFO:tensorflow:loss = 0.0915795, step = 46307 (1.405 sec)
# INFO:tensorflow:global_step/sec: 63.6019
# INFO:tensorflow:loss = 0.107896, step = 46407 (1.572 sec)
# INFO:tensorflow:global_step/sec: 67.6876
# INFO:tensorflow:loss = 0.106382, step = 46507 (1.480 sec)
# INFO:tensorflow:global_step/sec: 65.0846
# INFO:tensorflow:loss = 0.0925406, step = 46607 (1.535 sec)
# INFO:tensorflow:global_step/sec: 72.65
# INFO:tensorflow:loss = 0.107479, step = 46707 (1.377 sec)
# INFO:tensorflow:global_step/sec: 74.1757
# INFO:tensorflow:loss = 0.153556, step = 46807 (1.347 sec)
# INFO:tensorflow:global_step/sec: 71.9672
# INFO:tensorflow:loss = 0.130548, step = 46907 (1.391 sec)
# INFO:tensorflow:global_step/sec: 68.5466
# INFO:tensorflow:loss = 0.2158, step = 47007 (1.458 sec)
# INFO:tensorflow:global_step/sec: 66.9885
# INFO:tensorflow:loss = 0.087882, step = 47107 (1.493 sec)
# INFO:tensorflow:global_step/sec: 69.7183
# INFO:tensorflow:loss = 0.117568, step = 47207 (1.434 sec)
# INFO:tensorflow:global_step/sec: 70.6564
# INFO:tensorflow:loss = 0.088159, step = 47307 (1.414 sec)
# INFO:tensorflow:global_step/sec: 70.0677
# INFO:tensorflow:loss = 0.102637, step = 47407 (1.427 sec)
# INFO:tensorflow:global_step/sec: 68.5645
# INFO:tensorflow:loss = 0.0968557, step = 47507 (1.458 sec)
# INFO:tensorflow:global_step/sec: 68.4842
# ...
# INFO:tensorflow:global_step/sec: 70.8939
# INFO:tensorflow:loss = 0.157327, step = 80919 (1.410 sec)
# INFO:tensorflow:global_step/sec: 63.5012
# INFO:tensorflow:loss = 0.0953487, step = 81019 (1.576 sec)
# INFO:tensorflow:global_step/sec: 65.5663
# INFO:tensorflow:loss = 0.087736, step = 81119 (1.524 sec)
# INFO:tensorflow:global_step/sec: 69.1492
# INFO:tensorflow:loss = 0.090086, step = 81219 (1.448 sec)
# INFO:tensorflow:global_step/sec: 66.9819
# INFO:tensorflow:loss = 0.100764, step = 81319 (1.491 sec)
# INFO:tensorflow:global_step/sec: 71.2857
# INFO:tensorflow:loss = 0.0989997, step = 81419 (1.402 sec)
# INFO:tensorflow:global_step/sec: 72.6901
# INFO:tensorflow:loss = 0.0927463, step = 81519 (1.376 sec)
# INFO:tensorflow:global_step/sec: 70.3409
# INFO:tensorflow:loss = 0.110258, step = 81619 (1.423 sec)
# INFO:tensorflow:global_step/sec: 67.4829
# INFO:tensorflow:loss = 0.0989423, step = 81719 (1.482 sec)
# INFO:tensorflow:global_step/sec: 60.7027
# INFO:tensorflow:loss = 0.10376, step = 81819 (1.648 sec)
# INFO:tensorflow:global_step/sec: 66.0644
# INFO:tensorflow:loss = 0.400996, step = 81919 (1.512 sec)
# INFO:tensorflow:global_step/sec: 68.7023
# INFO:tensorflow:loss = 0.125653, step = 82019 (1.456 sec)
# INFO:tensorflow:global_step/sec: 66.5131
# INFO:tensorflow:loss = 0.095372, step = 82119 (1.503 sec)
# INFO:tensorflow:global_step/sec: 67.5857
# INFO:tensorflow:loss = 0.0881327, step = 82219 (1.480 sec)
# INFO:tensorflow:global_step/sec: 68.3895
# INFO:tensorflow:loss = 0.101661, step = 82319 (1.462 sec)
# INFO:tensorflow:global_step/sec: 66.1084
# INFO:tensorflow:loss = 0.0979985, step = 82419 (1.514 sec)
# INFO:tensorflow:global_step/sec: 66.6139
# INFO:tensorflow:loss = 0.0979818, step = 82519 (1.502 sec)
# INFO:tensorflow:global_step/sec: 65.6542
# INFO:tensorflow:loss = 0.0838407, step = 82619 (1.522 sec)
# INFO:tensorflow:global_step/sec: 67.9254
# INFO:tensorflow:loss = 0.0904091, step = 82719 (1.472 sec)
# INFO:tensorflow:global_step/sec: 69.156
# INFO:tensorflow:loss = 0.104263, step = 82819 (1.446 sec)
# INFO:tensorflow:global_step/sec: 65.2419
# INFO:tensorflow:loss = 0.0886631, step = 82919 (1.535 sec)
# INFO:tensorflow:global_step/sec: 65.8765
# INFO:tensorflow:loss = 0.127988, step = 83019 (1.516 sec)
# INFO:tensorflow:global_step/sec: 68.5572
# INFO:tensorflow:loss = 0.142553, step = 83119 (1.459 sec)
# INFO:tensorflow:global_step/sec: 68.7934
# INFO:tensorflow:loss = 0.169774, step = 83219 (1.454 sec)
# INFO:tensorflow:global_step/sec: 72.0287
# INFO:tensorflow:loss = 0.140524, step = 83319 (1.388 sec)
# INFO:tensorflow:global_step/sec: 66.5415
# INFO:tensorflow:loss = 0.0979901, step = 83419 (1.503 sec)
# INFO:tensorflow:global_step/sec: 68.9983
# INFO:tensorflow:loss = 0.0932998, step = 83519 (1.449 sec)
# INFO:tensorflow:global_step/sec: 70.5649
# INFO:tensorflow:loss = 0.109507, step = 83619 (1.417 sec)
# INFO:tensorflow:global_step/sec: 70.0893
# INFO:tensorflow:loss = 0.090062, step = 83719 (1.427 sec)
# INFO:tensorflow:global_step/sec: 65.7813
# INFO:tensorflow:loss = 0.102266, step = 83819 (1.520 sec)
# INFO:tensorflow:global_step/sec: 67.2436
# INFO:tensorflow:loss = 0.0886676, step = 83919 (1.489 sec)
# INFO:tensorflow:global_step/sec: 59.0459
# INFO:tensorflow:loss = 0.0878484, step = 84019 (1.694 sec)
# INFO:tensorflow:global_step/sec: 57.7921
# INFO:tensorflow:loss = 0.0861897, step = 84119 (1.731 sec)
# INFO:tensorflow:global_step/sec: 57.908
# INFO:tensorflow:loss = 0.102235, step = 84219 (1.726 sec)
# INFO:tensorflow:global_step/sec: 55.9974
# INFO:tensorflow:loss = 0.0891524, step = 84319 (1.785 sec)
# INFO:tensorflow:global_step/sec: 56.5243
# INFO:tensorflow:loss = 0.108186, step = 84419 (1.770 sec)
# INFO:tensorflow:global_step/sec: 58.4184
# INFO:tensorflow:loss = 0.120565, step = 84519 (1.711 sec)
# INFO:tensorflow:global_step/sec: 58.38
# INFO:tensorflow:loss = 0.0890448, step = 84619 (1.712 sec)
# INFO:tensorflow:global_step/sec: 63.9591
# INFO:tensorflow:loss = 0.126943, step = 84719 (1.566 sec)
# INFO:tensorflow:global_step/sec: 56.3752
# INFO:tensorflow:loss = 0.085327, step = 84819 (1.772 sec)
# INFO:tensorflow:global_step/sec: 59.2215
# INFO:tensorflow:loss = 0.092485, step = 84919 (1.689 sec)
# INFO:tensorflow:global_step/sec: 57.4982
# INFO:tensorflow:loss = 0.105837, step = 85019 (1.740 sec)
# INFO:tensorflow:global_step/sec: 58.0685
# INFO:tensorflow:loss = 0.115865, step = 85119 (1.723 sec)
# INFO:tensorflow:global_step/sec: 57.9537
# INFO:tensorflow:loss = 0.109918, step = 85219 (1.725 sec)
# INFO:tensorflow:global_step/sec: 56.9055
# INFO:tensorflow:loss = 0.132285, step = 85319 (1.757 sec)
# INFO:tensorflow:global_step/sec: 58.4313
# INFO:tensorflow:loss = 0.209953, step = 85419 (1.712 sec)
# INFO:tensorflow:global_step/sec: 59.462
# INFO:tensorflow:loss = 0.129967, step = 85519 (1.682 sec)
# INFO:tensorflow:global_step/sec: 64.3999
# INFO:tensorflow:loss = 0.115423, step = 85619 (1.552 sec)
# INFO:tensorflow:global_step/sec: 65.7885
# INFO:tensorflow:loss = 0.0947091, step = 85719 (1.519 sec)
# INFO:tensorflow:global_step/sec: 68.3907
# INFO:tensorflow:loss = 0.0975183, step = 85819 (1.462 sec)
# INFO:tensorflow:global_step/sec: 69.2493
# INFO:tensorflow:loss = 0.0927808, step = 85919 (1.445 sec)
# INFO:tensorflow:global_step/sec: 71.078
# INFO:tensorflow:loss = 0.106361, step = 86019 (1.405 sec)
# INFO:tensorflow:global_step/sec: 69.7164
# INFO:tensorflow:loss = 0.0909208, step = 86119 (1.435 sec)
# INFO:tensorflow:global_step/sec: 61.8259
# INFO:tensorflow:loss = 0.0862806, step = 86219 (1.619 sec)
# INFO:tensorflow:global_step/sec: 68.3386
# INFO:tensorflow:loss = 0.0885044, step = 86319 (1.461 sec)
# INFO:tensorflow:global_step/sec: 64.1076
# INFO:tensorflow:loss = 0.103906, step = 86419 (1.561 sec)
# INFO:tensorflow:global_step/sec: 68.3402
# INFO:tensorflow:loss = 0.090148, step = 86519 (1.462 sec)
# INFO:tensorflow:global_step/sec: 65.3783
# INFO:tensorflow:loss = 0.0889102, step = 86619 (1.529 sec)
# INFO:tensorflow:global_step/sec: 66.633
# INFO:tensorflow:loss = 0.100009, step = 86719 (1.501 sec)
# INFO:tensorflow:global_step/sec: 63.0553
# INFO:tensorflow:loss = 0.0855254, step = 86819 (1.585 sec)
# INFO:tensorflow:global_step/sec: 66.693
# INFO:tensorflow:loss = 0.0876344, step = 86919 (1.499 sec)
# INFO:tensorflow:global_step/sec: 69.0182
# INFO:tensorflow:loss = 0.0837274, step = 87019 (1.449 sec)
# INFO:tensorflow:global_step/sec: 69.8671
# INFO:tensorflow:loss = 0.154009, step = 87119 (1.431 sec)
# INFO:tensorflow:global_step/sec: 69.7824
# INFO:tensorflow:loss = 0.0921498, step = 87219 (1.433 sec)
# INFO:tensorflow:global_step/sec: 68.1628
# INFO:tensorflow:loss = 0.0902093, step = 87319 (1.467 sec)
# INFO:tensorflow:global_step/sec: 68.5402
# INFO:tensorflow:loss = 0.361819, step = 87419 (1.459 sec)
# INFO:tensorflow:global_step/sec: 68.8316
# INFO:tensorflow:loss = 0.0958508, step = 87519 (1.453 sec)
# INFO:tensorflow:global_step/sec: 67.8685
# INFO:tensorflow:loss = 0.0850429, step = 87619 (1.473 sec)
# INFO:tensorflow:global_step/sec: 69.0804
# INFO:tensorflow:loss = 0.148484, step = 87719 (1.448 sec)
# INFO:tensorflow:global_step/sec: 68.3834
# INFO:tensorflow:loss = 0.0971833, step = 87819 (1.463 sec)
# INFO:tensorflow:global_step/sec: 65.4896
# INFO:tensorflow:loss = 0.120488, step = 87919 (1.528 sec)
# INFO:tensorflow:global_step/sec: 63.3288
# INFO:tensorflow:loss = 0.115225, step = 88019 (1.580 sec)
# INFO:tensorflow:global_step/sec: 68.8677
# INFO:tensorflow:loss = 0.0921089, step = 88119 (1.450 sec)
# INFO:tensorflow:global_step/sec: 69.3838
# INFO:tensorflow:loss = 0.100078, step = 88219 (1.442 sec)
# INFO:tensorflow:global_step/sec: 68.6517
# INFO:tensorflow:loss = 0.101191, step = 88319 (1.457 sec)
# INFO:tensorflow:global_step/sec: 67.5522
# INFO:tensorflow:loss = 0.0892286, step = 88419 (1.480 sec)
# INFO:tensorflow:global_step/sec: 67.2319
# INFO:tensorflow:loss = 0.0864118, step = 88519 (1.488 sec)
# INFO:tensorflow:global_step/sec: 64.103
# INFO:tensorflow:loss = 0.0905638, step = 88619 (1.560 sec)
# INFO:tensorflow:global_step/sec: 62.9872
# INFO:tensorflow:loss = 0.0888634, step = 88719 (1.586 sec)
# INFO:tensorflow:global_step/sec: 67.1958
# INFO:tensorflow:loss = 0.112259, step = 88819 (1.489 sec)
# INFO:tensorflow:global_step/sec: 64.4701
# INFO:tensorflow:loss = 0.0928883, step = 88919 (1.551 sec)
# INFO:tensorflow:global_step/sec: 59.2592
# INFO:tensorflow:loss = 0.0880541, step = 89019 (1.689 sec)
# INFO:tensorflow:global_step/sec: 65.017
# INFO:tensorflow:loss = 0.0935747, step = 89119 (1.536 sec)
# INFO:tensorflow:global_step/sec: 62.3077
# INFO:tensorflow:loss = 0.0989972, step = 89219 (1.605 sec)
# INFO:tensorflow:global_step/sec: 67.078
# INFO:tensorflow:loss = 0.0962449, step = 89319 (1.493 sec)
# INFO:tensorflow:global_step/sec: 68.1937
# INFO:tensorflow:loss = 0.0911696, step = 89419 (1.465 sec)
# INFO:tensorflow:global_step/sec: 66.0295
# INFO:tensorflow:loss = 0.085607, step = 89519 (1.513 sec)
# INFO:tensorflow:global_step/sec: 57.9822
# INFO:tensorflow:loss = 0.0925982, step = 89619 (1.726 sec)
# INFO:tensorflow:global_step/sec: 62.4238
# INFO:tensorflow:loss = 0.0875162, step = 89719 (1.601 sec)
# INFO:tensorflow:global_step/sec: 61.5051
# INFO:tensorflow:loss = 0.15195, step = 89819 (1.627 sec)
# INFO:tensorflow:global_step/sec: 65.3629
# INFO:tensorflow:loss = 0.103635, step = 89919 (1.530 sec)
# INFO:tensorflow:global_step/sec: 65.991
# INFO:tensorflow:loss = 0.0945552, step = 90019 (1.515 sec)
# INFO:tensorflow:global_step/sec: 58.3786
# INFO:tensorflow:loss = 0.0972305, step = 90119 (1.713 sec)
# INFO:tensorflow:global_step/sec: 60.4445
# INFO:tensorflow:loss = 0.251826, step = 90219 (1.653 sec)
# INFO:tensorflow:global_step/sec: 62.0896
# INFO:tensorflow:loss = 0.122108, step = 90319 (1.611 sec)
# INFO:tensorflow:global_step/sec: 64.11
# INFO:tensorflow:loss = 0.0903818, step = 90419 (1.561 sec)
# INFO:tensorflow:global_step/sec: 63.8273
# INFO:tensorflow:loss = 0.0939273, step = 90519 (1.565 sec)
# INFO:tensorflow:global_step/sec: 62.6928
# INFO:tensorflow:loss = 0.116041, step = 90619 (1.596 sec)
# INFO:tensorflow:global_step/sec: 65.587
# INFO:tensorflow:loss = 0.0911732, step = 90719 (1.523 sec)
# INFO:tensorflow:global_step/sec: 67.5685
# INFO:tensorflow:loss = 0.12485, step = 90819 (1.481 sec)
# INFO:tensorflow:global_step/sec: 66.4469
# INFO:tensorflow:loss = 0.0911166, step = 90919 (1.505 sec)
# INFO:tensorflow:global_step/sec: 65.7
# INFO:tensorflow:loss = 0.0935281, step = 91019 (1.522 sec)
# INFO:tensorflow:global_step/sec: 64.7903
# INFO:tensorflow:loss = 0.0841873, step = 91119 (1.544 sec)
# INFO:tensorflow:global_step/sec: 59.9541
# INFO:tensorflow:loss = 0.0906454, step = 91219 (1.668 sec)
# INFO:tensorflow:global_step/sec: 63.3114
# INFO:tensorflow:loss = 0.128258, step = 91319 (1.579 sec)
# INFO:tensorflow:global_step/sec: 64.835
# INFO:tensorflow:loss = 0.0915324, step = 91419 (1.542 sec)
# INFO:tensorflow:global_step/sec: 66.6182
# INFO:tensorflow:loss = 0.10155, step = 91519 (1.501 sec)
# INFO:tensorflow:global_step/sec: 64.4915
# INFO:tensorflow:loss = 0.103101, step = 91619 (1.551 sec)
# INFO:tensorflow:global_step/sec: 61.9414
# INFO:tensorflow:loss = 0.0948661, step = 91719 (1.616 sec)
# INFO:tensorflow:global_step/sec: 61.0091
# INFO:tensorflow:loss = 0.0956358, step = 91819 (1.638 sec)
# INFO:tensorflow:global_step/sec: 59.4807
# INFO:tensorflow:loss = 0.0854608, step = 91919 (1.680 sec)
# INFO:tensorflow:global_step/sec: 60.2126
# INFO:tensorflow:loss = 0.1339, step = 92019 (1.662 sec)
# INFO:tensorflow:global_step/sec: 67.8927
# INFO:tensorflow:loss = 0.104875, step = 92119 (1.471 sec)
# INFO:tensorflow:global_step/sec: 74.4848
# INFO:tensorflow:loss = 0.111109, step = 92219 (1.342 sec)
# INFO:tensorflow:global_step/sec: 74.8804
# INFO:tensorflow:loss = 0.0899134, step = 92319 (1.336 sec)
# INFO:tensorflow:global_step/sec: 76.277
# INFO:tensorflow:loss = 0.086751, step = 92419 (1.311 sec)
# INFO:tensorflow:global_step/sec: 75.6054
# INFO:tensorflow:loss = 0.0860547, step = 92519 (1.323 sec)
# INFO:tensorflow:global_step/sec: 75.5928
# INFO:tensorflow:loss = 0.0872427, step = 92619 (1.323 sec)
# INFO:tensorflow:global_step/sec: 74.498
# INFO:tensorflow:loss = 0.125721, step = 92719 (1.343 sec)
# INFO:tensorflow:global_step/sec: 76.0829
# INFO:tensorflow:loss = 0.408765, step = 92819 (1.314 sec)
# INFO:tensorflow:global_step/sec: 76.4982
# INFO:tensorflow:loss = 0.112831, step = 92919 (1.307 sec)
# INFO:tensorflow:global_step/sec: 76.1894
# INFO:tensorflow:loss = 0.119296, step = 93019 (1.312 sec)
# INFO:tensorflow:global_step/sec: 76.9936
# INFO:tensorflow:loss = 0.142208, step = 93119 (1.299 sec)
# INFO:tensorflow:global_step/sec: 77.9478
# INFO:tensorflow:loss = 0.0958338, step = 93219 (1.283 sec)
# INFO:tensorflow:global_step/sec: 77.704
# INFO:tensorflow:loss = 0.0916121, step = 93319 (1.287 sec)
# INFO:tensorflow:global_step/sec: 78.1406
# INFO:tensorflow:loss = 0.116041, step = 93419 (1.280 sec)
# INFO:tensorflow:global_step/sec: 77.0471
# INFO:tensorflow:loss = 0.0995984, step = 93519 (1.298 sec)
# INFO:tensorflow:global_step/sec: 76.4064
# INFO:tensorflow:loss = 0.108161, step = 93619 (1.309 sec)
# INFO:tensorflow:global_step/sec: 76.3228
# INFO:tensorflow:loss = 0.0840055, step = 93719 (1.310 sec)
# INFO:tensorflow:global_step/sec: 75.4453
# INFO:tensorflow:loss = 0.0930945, step = 93819 (1.326 sec)
# INFO:tensorflow:global_step/sec: 75.3171
# INFO:tensorflow:loss = 0.0918766, step = 93919 (1.327 sec)
# INFO:tensorflow:global_step/sec: 74.7539
# INFO:tensorflow:loss = 0.121569, step = 94019 (1.338 sec)
# INFO:tensorflow:global_step/sec: 76.1447
# INFO:tensorflow:loss = 0.0930112, step = 94119 (1.313 sec)
# INFO:tensorflow:global_step/sec: 76.1797
# INFO:tensorflow:loss = 0.0944979, step = 94219 (1.313 sec)
# INFO:tensorflow:global_step/sec: 75.079
# INFO:tensorflow:loss = 0.0990224, step = 94319 (1.332 sec)
# INFO:tensorflow:global_step/sec: 75.4943
# INFO:tensorflow:loss = 0.100158, step = 94419 (1.325 sec)
# INFO:tensorflow:global_step/sec: 74.1246
# INFO:tensorflow:loss = 0.0899023, step = 94519 (1.349 sec)
# INFO:tensorflow:global_step/sec: 74.511
# INFO:tensorflow:loss = 0.108681, step = 94619 (1.342 sec)
# INFO:tensorflow:global_step/sec: 70.0952
# INFO:tensorflow:loss = 0.106914, step = 94719 (1.427 sec)
# INFO:tensorflow:global_step/sec: 76.2495
# INFO:tensorflow:loss = 0.0920499, step = 94819 (1.311 sec)
# INFO:tensorflow:global_step/sec: 78.3706
# INFO:tensorflow:loss = 0.111814, step = 94919 (1.276 sec)
# INFO:tensorflow:global_step/sec: 77.5643
# INFO:tensorflow:loss = 0.135539, step = 95019 (1.289 sec)
# INFO:tensorflow:global_step/sec: 74.9799
# INFO:tensorflow:loss = 0.127174, step = 95119 (1.336 sec)
# INFO:tensorflow:global_step/sec: 70.5054
# INFO:tensorflow:loss = 0.216199, step = 95219 (1.417 sec)
# INFO:tensorflow:global_step/sec: 63.9793
# INFO:tensorflow:loss = 0.0870832, step = 95319 (1.564 sec)
# INFO:tensorflow:global_step/sec: 60.4773
# INFO:tensorflow:loss = 0.116371, step = 95419 (1.655 sec)
# INFO:tensorflow:global_step/sec: 52.332
# INFO:tensorflow:loss = 0.0866908, step = 95519 (1.911 sec)
# INFO:tensorflow:global_step/sec: 55.0471
# INFO:tensorflow:loss = 0.101373, step = 95619 (1.816 sec)
# INFO:tensorflow:global_step/sec: 55.3476
# INFO:tensorflow:loss = 0.0975211, step = 95719 (1.806 sec)
# INFO:tensorflow:global_step/sec: 59.7523
# INFO:tensorflow:loss = 0.0919406, step = 95819 (1.675 sec)
# INFO:tensorflow:global_step/sec: 52.0099
# INFO:tensorflow:loss = 0.1205, step = 95919 (1.923 sec)
# INFO:tensorflow:global_step/sec: 55.3967
# INFO:tensorflow:loss = 0.0858895, step = 96019 (1.805 sec)
# INFO:tensorflow:global_step/sec: 54.526
# INFO:tensorflow:loss = 0.109701, step = 96119 (1.833 sec)
# INFO:tensorflow:global_step/sec: 52.5208
# INFO:tensorflow:loss = 0.0959367, step = 96219 (1.904 sec)
# INFO:tensorflow:global_step/sec: 54.8667
# INFO:tensorflow:loss = 0.0930905, step = 96319 (1.824 sec)
# INFO:tensorflow:global_step/sec: 55.1429
# INFO:tensorflow:loss = 0.0856693, step = 96419 (1.813 sec)
# INFO:tensorflow:Saving checkpoints for 96424 into /tmp/tf_bow_sst_20180327-2137/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0973532.
# INFO:tensorflow:Starting evaluation at 2018-03-27-22:02:49
# INFO:tensorflow:Restoring parameters from /tmp/tf_bow_sst_20180327-2137/model.ckpt-96424
# INFO:tensorflow:Finished evaluation at 2018-03-27-22:03:02
# INFO:tensorflow:Saving dict for global step 96424: accuracy = 0.936785, cross_entropy_loss = 0.220313, global_step = 96424, loss = 0.338722

# %% [markdown]
# ### Testing
#
# Note -- many test examples contain explicit content

# %%
test_sents = [("ass and titties", KID_INAPPROPRIATE),
("fuck the police", KID_INAPPROPRIATE),
("cats are nice", KID_APPROPRIATE),
("one day I saw a horse on a hill and I liked it", KID_APPROPRIATE),
("mrs. tayler is a whore", KID_INAPPROPRIATE),
("I'd like to take you someplace nice and quiet", KID_INAPPROPRIATE),
("You gay ? Proceeds to chase him that's how bullying works", KID_INAPPROPRIATE),
("transfer responsibility dad temperature earn voter impossible radiation.", KID_APPROPRIATE),
("JADE CHYNOWETH AND JOSH KILLACKY LOVETEAM PLS", KID_APPROPRIATE),
("Lol, looks like the same generic crap you come to expect from these types of shows.  Guess it doesn't get old for some people.", KID_INAPPROPRIATE),
("Disney sold the rights to this?", KID_APPROPRIATE),
("Only step up 1 and 2 were good. All of the other ones have just been corny.", KID_APPROPRIATE),
("i rather not call it step up, its another level with different camera techniques and its so Channing Tatum style", KID_APPROPRIATE),
("I love the series its very good, im waiting for 2 one", KID_APPROPRIATE),
("GREAT", KID_APPROPRIATE),
("Job negotiate set alternative little introduction apparent crazy proper used care free.", KID_APPROPRIATE),
("Oxygen identify member dependent translate else card might handful.", KID_APPROPRIATE),
("Release accompany pole general something widely fly cup detective personnel.", KID_APPROPRIATE),
("Silly largely obstacle warrior charge flavor diabetes medal.", KID_APPROPRIATE),
("We need moose back", KID_APPROPRIATE),
("Exciting time to be alive bro watching our Prez Trump vs. the DeepState/Swamp that's the deal profs to him.", KID_APPROPRIATE),
("Idk if I want to watch it or not : ^/", KID_APPROPRIATE),
("Maximum testing blanket absolutely shock until actress sex liability.", KID_INAPPROPRIATE),
("3 was the best.", KID_APPROPRIATE),
("I knew they would have a all men gay dance group", KID_INAPPROPRIATE),
("Same old garbage; I'm sick of it !", KID_APPROPRIATE),
("GAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAYYYYYYYYYYYYYYYYYYYYYYYYY",KID_INAPPROPRIATE),
("Millenials = The worst generation",KID_APPROPRIATE),
("that opening statement is the most overused sentence i've seen",KID_APPROPRIATE),
("Pan spokesman via guard campaign characteristic movement expert attend garage.",KID_APPROPRIATE),
("ayyy https://youtu.be/wZwyQZDfyHY",KID_APPROPRIATE),
("WELP....the end of the step up franchise met a very disappointing end. Jesus this looks worse than most dumpster fires Ive seen",KID_APPROPRIATE),
("blacks that look white and wiggas.  yeah, looks great. (not!)",KID_INAPPROPRIATE),
("Rich And Diverse artistry- Advocating White Genocide. How is enrichment going on in South Africa?",KID_INAPPROPRIATE),
("step up <3",KID_APPROPRIATE),
("When is episode 5 coming out",KID_APPROPRIATE),
("This series is actually pretty good...watched it and was so happy I gave it a shot; I loved it! The storyline is actually stronger than I expected, and especially where they left off this first season, I'm so excited for what's to come; I hope they keep up the good work and produce even more (authentic stuff next season.",KID_APPROPRIATE),
("https://vk.com/club162181675 вступайте",KID_APPROPRIATE),
("lunch argument across expansion free govern healthy afternoon.",KID_APPROPRIATE),
("Modern day version of Fame!",KID_APPROPRIATE),
("Neyo!",KID_APPROPRIATE),
("I wasn't expecting this from YouTube but it's really good",KID_APPROPRIATE),
("The",KID_APPROPRIATE),
("what garbage i this want to be step up is more like stomp the yard",KID_APPROPRIATE),
("if you're actually thinking of watching this show... do it. i recommend it. it's so much more than what we ever got to see from step up or any dance movies at all. so much diversity & so many topics it's talking about. i was surprised at how much i actually enjoyed the show & how bad i need a (second season. just give it a try since the first 4 episodes are for free on here, i don't think y'all are gonna regret it",KID_APPROPRIATE),
("Aren’t u guys releasing more seasons and episodes??? we still need more of ‘em",KID_APPROPRIATE),
("Have Chris brown in the step up movies it’ll be dope",KID_APPROPRIATE),
("http://hikmatblogs.blogspot.com/2018/02/10-ways-to-improve-your-finances-today.html",KID_APPROPRIATE),
("No Moose no Step Up",KID_APPROPRIATE),
("Let me guess?? Suburban girl trying to prove her gangsta and most of the black men are gay.... WHACK!!!",KID_INAPPROPRIATE),
("What, no moose cameo ?",KID_APPROPRIATE),
("trash.",KID_APPROPRIATE),
("Why does everything have to be so gay  won't be watching this sick of all our black men in tv series being gay smh",KID_INAPPROPRIATE),
("Who's that girl on the trailer cover?",KID_APPROPRIATE),
("Atlanta is a n!66er filled cesspool.. i can't figure out why parents stopped teaching their children white from wrong.. why today's youth wants grey babies.. why ruin family pictures with those half n!66e kinky haired flat nosed kids..  why these fathers aren't teaching their daughters to stay off the chimpdicks.. i mean, for real, how low does your self esteem have to be to want to share your beautiful young white body with these savage nigloyds... i'm sorry your fathers have failed you girls.. I taught mine white from wrong.. my grandkids will be bright white with blonde hair and blue eyes.. not gray with kinky rugs and flat noses.. just the idea of beautiful young white girls with sweaty, greasy n!66ers up on them just makes me wanna puke.. parents.. it's time to start teaching some basic family values again.. not the kardashian kind where they just keep getting impregnated by stray chimps.. it's just disgusting... let's clean up and keep the white blood lines free from contaminants..  you young white girls... just say no.. find a decent white boy to make babies with.. you can't tell me that a n!66er is all you can get..  well, maybe the fat ugly girls.. but even you can do better.. find a fat ugly white guy..  give him that poontang .. not these foot stomping, drum banging monkeys .. talentless rappers...  all wanna pretend they are in the music business.. rap isn't music.. any tar baby can get a drum machine and call it a beat lab.. then they steal a macbook from a white girl.. and start their career as the white girl's baby daddy.. she says he's a musician.. but he's really just another worthless n166er  he will keep her on welfare.. just a waste.. february is black history month.. the other 11 is caucasian (history months.. we will celebrate by taking our women back..",KID_INAPPROPRIATE),
("i run them streetsXD",KID_APPROPRIATE),
("my answer is....hell noXD",KID_APPROPRIATE),
("Sail star diamond rate working love pond size that monument prevention celebrate.",KID_APPROPRIATE),
("So is Kevin Bacon they're Jesus or something?",KID_APPROPRIATE),
("Can someone please give me the name of the girl on the thumbnail please ?????",KID_APPROPRIATE),
("I would rather be prison raped than watch 5seconds of this garbage",KID_INAPPROPRIATE),
("Prosecution tool before endless visit dump shake sake remarkable hurt safe public.",KID_APPROPRIATE),
("total grief slave esyvbp question fourth fun basic fly sacrifice reply.",KID_INAPPROPRIATE),
("As she named the Empress, Anna Pávlovna’s face suddenly assumed an expression of profound and sincere devotion and respect mingled with sadness, and this occurred every time she mentioned her illustrious patroness. ", KID_INAPPROPRIATE),
("She added that Her Majesty had deigned to show Baron Funke beaucoup d’estime, and again her face clouded over with sadness.", KID_INAPPROPRIATE),
("The prince was silent and looked indifferent. ", KID_APPROPRIATE),
("But, with the womanly and courtierlike quickness and tact habitual to her, Anna Pávlovna wished both to rebuke him (for daring to speak as he had done of a ma ", KID_INAPPROPRIATE),
("recommended to the Empress) and at the same time to console him, so she said ", KID_INAPPROPRIATE)]

# %%
test_tokens = [tokenizer.tokenize(x[0]) for x in test_sents]

test_tokens_canonical = [utils.canonicalize_words(x) for x in test_tokens]

test_ids = [vocab.words_to_ids(x) for x in test_tokens_canonical]

test_x, test_ns, test_y = [],[],[]

for i,x in enumerate(test_ids):

    padded, orig_len = pad_array(x,pad_len)

    test_x.append(padded)
    test_ns.append(orig_len)
    test_y.append(test_sents[i][1])

test_x_np = np.array(test_x)
test_ns_np = np.array(test_ns)
test_y_np = np.array(test_y)

# %%
test_input_fn = tf.estimator.inputs.numpy_input_fn(
                    x={"ids": test_x_np, "ns": test_ns_np}, y=test_y_np,
                    batch_size=128, num_epochs=1, shuffle=False
                )

eval_metrics = model.evaluate(input_fn=test_input_fn, name="eval")

#### END(YOUR CODE) ####
print("Accuracy on test set: {:.02%}".format(eval_metrics['accuracy']))
eval_metrics
# Out:
# INFO:tensorflow:Starting evaluation at 2018-03-27-22:03:03
# INFO:tensorflow:Restoring parameters from /tmp/tf_bow_sst_20180327-2137/model.ckpt-96424
# INFO:tensorflow:Finished evaluation at 2018-03-27-22:03:03
# INFO:tensorflow:Saving dict for global step 96424: accuracy = 0.411765, cross_entropy_loss = 2.22641, global_step = 96424, loss = 2.31485
# Accuracy on test set: 41.18%
# {'accuracy': 0.41176471,
#  'cross_entropy_loss': 2.2264147,
#  'global_step': 96424,
#  'loss': 2.3148451}

# %%
from sklearn.metrics import accuracy_score
predictions = list(model.predict(test_input_fn))  # list of dicts
y_pred = [p['max'] for p in predictions]
acc = accuracy_score(y_pred, test_y)
print("Accuracy on test set: {:.02%}".format(acc))
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/tf_bow_sst_20180327-2137/model.ckpt-96424
# Accuracy on test set: 41.18%

# %% [markdown]
# ### Error Analysis

# %%
param_names = {KID_APPROPRIATE:   "Appropriate  ",
               KID_INAPPROPRIATE: "Inappropriate"}
template = "Sentence  :   {}\nPredicted :   {} \nActual    :   {}  \n\n" 
for i, example in enumerate(y_pred):
    print(template.format(test_sents[i][0], param_names[y_pred[i]], param_names[test_sents[i][1]]))
# Out:
# Sentence  :   ass and titties
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   fuck the police
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   cats are nice
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   one day I saw a horse on a hill and I liked it
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   mrs. tayler is a whore
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   I'd like to take you someplace nice and quiet
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   You gay ? Proceeds to chase him that's how bullying works
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   transfer responsibility dad temperature earn voter impossible radiation.
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   JADE CHYNOWETH AND JOSH KILLACKY LOVETEAM PLS
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Lol, looks like the same generic crap you come to expect from these types of shows.  Guess it doesn't get old for some people.
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   Disney sold the rights to this?
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Only step up 1 and 2 were good. All of the other ones have just been corny.
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   i rather not call it step up, its another level with different camera techniques and its so Channing Tatum style
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   I love the series its very good, im waiting for 2 one
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   GREAT
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Job negotiate set alternative little introduction apparent crazy proper used care free.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Oxygen identify member dependent translate else card might handful.
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Release accompany pole general something widely fly cup detective personnel.
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Silly largely obstacle warrior charge flavor diabetes medal.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   We need moose back
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Exciting time to be alive bro watching our Prez Trump vs. the DeepState/Swamp that's the deal profs to him.
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Idk if I want to watch it or not : ^/
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Maximum testing blanket absolutely shock until actress sex liability.
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   3 was the best.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   I knew they would have a all men gay dance group
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   Same old garbage; I'm sick of it !
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   GAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAYYYYYYYYYYYYYYYYYYYYYYYYY
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   Millenials = The worst generation
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   that opening statement is the most overused sentence i've seen
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Pan spokesman via guard campaign characteristic movement expert attend garage.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   ayyy https://youtu.be/wZwyQZDfyHY
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   WELP....the end of the step up franchise met a very disappointing end. Jesus this looks worse than most dumpster fires Ive seen
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   blacks that look white and wiggas.  yeah, looks great. (not!)
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   Rich And Diverse artistry- Advocating White Genocide. How is enrichment going on in South Africa?
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   step up <3
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   When is episode 5 coming out
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   This series is actually pretty good...watched it and was so happy I gave it a shot; I loved it! The storyline is actually stronger than I expected, and especially where they left off this first season, I'm so excited for what's to come; I hope they keep up the good work and produce even more (authentic stuff next season.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   https://vk.com/club162181675 вступайте
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   lunch argument across expansion free govern healthy afternoon.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Modern day version of Fame!
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Neyo!
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   I wasn't expecting this from YouTube but it's really good
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   The
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   what garbage i this want to be step up is more like stomp the yard
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   if you're actually thinking of watching this show... do it. i recommend it. it's so much more than what we ever got to see from step up or any dance movies at all. so much diversity & so many topics it's talking about. i was surprised at how much i actually enjoyed the show & how bad i need a (second season. just give it a try since the first 4 episodes are for free on here, i don't think y'all are gonna regret it
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Aren’t u guys releasing more seasons and episodes??? we still need more of ‘em
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Have Chris brown in the step up movies it’ll be dope
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   http://hikmatblogs.blogspot.com/2018/02/10-ways-to-improve-your-finances-today.html
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   No Moose no Step Up
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Let me guess?? Suburban girl trying to prove her gangsta and most of the black men are gay.... WHACK!!!
# Predicted :   Appropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   What, no moose cameo ?
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   trash.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Why does everything have to be so gay  won't be watching this sick of all our black men in tv series being gay smh
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   Who's that girl on the trailer cover?
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Atlanta is a n!66er filled cesspool.. i can't figure out why parents stopped teaching their children white from wrong.. why today's youth wants grey babies.. why ruin family pictures with those half n!66e kinky haired flat nosed kids..  why these fathers aren't teaching their daughters to stay off the chimpdicks.. i mean, for real, how low does your self esteem have to be to want to share your beautiful young white body with these savage nigloyds... i'm sorry your fathers have failed you girls.. I taught mine white from wrong.. my grandkids will be bright white with blonde hair and blue eyes.. not gray with kinky rugs and flat noses.. just the idea of beautiful young white girls with sweaty, greasy n!66ers up on them just makes me wanna puke.. parents.. it's time to start teaching some basic family values again.. not the kardashian kind where they just keep getting impregnated by stray chimps.. it's just disgusting... let's clean up and keep the white blood lines free from contaminants..  you young white girls... just say no.. find a decent white boy to make babies with.. you can't tell me that a n!66er is all you can get..  well, maybe the fat ugly girls.. but even you can do better.. find a fat ugly white guy..  give him that poontang .. not these foot stomping, drum banging monkeys .. talentless rappers...  all wanna pretend they are in the music business.. rap isn't music.. any tar baby can get a drum machine and call it a beat lab.. then they steal a macbook from a white girl.. and start their career as the white girl's baby daddy.. she says he's a musician.. but he's really just another worthless n166er  he will keep her on welfare.. just a waste.. february is black history month.. the other 11 is caucasian (history months.. we will celebrate by taking our women back..
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   i run them streetsXD
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   my answer is....hell noXD
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Sail star diamond rate working love pond size that monument prevention celebrate.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   So is Kevin Bacon they're Jesus or something?
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Can someone please give me the name of the girl on the thumbnail please ?????
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   I would rather be prison raped than watch 5seconds of this garbage
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   Prosecution tool before endless visit dump shake sake remarkable hurt safe public.
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   total grief slave esyvbp question fourth fun basic fly sacrifice reply.
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   As she named the Empress, Anna Pávlovna’s face suddenly assumed an expression of profound and sincere devotion and respect mingled with sadness, and this occurred every time she mentioned her illustrious patroness.
# Predicted :   Appropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   She added that Her Majesty had deigned to show Baron Funke beaucoup d’estime, and again her face clouded over with sadness.
# Predicted :   Appropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   The prince was silent and looked indifferent.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   But, with the womanly and courtierlike quickness and tact habitual to her, Anna Pávlovna wished both to rebuke him (for daring to speak as he had done of a ma
# Predicted :   Appropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   recommended to the Empress) and at the same time to console him, so she said
# Predicted :   Appropriate
# Actual    :   Inappropriate

# %% [markdown]
# #### Error Notes
# -  Are long sentences incorrectly categorized?
# -  Misses innuendo (but innuendo is rare)
# -  Frequently fails random words, but that's probably ok
# -  We're training sentences against (potentially) multi-sentence comments. Is that ok?
# -  Would sentiment analysis help?
# -  Would another embedding help?
# -  Would readability scores help?
# -  Worth pursuing a hybrid sensitivity/complexity model, then combine at classification-time?
#
# #### Eng Notes
# - How can we improve speed?
# - How can we improve accuracy?
# - Would adding wikipedia set help?
# - How to adjust hyperparams
# - How to deal with memory issues
