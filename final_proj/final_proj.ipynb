# %%
from __future__ import print_function
from __future__ import division
from importlib import reload

from nltk.tokenize.treebank import TreebankWordTokenizer
import collections
import nltk
import numpy as np
import glob
import math

import pandas as pd
import tensorflow as tf
import os, sys, re, json, time, datetime, shutil

# Helper libraries
from w266_common import utils, vocabulary
from w266_common import patched_numpy_io
# Out:
# /home/peterg/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# ### Constants

# %%
KID_APPROPRIATE = 1
KID_INAPPROPRIATE = 0

# %% [markdown]
# ### Grab Data

# %%
book_files = glob.glob('/home/peterg/2018-spring-main/assignment/final_proj/books/*.txt')
fourchan_files = glob.glob('/home/peterg/2018-spring-main/assignment/final_proj/4chan/*.txt')

# %%
pos_examples, neg_examples = [], []

# positive (appropriate for kids) examples come from 
# the children's bookshelf of project Gutenberg
for book in book_files[:60]:
    with open(book, "r") as pos_file:
        for line in pos_file:
            pos_examples.append(line)

# negative (inapprorpiate for kids) training examples come
# from the "shit 4chan says" board on 4chan.org
single_4chan_file = ["/home/peterg/2018-spring-main/assignment/final_proj/4chan/4chan_s4s.txt",]
for board in single_4chan_file:
    with open(board, 'r') as neg_file:
        for line in neg_file:
            neg_examples.append(line)

print(len(pos_examples), len(neg_examples))
# Out:
# 154277 2760399

# %% [markdown]
# ### Tokenization

# %%
tokenizer = TreebankWordTokenizer()

# the number of positive and negative examples to pull for training
num_sents = 250000

pos_tokens = [tokenizer.tokenize(x) for x in pos_examples[:num_sents]]
neg_tokens = [tokenizer.tokenize(x) for x in neg_examples[:num_sents]]

# %%
print(pos_examples[:5])
print(neg_examples[:5])
# Out:
# ['      THE SONG OF HIAWATHA       Henry W. Longfellow CONTENTS Introductory Note Introduction I.\n', 'The Peace-Pipe II.\n', 'The Four Winds III.\n', "Hiawatha's Childhood IV.\n", "Hiawatha and Mudjekeewis V.    Hiawatha's Fasting VI.\n"]
# ["'I only browse on iphone\n", " (check your desktop privilege) How do I create memes on mobile? Does anyone know of an app that is similar to ms paint? Any basic art app that is free and good?'\n", "'( ͡° ͜ʖ ͡°)'\n", "'epin; simply ebin'\n", "'shit not again'\n"]

# %% [markdown]
# ### Canonicalization

# %%
pos_tokens_canonical = [utils.canonicalize_words(x) for x in pos_tokens]
neg_tokens_canonical = [utils.canonicalize_words(x) for x in neg_tokens]

# %% [markdown]
# ### Generate Vocabulary

# %%
all_tokens_canonical = pos_tokens_canonical + neg_tokens_canonical

all_tokens_flattened = [] 
for sublist in all_tokens_canonical:
    for item in sublist:
        all_tokens_flattened.append(item)

vocab = vocabulary.Vocabulary(all_tokens_flattened, size=70000)  # size=None means unlimited
print("Vocabulary size: {:,}".format(vocab.size))


# print("Vocabulary dict: ", vocab.word_to_id)
# x_ids = vocab.words_to_ids(all_tokens_flattened)
# print("x_ids =", x_ids)
# x_tokens_recovered = vocab.ids_to_words(x_ids)
# x_tokens_recovered
# Out:
# Vocabulary size: 70,000

# %% [markdown]
# ### Generate training set

# %%
def pad_array(array, pad_len):
    length = len(array)
    if length <= pad_len:
        delta = pad_len - length
        for i in range(delta):
            array.append(0)
            
        return array, length
    if length > pad_len:
        return array[:pad_len], length

# %%
pos_ids = [vocab.words_to_ids(x) for x in pos_tokens_canonical]
neg_ids = [vocab.words_to_ids(x) for x in neg_tokens_canonical]

train_x, train_ns, train_y = [], [], []

pad_len = 40

train_frac = 0.5
dev_frac = 0.2

# train_frac + dev_frac must be <= 1
assert(train_frac + dev_frac <= 1.0)

num_sents = math.floor(len(pos_ids) * train_frac)
num_dev_sents = math.floor(len(pos_ids) * dev_frac)

# add one positive and one negative example
for i in range(num_sents):
    if i % 10000 == 0:
        print("Done with", i)
    padded, orig_len = pad_array(pos_ids[i],pad_len)
    train_x.append(padded)
    train_ns.append(orig_len)
    train_y.append(KID_APPROPRIATE)
    
    padded, orig_len = pad_array(neg_ids[i],pad_len)
    train_x.append(padded)
    train_ns.append(orig_len)
    train_y.append(KID_INAPPROPRIATE)
    
    
dev_x, dev_ns, dev_y = [], [], []

# take dev examples from the back half of the array
for i in range(num_dev_sents):
    if i % 10000 == 0:
        print("Done with", i)
    padded, orig_len = pad_array(pos_ids[-i],pad_len)
    dev_x.append(padded)
    dev_ns.append(orig_len)
    dev_y.append(KID_APPROPRIATE)
    
    padded, orig_len = pad_array(neg_ids[-i],pad_len)
    dev_x.append(padded)
    dev_ns.append(orig_len)
    dev_y.append(KID_INAPPROPRIATE)

# print(train_x[:3])
# print(vocab.ids_to_words(train_x[1]))
# print(train_ns[:3])
# print(train_y[:3])

batches = len(train_x)
max_len = pad_len
# Out:
# Done with 0
# Done with 10000
# Done with 20000
# Done with 30000
# Done with 40000
# Done with 50000
# Done with 60000
# Done with 70000
# Done with 0
# Done with 10000
# Done with 20000
# Done with 30000

# %%
train_x_np = np.array(train_x)
train_ns_np = np.array(train_ns)
train_y_np = np.array(train_y)

dev_x_np = np.array(dev_x)
dev_ns_np = np.array(dev_ns)
dev_y_np = np.array(dev_y)

# %%
import models; reload(models)
x, ns, y = train_x_np, train_ns_np, train_y_np
batch_size = 32


# Specify model hyperparameters as used by model_fn
model_params = dict(V=vocab.size, embed_dim=90, hidden_dims=[50,25], num_classes=2,
                    encoder_type='bow',
                    lr=0.1, optimizer='adagrad', beta=0.01)
model_fn = models.classifier_model_fn

total_batches = 0
total_examples = 0
total_loss = 0
loss_ema = np.log(2)  # track exponential-moving-average of loss
ema_decay = np.exp(-1/10)  # decay parameter for moving average = np.exp(-1/history_length)
with tf.Graph().as_default(), tf.Session() as sess:
    ##
    # Construct the graph here. No session.run calls - just wiring up Tensors.
    ##
    # Add placeholders so we can feed in data.
    x_ph_  = tf.placeholder(tf.int32, shape=[None, x.shape[1]])  # [batch_size, max_len]
    ns_ph_ = tf.placeholder(tf.int32, shape=[None])              # [batch_size]
    y_ph_  = tf.placeholder(tf.int32, shape=[None])              # [batch_size]
    
    # Construct the graph using model_fn
    features = {"ids": x_ph_, "ns": ns_ph_}  # note that values are Tensors
    estimator_spec = model_fn(features, labels=y_ph_, mode=tf.estimator.ModeKeys.TRAIN,
                              params=model_params)
    loss_     = estimator_spec.loss
    train_op_ = estimator_spec.train_op
    
    ##
    # Done constructing the graph, now we can make session.run calls.
    ##
    sess.run(tf.global_variables_initializer())
    
    # Run a single epoch
    t0 = time.time()
    for (bx, bns, by) in utils.multi_batch_generator(batch_size, x, ns, y):
        # feed NumPy arrays into the placeholder Tensors
        feed_dict = {x_ph_: bx, ns_ph_: bns, y_ph_: by}
        batch_loss, _ = sess.run([loss_, train_op_], feed_dict=feed_dict)
        
        # Compute some statistics
        total_batches += 1
        total_examples += len(bx)
        total_loss += batch_loss * len(bx)  # re-scale, since batch loss is mean
        # Compute moving average to smooth out noisy per-batch loss
        loss_ema = ema_decay * loss_ema + (1 - ema_decay) * batch_loss
        
        if (total_batches % 25 == 0):
            print("{:5,} examples, moving-average loss {:.2f}".format(total_examples, 
                                                                      loss_ema))    
    print("Completed one epoch in {:s}".format(utils.pretty_timedelta(since=t0)))
# Out:
#   800 examples, moving-average loss 1.18
# 1,600 examples, moving-average loss 0.83
# 2,400 examples, moving-average loss 0.80
# 3,200 examples, moving-average loss 0.70
# 4,000 examples, moving-average loss 0.74
# 4,800 examples, moving-average loss 0.58
# 5,600 examples, moving-average loss 0.52
# 6,400 examples, moving-average loss 0.51
# 7,200 examples, moving-average loss 0.42
# 8,000 examples, moving-average loss 0.37
# 8,800 examples, moving-average loss 0.35
# 9,600 examples, moving-average loss 0.33
# 10,400 examples, moving-average loss 0.33
# 11,200 examples, moving-average loss 0.35
# 12,000 examples, moving-average loss 0.28
# 12,800 examples, moving-average loss 0.34
# 13,600 examples, moving-average loss 0.33
# 14,400 examples, moving-average loss 0.25
# 15,200 examples, moving-average loss 0.27
# 16,000 examples, moving-average loss 0.21
# 16,800 examples, moving-average loss 0.22
# 17,600 examples, moving-average loss 0.21
# 18,400 examples, moving-average loss 0.19
# 19,200 examples, moving-average loss 0.19
# 20,000 examples, moving-average loss 0.19
# 20,800 examples, moving-average loss 0.18
# 21,600 examples, moving-average loss 0.20
# 22,400 examples, moving-average loss 0.22
# 23,200 examples, moving-average loss 0.18
# 24,000 examples, moving-average loss 0.17
# 24,800 examples, moving-average loss 0.29
# 25,600 examples, moving-average loss 0.24
# 26,400 examples, moving-average loss 0.19
# 27,200 examples, moving-average loss 0.22
# 28,000 examples, moving-average loss 0.17
# 28,800 examples, moving-average loss 0.16
# 29,600 examples, moving-average loss 0.15
# 30,400 examples, moving-average loss 0.16
# 31,200 examples, moving-average loss 0.17
# 32,000 examples, moving-average loss 0.20
# 32,800 examples, moving-average loss 0.18
# 33,600 examples, moving-average loss 0.18
# 34,400 examples, moving-average loss 0.19
# 35,200 examples, moving-average loss 0.20
# 36,000 examples, moving-average loss 0.21
# 36,800 examples, moving-average loss 0.14
# 37,600 examples, moving-average loss 0.15
# 38,400 examples, moving-average loss 0.15
# 39,200 examples, moving-average loss 0.16
# 40,000 examples, moving-average loss 0.13
# 40,800 examples, moving-average loss 0.14
# 41,600 examples, moving-average loss 0.22
# 42,400 examples, moving-average loss 0.17
# 43,200 examples, moving-average loss 0.15
# 44,000 examples, moving-average loss 0.16
# 44,800 examples, moving-average loss 0.16
# 45,600 examples, moving-average loss 0.16
# 46,400 examples, moving-average loss 0.19
# 47,200 examples, moving-average loss 0.19
# 48,000 examples, moving-average loss 0.22
# 48,800 examples, moving-average loss 0.18
# 49,600 examples, moving-average loss 0.15
# 50,400 examples, moving-average loss 0.23
# 51,200 examples, moving-average loss 0.16
# 52,000 examples, moving-average loss 0.15
# 52,800 examples, moving-average loss 0.13
# 53,600 examples, moving-average loss 0.14
# 54,400 examples, moving-average loss 0.13
# 55,200 examples, moving-average loss 0.15
# 56,000 examples, moving-average loss 0.15
# 56,800 examples, moving-average loss 0.13
# 57,600 examples, moving-average loss 0.13
# 58,400 examples, moving-average loss 0.14
# 59,200 examples, moving-average loss 0.17
# 60,000 examples, moving-average loss 0.20
# 60,800 examples, moving-average loss 0.18
# 61,600 examples, moving-average loss 0.18
# 62,400 examples, moving-average loss 0.16
# 63,200 examples, moving-average loss 0.20
# 64,000 examples, moving-average loss 0.19
# 64,800 examples, moving-average loss 0.17
# 65,600 examples, moving-average loss 0.21
# 66,400 examples, moving-average loss 0.23
# 67,200 examples, moving-average loss 0.26
# 68,000 examples, moving-average loss 0.27
# 68,800 examples, moving-average loss 0.23
# 69,600 examples, moving-average loss 0.22
# 70,400 examples, moving-average loss 0.20
# 71,200 examples, moving-average loss 0.19
# 72,000 examples, moving-average loss 0.15
# 72,800 examples, moving-average loss 0.19
# 73,600 examples, moving-average loss 0.17
# 74,400 examples, moving-average loss 0.17
# 75,200 examples, moving-average loss 0.15
# 76,000 examples, moving-average loss 0.13
# 76,800 examples, moving-average loss 0.19
# 77,600 examples, moving-average loss 0.17
# 78,400 examples, moving-average loss 0.16
# 79,200 examples, moving-average loss 0.15
# 80,000 examples, moving-average loss 0.13
# 80,800 examples, moving-average loss 0.13
# 81,600 examples, moving-average loss 0.14
# 82,400 examples, moving-average loss 0.14
# 83,200 examples, moving-average loss 0.14
# 84,000 examples, moving-average loss 0.15
# 84,800 examples, moving-average loss 0.16
# 85,600 examples, moving-average loss 0.12
# 86,400 examples, moving-average loss 0.15
# 87,200 examples, moving-average loss 0.13
# 88,000 examples, moving-average loss 0.16
# 88,800 examples, moving-average loss 0.14
# 89,600 examples, moving-average loss 0.19
# 90,400 examples, moving-average loss 0.15
# 91,200 examples, moving-average loss 0.17
# 92,000 examples, moving-average loss 0.16
# 92,800 examples, moving-average loss 0.14
# 93,600 examples, moving-average loss 0.13
# 94,400 examples, moving-average loss 0.11
# 95,200 examples, moving-average loss 0.12
# 96,000 examples, moving-average loss 0.13
# 96,800 examples, moving-average loss 0.15
# 97,600 examples, moving-average loss 0.13
# 98,400 examples, moving-average loss 0.14
# 99,200 examples, moving-average loss 0.14
# 100,000 examples, moving-average loss 0.13
# 100,800 examples, moving-average loss 0.16
# 101,600 examples, moving-average loss 0.14
# 102,400 examples, moving-average loss 0.14
# 103,200 examples, moving-average loss 0.13
# 104,000 examples, moving-average loss 0.12
# 104,800 examples, moving-average loss 0.12
# 105,600 examples, moving-average loss 0.19
# 106,400 examples, moving-average loss 0.17
# 107,200 examples, moving-average loss 0.17
# 108,000 examples, moving-average loss 0.15
# 108,800 examples, moving-average loss 0.15
# 109,600 examples, moving-average loss 0.13
# 110,400 examples, moving-average loss 0.16
# 111,200 examples, moving-average loss 0.16
# 112,000 examples, moving-average loss 0.13
# 112,800 examples, moving-average loss 0.13
# 113,600 examples, moving-average loss 0.15
# 114,400 examples, moving-average loss 0.13
# 115,200 examples, moving-average loss 0.12
# 116,000 examples, moving-average loss 0.23
# 116,800 examples, moving-average loss 0.16
# 117,600 examples, moving-average loss 0.17
# 118,400 examples, moving-average loss 0.15
# 119,200 examples, moving-average loss 0.15
# 120,000 examples, moving-average loss 0.12
# 120,800 examples, moving-average loss 0.12
# 121,600 examples, moving-average loss 0.22
# 122,400 examples, moving-average loss 0.16
# 123,200 examples, moving-average loss 0.16
# 124,000 examples, moving-average loss 0.13
# 124,800 examples, moving-average loss 0.12
# 125,600 examples, moving-average loss 0.14
# 126,400 examples, moving-average loss 0.14
# 127,200 examples, moving-average loss 0.15
# 128,000 examples, moving-average loss 0.14
# 128,800 examples, moving-average loss 0.12
# 129,600 examples, moving-average loss 0.16
# 130,400 examples, moving-average loss 0.15
# 131,200 examples, moving-average loss 0.15
# 132,000 examples, moving-average loss 0.14
# 132,800 examples, moving-average loss 0.13
# 133,600 examples, moving-average loss 0.16
# 134,400 examples, moving-average loss 0.13
# 135,200 examples, moving-average loss 0.17
# 136,000 examples, moving-average loss 0.13
# 136,800 examples, moving-average loss 0.13
# 137,600 examples, moving-average loss 0.14
# 138,400 examples, moving-average loss 0.12
# 139,200 examples, moving-average loss 0.16
# 140,000 examples, moving-average loss 0.22
# 140,800 examples, moving-average loss 0.19
# 141,600 examples, moving-average loss 0.19
# 142,400 examples, moving-average loss 0.20
# 143,200 examples, moving-average loss 0.18
# 144,000 examples, moving-average loss 0.19
# 144,800 examples, moving-average loss 0.22
# 145,600 examples, moving-average loss 0.20
# 146,400 examples, moving-average loss 0.21
# 147,200 examples, moving-average loss 0.19
# 148,000 examples, moving-average loss 0.13
# 148,800 examples, moving-average loss 0.15
# 149,600 examples, moving-average loss 0.14
# 150,400 examples, moving-average loss 0.26
# 151,200 examples, moving-average loss 0.19
# 152,000 examples, moving-average loss 0.18
# 152,800 examples, moving-average loss 0.15
# 153,600 examples, moving-average loss 0.20
# Completed one epoch in 0:01:15

# %%
import models; reload(models)

# Specify model hyperparameters as used by model_fn
model_params = dict(V=vocab.size, embed_dim=50, hidden_dims=[25], num_classes=2,
                    encoder_type='bow',
                    lr=0.1, optimizer='adagrad', beta=0.01)

checkpoint_dir = "/tmp/tf_bow_sst_" + datetime.datetime.now().strftime("%Y%m%d-%H%M")
if os.path.isdir(checkpoint_dir):
    shutil.rmtree(checkpoint_dir)
# Write vocabulary to file, so TensorBoard can label embeddings.
# creates checkpoint_dir/projector_config.pbtxt and checkpoint_dir/metadata.tsv
vocab.write_projector_config(checkpoint_dir, "Encoder/Embedding_Layer/W_embed")

model = tf.estimator.Estimator(model_fn=models.classifier_model_fn, 
                               params=model_params,
                               model_dir=checkpoint_dir)
print("")
print("To view training (once it starts), run:\n")
print("    tensorboard --logdir='{:s}' --port 6006".format(checkpoint_dir))
print("\nThen in your browser, open: http://localhost:6006")
# Out:
# Vocabulary (70,000 words) written to '/tmp/tf_bow_sst_20180325-2308/metadata.tsv'
# Projector config written to /tmp/tf_bow_sst_20180325-2308/projector_config.pbtxt
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tf_bow_sst_20180325-2308', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f84563771d0>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
#
# To view training (once it starts), run:
#
#     tensorboard --logdir='/tmp/tf_bow_sst_20180325-2308' --port 6006
#
# Then in your browser, open: http://localhost:6006

# %% [markdown]
# ### Training

# %%
# Training params, just used in this cell for the input_fn-s
train_params = dict(batch_size=32, total_epochs=20, eval_every=5)
assert(train_params['total_epochs'] % train_params['eval_every'] == 0)

# Construct and train the model, saving checkpoints to the directory above.
# Input function for training set batches
# Do 'eval_every' epochs at once, followed by evaluating on the dev set.
# NOTE: use patch_numpy_io.numpy_input_fn instead of tf.estimator.inputs.numpy_input_fn
train_input_fn = patched_numpy_io.numpy_input_fn(
                    x={"ids": train_x_np, "ns": train_ns_np}, y=train_y_np,
                    batch_size=train_params['batch_size'], 
                    num_epochs=train_params['eval_every'], shuffle=True, seed=42
                 )

# %%
# Input function for dev set batches. As above, but:
# - Don't randomize order
# - Iterate exactly once (one epoch)
dev_input_fn = tf.estimator.inputs.numpy_input_fn(
                    x={"ids": dev_x_np, "ns": dev_ns_np}, y=dev_y_np,
                    batch_size=128, num_epochs=1, shuffle=False
                )

for _ in range(train_params['total_epochs'] // train_params['eval_every']):
    # Train for a few epochs, then evaluate on dev
    model.train(input_fn=train_input_fn)
    eval_metrics = model.evaluate(input_fn=dev_input_fn, name="dev")
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tf_bow_sst_20180325-2308/model.ckpt.
# INFO:tensorflow:loss = 1.1038, step = 1
# INFO:tensorflow:global_step/sec: 103.007
# INFO:tensorflow:loss = 0.335523, step = 101 (0.974 sec)
# INFO:tensorflow:global_step/sec: 109.335
# INFO:tensorflow:loss = 0.22625, step = 201 (0.915 sec)
# INFO:tensorflow:global_step/sec: 87.3874
# INFO:tensorflow:loss = 0.184236, step = 301 (1.144 sec)
# INFO:tensorflow:global_step/sec: 109.8
# INFO:tensorflow:loss = 0.224307, step = 401 (0.911 sec)
# INFO:tensorflow:global_step/sec: 110.94
# INFO:tensorflow:loss = 0.193221, step = 501 (0.901 sec)
# INFO:tensorflow:global_step/sec: 109.885
# INFO:tensorflow:loss = 0.175772, step = 601 (0.910 sec)
# INFO:tensorflow:global_step/sec: 105.916
# INFO:tensorflow:loss = 0.474021, step = 701 (0.944 sec)
# INFO:tensorflow:global_step/sec: 106.723
# INFO:tensorflow:loss = 0.180785, step = 801 (0.937 sec)
# INFO:tensorflow:global_step/sec: 107.678
# INFO:tensorflow:loss = 0.156312, step = 901 (0.928 sec)
# INFO:tensorflow:global_step/sec: 105.827
# INFO:tensorflow:loss = 0.364384, step = 1001 (0.945 sec)
# INFO:tensorflow:global_step/sec: 108.239
# INFO:tensorflow:loss = 0.359577, step = 1101 (0.924 sec)
# INFO:tensorflow:global_step/sec: 110.285
# INFO:tensorflow:loss = 0.561228, step = 1201 (0.907 sec)
# INFO:tensorflow:global_step/sec: 108.413
# INFO:tensorflow:loss = 0.300432, step = 1301 (0.923 sec)
# INFO:tensorflow:global_step/sec: 106.774
# INFO:tensorflow:loss = 0.201895, step = 1401 (0.937 sec)
# INFO:tensorflow:global_step/sec: 108.804
# INFO:tensorflow:loss = 0.175602, step = 1501 (0.918 sec)
# INFO:tensorflow:global_step/sec: 111.36
# INFO:tensorflow:loss = 0.20966, step = 1601 (0.898 sec)
# INFO:tensorflow:global_step/sec: 108.718
# INFO:tensorflow:loss = 0.214276, step = 1701 (0.920 sec)
# INFO:tensorflow:global_step/sec: 107.99
# INFO:tensorflow:loss = 0.11579, step = 1801 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.508
# INFO:tensorflow:loss = 0.311081, step = 1901 (0.930 sec)
# INFO:tensorflow:global_step/sec: 110.545
# INFO:tensorflow:loss = 0.115639, step = 2001 (0.905 sec)
# INFO:tensorflow:global_step/sec: 110.692
# INFO:tensorflow:loss = 0.454308, step = 2101 (0.903 sec)
# INFO:tensorflow:global_step/sec: 109.338
# INFO:tensorflow:loss = 0.15512, step = 2201 (0.915 sec)
# INFO:tensorflow:global_step/sec: 109.488
# INFO:tensorflow:loss = 0.139613, step = 2301 (0.913 sec)
# INFO:tensorflow:global_step/sec: 111.244
# INFO:tensorflow:loss = 0.157779, step = 2401 (0.899 sec)
# INFO:tensorflow:global_step/sec: 109.17
# INFO:tensorflow:loss = 0.132053, step = 2501 (0.917 sec)
# INFO:tensorflow:global_step/sec: 99.911
# INFO:tensorflow:loss = 0.238341, step = 2601 (1.000 sec)
# INFO:tensorflow:global_step/sec: 107.417
# INFO:tensorflow:loss = 0.200813, step = 2701 (0.931 sec)
# INFO:tensorflow:global_step/sec: 112.001
# INFO:tensorflow:loss = 0.19295, step = 2801 (0.893 sec)
# INFO:tensorflow:global_step/sec: 110.046
# INFO:tensorflow:loss = 0.132459, step = 2901 (0.909 sec)
# INFO:tensorflow:global_step/sec: 105.48
# INFO:tensorflow:loss = 0.199984, step = 3001 (0.948 sec)
# INFO:tensorflow:global_step/sec: 112.436
# INFO:tensorflow:loss = 0.141028, step = 3101 (0.889 sec)
# INFO:tensorflow:global_step/sec: 111.375
# INFO:tensorflow:loss = 0.13158, step = 3201 (0.898 sec)
# INFO:tensorflow:global_step/sec: 109.863
# INFO:tensorflow:loss = 0.165051, step = 3301 (0.910 sec)
# INFO:tensorflow:global_step/sec: 107.58
# INFO:tensorflow:loss = 0.14453, step = 3401 (0.930 sec)
# INFO:tensorflow:global_step/sec: 105.359
# INFO:tensorflow:loss = 0.179921, step = 3501 (0.949 sec)
# INFO:tensorflow:global_step/sec: 112.566
# INFO:tensorflow:loss = 0.465944, step = 3601 (0.888 sec)
# INFO:tensorflow:global_step/sec: 110.808
# INFO:tensorflow:loss = 0.20966, step = 3701 (0.903 sec)
# INFO:tensorflow:global_step/sec: 109.739
# INFO:tensorflow:loss = 0.14264, step = 3801 (0.911 sec)
# INFO:tensorflow:global_step/sec: 111.63
# INFO:tensorflow:loss = 0.118502, step = 3901 (0.896 sec)
# INFO:tensorflow:global_step/sec: 108.297
# INFO:tensorflow:loss = 0.233106, step = 4001 (0.925 sec)
# INFO:tensorflow:global_step/sec: 98.5533
# INFO:tensorflow:loss = 0.122718, step = 4101 (1.014 sec)
# INFO:tensorflow:global_step/sec: 97.2533
# INFO:tensorflow:loss = 0.140925, step = 4201 (1.029 sec)
# INFO:tensorflow:global_step/sec: 96.0463
# INFO:tensorflow:loss = 0.1388, step = 4301 (1.040 sec)
# INFO:tensorflow:global_step/sec: 99.5673
# INFO:tensorflow:loss = 0.105696, step = 4401 (1.005 sec)
# INFO:tensorflow:global_step/sec: 98.7515
# INFO:tensorflow:loss = 0.10677, step = 4501 (1.013 sec)
# INFO:tensorflow:global_step/sec: 91.121
# INFO:tensorflow:loss = 0.113535, step = 4601 (1.099 sec)
# INFO:tensorflow:global_step/sec: 95.9654
# INFO:tensorflow:loss = 0.14024, step = 4701 (1.040 sec)
# INFO:tensorflow:global_step/sec: 99.6079
# INFO:tensorflow:loss = 0.167121, step = 4801 (1.005 sec)
# INFO:tensorflow:global_step/sec: 91.6262
# INFO:tensorflow:loss = 0.124903, step = 4901 (1.091 sec)
# INFO:tensorflow:global_step/sec: 96.0893
# INFO:tensorflow:loss = 0.445351, step = 5001 (1.041 sec)
# INFO:tensorflow:global_step/sec: 97.9147
# INFO:tensorflow:loss = 0.152875, step = 5101 (1.022 sec)
# INFO:tensorflow:global_step/sec: 96.7441
# INFO:tensorflow:loss = 0.141205, step = 5201 (1.033 sec)
# INFO:tensorflow:global_step/sec: 100.085
# INFO:tensorflow:loss = 0.104284, step = 5301 (0.999 sec)
# INFO:tensorflow:global_step/sec: 99.4328
# INFO:tensorflow:loss = 0.122055, step = 5401 (1.005 sec)
# INFO:tensorflow:global_step/sec: 99.8836
# INFO:tensorflow:loss = 0.189978, step = 5501 (1.002 sec)
# INFO:tensorflow:global_step/sec: 94.3713
# INFO:tensorflow:loss = 0.128941, step = 5601 (1.060 sec)
# INFO:tensorflow:global_step/sec: 87.2465
# INFO:tensorflow:loss = 0.145912, step = 5701 (1.147 sec)
# INFO:tensorflow:global_step/sec: 88.842
# INFO:tensorflow:loss = 0.207134, step = 5801 (1.126 sec)
# INFO:tensorflow:global_step/sec: 79.9137
# INFO:tensorflow:loss = 0.136728, step = 5901 (1.252 sec)
# INFO:tensorflow:global_step/sec: 76.042
# INFO:tensorflow:loss = 0.185154, step = 6001 (1.315 sec)
# INFO:tensorflow:global_step/sec: 89.28
# INFO:tensorflow:loss = 0.122298, step = 6101 (1.119 sec)
# INFO:tensorflow:global_step/sec: 98.3429
# INFO:tensorflow:loss = 0.151143, step = 6201 (1.015 sec)
# INFO:tensorflow:global_step/sec: 108.403
# INFO:tensorflow:loss = 0.213383, step = 6301 (0.922 sec)
# INFO:tensorflow:global_step/sec: 108.664
# INFO:tensorflow:loss = 0.128019, step = 6401 (0.920 sec)
# INFO:tensorflow:global_step/sec: 109.939
# INFO:tensorflow:loss = 0.136198, step = 6501 (0.909 sec)
# INFO:tensorflow:global_step/sec: 113.533
# INFO:tensorflow:loss = 0.108775, step = 6601 (0.881 sec)
# INFO:tensorflow:global_step/sec: 110.408
# INFO:tensorflow:loss = 0.121601, step = 6701 (0.906 sec)
# INFO:tensorflow:global_step/sec: 98.9949
# INFO:tensorflow:loss = 0.122634, step = 6801 (1.011 sec)
# INFO:tensorflow:global_step/sec: 97.0329
# INFO:tensorflow:loss = 0.131395, step = 6901 (1.031 sec)
# INFO:tensorflow:global_step/sec: 100.756
# INFO:tensorflow:loss = 0.120274, step = 7001 (0.992 sec)
# INFO:tensorflow:global_step/sec: 97.1415
# INFO:tensorflow:loss = 0.125307, step = 7101 (1.029 sec)
# INFO:tensorflow:global_step/sec: 97.0717
# INFO:tensorflow:loss = 0.372128, step = 7201 (1.031 sec)
# INFO:tensorflow:global_step/sec: 93.6301
# INFO:tensorflow:loss = 0.114355, step = 7301 (1.068 sec)
# INFO:tensorflow:global_step/sec: 92.5953
# INFO:tensorflow:loss = 0.150808, step = 7401 (1.079 sec)
# INFO:tensorflow:global_step/sec: 94.9386
# INFO:tensorflow:loss = 0.124872, step = 7501 (1.053 sec)
# INFO:tensorflow:global_step/sec: 97.3068
# INFO:tensorflow:loss = 0.0963076, step = 7601 (1.029 sec)
# INFO:tensorflow:global_step/sec: 95.6424
# INFO:tensorflow:loss = 0.46404, step = 7701 (1.045 sec)
# INFO:tensorflow:global_step/sec: 102.724
# INFO:tensorflow:loss = 0.111815, step = 7801 (0.972 sec)
# INFO:tensorflow:global_step/sec: 107.045
# INFO:tensorflow:loss = 0.173165, step = 7901 (0.934 sec)
# INFO:tensorflow:global_step/sec: 110.427
# INFO:tensorflow:loss = 0.182229, step = 8001 (0.906 sec)
# INFO:tensorflow:global_step/sec: 111.74
# INFO:tensorflow:loss = 0.175636, step = 8101 (0.895 sec)
# INFO:tensorflow:global_step/sec: 110.057
# INFO:tensorflow:loss = 0.148805, step = 8201 (0.909 sec)
# INFO:tensorflow:global_step/sec: 111.23
# INFO:tensorflow:loss = 0.308555, step = 8301 (0.899 sec)
# INFO:tensorflow:global_step/sec: 110.222
# INFO:tensorflow:loss = 0.151668, step = 8401 (0.907 sec)
# INFO:tensorflow:global_step/sec: 110.411
# INFO:tensorflow:loss = 0.14169, step = 8501 (0.906 sec)
# INFO:tensorflow:global_step/sec: 104.818
# INFO:tensorflow:loss = 0.299141, step = 8601 (0.955 sec)
# INFO:tensorflow:global_step/sec: 98.4916
# INFO:tensorflow:loss = 0.121801, step = 8701 (1.015 sec)
# INFO:tensorflow:global_step/sec: 100.602
# INFO:tensorflow:loss = 0.105865, step = 8801 (0.994 sec)
# INFO:tensorflow:global_step/sec: 83.2512
# INFO:tensorflow:loss = 0.105245, step = 8901 (1.203 sec)
# INFO:tensorflow:global_step/sec: 72.5558
# INFO:tensorflow:loss = 0.124217, step = 9001 (1.377 sec)
# INFO:tensorflow:global_step/sec: 71.5723
# INFO:tensorflow:loss = 0.152238, step = 9101 (1.399 sec)
# INFO:tensorflow:global_step/sec: 84.764
# INFO:tensorflow:loss = 0.124923, step = 9201 (1.177 sec)
# INFO:tensorflow:global_step/sec: 96.1052
# INFO:tensorflow:loss = 0.1214, step = 9301 (1.041 sec)
# INFO:tensorflow:global_step/sec: 90.9082
# INFO:tensorflow:loss = 0.166942, step = 9401 (1.100 sec)
# INFO:tensorflow:global_step/sec: 93.6083
# INFO:tensorflow:loss = 0.171089, step = 9501 (1.068 sec)
# INFO:tensorflow:global_step/sec: 97.497
# INFO:tensorflow:loss = 0.482662, step = 9601 (1.025 sec)
# INFO:tensorflow:global_step/sec: 98.0778
# INFO:tensorflow:loss = 0.129422, step = 9701 (1.020 sec)
# INFO:tensorflow:global_step/sec: 100.761
# INFO:tensorflow:loss = 0.183404, step = 9801 (0.992 sec)
# INFO:tensorflow:global_step/sec: 96.401
# INFO:tensorflow:loss = 0.100015, step = 9901 (1.038 sec)
# INFO:tensorflow:global_step/sec: 91.9968
# INFO:tensorflow:loss = 0.117935, step = 10001 (1.087 sec)
# INFO:tensorflow:global_step/sec: 101.29
# INFO:tensorflow:loss = 0.110737, step = 10101 (0.987 sec)
# INFO:tensorflow:global_step/sec: 101.012
# INFO:tensorflow:loss = 0.118208, step = 10201 (0.990 sec)
# INFO:tensorflow:global_step/sec: 95.0192
# INFO:tensorflow:loss = 0.106712, step = 10301 (1.053 sec)
# INFO:tensorflow:global_step/sec: 92.01
# INFO:tensorflow:loss = 0.112614, step = 10401 (1.087 sec)
# INFO:tensorflow:global_step/sec: 91.2713
# INFO:tensorflow:loss = 0.127251, step = 10501 (1.097 sec)
# INFO:tensorflow:global_step/sec: 89.404
# INFO:tensorflow:loss = 0.102681, step = 10601 (1.117 sec)
# INFO:tensorflow:global_step/sec: 95.7528
# INFO:tensorflow:loss = 0.16769, step = 10701 (1.044 sec)
# INFO:tensorflow:global_step/sec: 101.197
# INFO:tensorflow:loss = 0.227666, step = 10801 (0.988 sec)
# INFO:tensorflow:global_step/sec: 89.724
# INFO:tensorflow:loss = 0.253188, step = 10901 (1.115 sec)
# INFO:tensorflow:global_step/sec: 90.1373
# INFO:tensorflow:loss = 0.145356, step = 11001 (1.109 sec)
# INFO:tensorflow:global_step/sec: 92.2568
# INFO:tensorflow:loss = 0.114393, step = 11101 (1.084 sec)
# INFO:tensorflow:global_step/sec: 108.236
# INFO:tensorflow:loss = 0.131526, step = 11201 (0.923 sec)
# INFO:tensorflow:global_step/sec: 108.77
# INFO:tensorflow:loss = 0.11567, step = 11301 (0.920 sec)
# INFO:tensorflow:global_step/sec: 110.151
# INFO:tensorflow:loss = 0.108079, step = 11401 (0.908 sec)
# INFO:tensorflow:global_step/sec: 108.515
# INFO:tensorflow:loss = 0.128254, step = 11501 (0.922 sec)
# INFO:tensorflow:global_step/sec: 109.2
# INFO:tensorflow:loss = 0.115537, step = 11601 (0.916 sec)
# INFO:tensorflow:global_step/sec: 107.123
# INFO:tensorflow:loss = 0.105733, step = 11701 (0.934 sec)
# INFO:tensorflow:global_step/sec: 106.193
# INFO:tensorflow:loss = 0.0977203, step = 11801 (0.941 sec)
# INFO:tensorflow:global_step/sec: 108.737
# INFO:tensorflow:loss = 0.133725, step = 11901 (0.920 sec)
# INFO:tensorflow:global_step/sec: 108.324
# INFO:tensorflow:loss = 0.114131, step = 12001 (0.923 sec)
# INFO:tensorflow:global_step/sec: 104.864
# INFO:tensorflow:loss = 0.134617, step = 12101 (0.954 sec)
# INFO:tensorflow:global_step/sec: 107.294
# INFO:tensorflow:loss = 0.150336, step = 12201 (0.932 sec)
# INFO:tensorflow:global_step/sec: 108.639
# INFO:tensorflow:loss = 0.103579, step = 12301 (0.920 sec)
# INFO:tensorflow:global_step/sec: 107.594
# INFO:tensorflow:loss = 0.150681, step = 12401 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.167
# INFO:tensorflow:loss = 0.110733, step = 12501 (0.935 sec)
# INFO:tensorflow:global_step/sec: 107.633
# INFO:tensorflow:loss = 0.127443, step = 12601 (0.928 sec)
# INFO:tensorflow:global_step/sec: 108.266
# INFO:tensorflow:loss = 0.120323, step = 12701 (0.924 sec)
# INFO:tensorflow:global_step/sec: 110.49
# INFO:tensorflow:loss = 0.15097, step = 12801 (0.905 sec)
# INFO:tensorflow:global_step/sec: 109.221
# INFO:tensorflow:loss = 0.145947, step = 12901 (0.916 sec)
# INFO:tensorflow:global_step/sec: 111.538
# INFO:tensorflow:loss = 0.142238, step = 13001 (0.896 sec)
# INFO:tensorflow:global_step/sec: 110.461
# INFO:tensorflow:loss = 0.261061, step = 13101 (0.906 sec)
# INFO:tensorflow:global_step/sec: 108.803
# INFO:tensorflow:loss = 0.165077, step = 13201 (0.920 sec)
# INFO:tensorflow:global_step/sec: 106.837
# INFO:tensorflow:loss = 0.134476, step = 13301 (0.936 sec)
# INFO:tensorflow:global_step/sec: 96.3877
# INFO:tensorflow:loss = 0.132938, step = 13401 (1.037 sec)
# INFO:tensorflow:global_step/sec: 100.999
# INFO:tensorflow:loss = 0.146626, step = 13501 (0.990 sec)
# INFO:tensorflow:global_step/sec: 97.9147
# INFO:tensorflow:loss = 0.107615, step = 13601 (1.022 sec)
# INFO:tensorflow:global_step/sec: 99.3156
# INFO:tensorflow:loss = 0.151597, step = 13701 (1.006 sec)
# INFO:tensorflow:global_step/sec: 99.0163
# INFO:tensorflow:loss = 0.124424, step = 13801 (1.011 sec)
# INFO:tensorflow:global_step/sec: 94.3816
# INFO:tensorflow:loss = 0.106857, step = 13901 (1.059 sec)
# INFO:tensorflow:global_step/sec: 102.006
# INFO:tensorflow:loss = 0.107204, step = 14001 (0.979 sec)
# INFO:tensorflow:global_step/sec: 101.606
# INFO:tensorflow:loss = 0.133259, step = 14101 (0.985 sec)
# INFO:tensorflow:global_step/sec: 99.9812
# INFO:tensorflow:loss = 0.103004, step = 14201 (1.000 sec)
# INFO:tensorflow:global_step/sec: 102.238
# INFO:tensorflow:loss = 0.102003, step = 14301 (0.978 sec)
# INFO:tensorflow:global_step/sec: 100.747
# INFO:tensorflow:loss = 0.120954, step = 14401 (0.992 sec)
# INFO:tensorflow:global_step/sec: 100.368
# INFO:tensorflow:loss = 0.104119, step = 14501 (0.997 sec)
# INFO:tensorflow:global_step/sec: 103.433
# INFO:tensorflow:loss = 0.104398, step = 14601 (0.967 sec)
# INFO:tensorflow:global_step/sec: 102.39
# INFO:tensorflow:loss = 0.103332, step = 14701 (0.977 sec)
# INFO:tensorflow:global_step/sec: 95.8039
# INFO:tensorflow:loss = 0.168785, step = 14801 (1.044 sec)
# INFO:tensorflow:global_step/sec: 94.553
# INFO:tensorflow:loss = 0.13835, step = 14901 (1.058 sec)
# INFO:tensorflow:global_step/sec: 99.3175
# INFO:tensorflow:loss = 0.108472, step = 15001 (1.007 sec)
# INFO:tensorflow:global_step/sec: 92.8735
# INFO:tensorflow:loss = 0.349627, step = 15101 (1.077 sec)
# INFO:tensorflow:global_step/sec: 100.388
# INFO:tensorflow:loss = 0.114074, step = 15201 (0.996 sec)
# INFO:tensorflow:global_step/sec: 98.3658
# INFO:tensorflow:loss = 0.100701, step = 15301 (1.017 sec)
# INFO:tensorflow:global_step/sec: 93.5259
# INFO:tensorflow:loss = 0.173609, step = 15401 (1.068 sec)
# INFO:tensorflow:global_step/sec: 109.091
# INFO:tensorflow:loss = 0.119726, step = 15501 (0.917 sec)
# INFO:tensorflow:global_step/sec: 110.412
# INFO:tensorflow:loss = 0.151893, step = 15601 (0.905 sec)
# INFO:tensorflow:global_step/sec: 109.262
# INFO:tensorflow:loss = 0.141216, step = 15701 (0.915 sec)
# INFO:tensorflow:global_step/sec: 109.923
# INFO:tensorflow:loss = 0.129519, step = 15801 (0.910 sec)
# INFO:tensorflow:global_step/sec: 108.152
# INFO:tensorflow:loss = 0.11306, step = 15901 (0.924 sec)
# INFO:tensorflow:global_step/sec: 108.651
# INFO:tensorflow:loss = 0.120975, step = 16001 (0.921 sec)
# INFO:tensorflow:global_step/sec: 110.361
# INFO:tensorflow:loss = 0.107059, step = 16101 (0.907 sec)
# INFO:tensorflow:global_step/sec: 105.43
# INFO:tensorflow:loss = 0.103854, step = 16201 (0.948 sec)
# INFO:tensorflow:global_step/sec: 105.933
# INFO:tensorflow:loss = 0.112086, step = 16301 (0.944 sec)
# INFO:tensorflow:global_step/sec: 108.212
# INFO:tensorflow:loss = 0.10285, step = 16401 (0.924 sec)
# INFO:tensorflow:global_step/sec: 107.477
# INFO:tensorflow:loss = 0.126039, step = 16501 (0.930 sec)
# INFO:tensorflow:global_step/sec: 109.091
# INFO:tensorflow:loss = 0.103275, step = 16601 (0.917 sec)
# INFO:tensorflow:global_step/sec: 109.525
# INFO:tensorflow:loss = 0.104287, step = 16701 (0.913 sec)
# INFO:tensorflow:global_step/sec: 108.181
# INFO:tensorflow:loss = 0.116141, step = 16801 (0.924 sec)
# INFO:tensorflow:global_step/sec: 109.108
# INFO:tensorflow:loss = 0.1106, step = 16901 (0.917 sec)
# INFO:tensorflow:global_step/sec: 108.325
# INFO:tensorflow:loss = 0.111261, step = 17001 (0.923 sec)
# INFO:tensorflow:global_step/sec: 110.138
# INFO:tensorflow:loss = 0.130787, step = 17101 (0.908 sec)
# INFO:tensorflow:global_step/sec: 109.942
# INFO:tensorflow:loss = 0.111262, step = 17201 (0.910 sec)
# INFO:tensorflow:global_step/sec: 107.893
# INFO:tensorflow:loss = 0.119894, step = 17301 (0.927 sec)
# INFO:tensorflow:global_step/sec: 109.555
# INFO:tensorflow:loss = 0.0955665, step = 17401 (0.913 sec)
# INFO:tensorflow:global_step/sec: 95.8162
# INFO:tensorflow:loss = 0.16065, step = 17501 (1.045 sec)
# INFO:tensorflow:global_step/sec: 93.1503
# INFO:tensorflow:loss = 0.123529, step = 17601 (1.074 sec)
# INFO:tensorflow:global_step/sec: 93.5443
# INFO:tensorflow:loss = 0.11894, step = 17701 (1.069 sec)
# INFO:tensorflow:global_step/sec: 87.2588
# INFO:tensorflow:loss = 0.12075, step = 17801 (1.146 sec)
# INFO:tensorflow:global_step/sec: 92.7415
# INFO:tensorflow:loss = 0.248989, step = 17901 (1.078 sec)
# INFO:tensorflow:global_step/sec: 93.3806
# INFO:tensorflow:loss = 0.157769, step = 18001 (1.072 sec)
# INFO:tensorflow:global_step/sec: 94.2691
# INFO:tensorflow:loss = 0.119276, step = 18101 (1.060 sec)
# INFO:tensorflow:global_step/sec: 99.2581
# INFO:tensorflow:loss = 0.113624, step = 18201 (1.008 sec)
# INFO:tensorflow:global_step/sec: 94.9414
# INFO:tensorflow:loss = 0.134625, step = 18301 (1.053 sec)
# INFO:tensorflow:global_step/sec: 99.372
# INFO:tensorflow:loss = 0.115555, step = 18401 (1.006 sec)
# INFO:tensorflow:global_step/sec: 98.9156
# INFO:tensorflow:loss = 0.133433, step = 18501 (1.011 sec)
# INFO:tensorflow:global_step/sec: 98.8
# INFO:tensorflow:loss = 0.107169, step = 18601 (1.012 sec)
# INFO:tensorflow:global_step/sec: 96.4361
# INFO:tensorflow:loss = 0.112232, step = 18701 (1.037 sec)
# INFO:tensorflow:global_step/sec: 97.1876
# INFO:tensorflow:loss = 0.0984024, step = 18801 (1.029 sec)
# INFO:tensorflow:global_step/sec: 98.0968
# INFO:tensorflow:loss = 0.105985, step = 18901 (1.019 sec)
# INFO:tensorflow:global_step/sec: 98.9631
# INFO:tensorflow:loss = 0.135489, step = 19001 (1.011 sec)
# INFO:tensorflow:global_step/sec: 96.4931
# INFO:tensorflow:loss = 0.12284, step = 19101 (1.036 sec)
# INFO:tensorflow:global_step/sec: 98.6791
# INFO:tensorflow:loss = 0.126914, step = 19201 (1.014 sec)
# INFO:tensorflow:global_step/sec: 94.8304
# INFO:tensorflow:loss = 0.13657, step = 19301 (1.054 sec)
# INFO:tensorflow:global_step/sec: 98.6241
# INFO:tensorflow:loss = 0.115227, step = 19401 (1.015 sec)
# INFO:tensorflow:global_step/sec: 93.2548
# INFO:tensorflow:loss = 0.098514, step = 19501 (1.072 sec)
# INFO:tensorflow:global_step/sec: 100.467
# INFO:tensorflow:loss = 0.104723, step = 19601 (0.995 sec)
# INFO:tensorflow:global_step/sec: 98.9363
# INFO:tensorflow:loss = 0.16704, step = 19701 (1.011 sec)
# INFO:tensorflow:global_step/sec: 100.2
# INFO:tensorflow:loss = 0.124886, step = 19801 (0.998 sec)
# INFO:tensorflow:global_step/sec: 98.5988
# INFO:tensorflow:loss = 0.135163, step = 19901 (1.015 sec)
# INFO:tensorflow:global_step/sec: 98.2024
# INFO:tensorflow:loss = 0.0978663, step = 20001 (1.017 sec)
# INFO:tensorflow:global_step/sec: 97.7779
# INFO:tensorflow:loss = 0.109215, step = 20101 (1.023 sec)
# INFO:tensorflow:global_step/sec: 99.0092
# INFO:tensorflow:loss = 0.0956056, step = 20201 (1.010 sec)
# INFO:tensorflow:global_step/sec: 95.6048
# INFO:tensorflow:loss = 0.102017, step = 20301 (1.047 sec)
# INFO:tensorflow:global_step/sec: 95.2595
# INFO:tensorflow:loss = 0.186354, step = 20401 (1.049 sec)
# INFO:tensorflow:global_step/sec: 94.2614
# INFO:tensorflow:loss = 0.452637, step = 20501 (1.060 sec)
# INFO:tensorflow:global_step/sec: 92.5266
# INFO:tensorflow:loss = 0.128848, step = 20601 (1.083 sec)
# INFO:tensorflow:global_step/sec: 90.2853
# INFO:tensorflow:loss = 0.158371, step = 20701 (1.107 sec)
# INFO:tensorflow:global_step/sec: 95.0145
# INFO:tensorflow:loss = 0.173872, step = 20801 (1.052 sec)
# INFO:tensorflow:global_step/sec: 98.9541
# INFO:tensorflow:loss = 0.138886, step = 20901 (1.011 sec)
# INFO:tensorflow:global_step/sec: 100.38
# INFO:tensorflow:loss = 0.128758, step = 21001 (0.996 sec)
# INFO:tensorflow:global_step/sec: 94.462
# INFO:tensorflow:loss = 0.134872, step = 21101 (1.059 sec)
# INFO:tensorflow:global_step/sec: 98.4685
# INFO:tensorflow:loss = 0.125315, step = 21201 (1.015 sec)
# INFO:tensorflow:global_step/sec: 99.0856
# INFO:tensorflow:loss = 0.128294, step = 21301 (1.009 sec)
# INFO:tensorflow:global_step/sec: 99.6174
# INFO:tensorflow:loss = 0.0959353, step = 21401 (1.003 sec)
# INFO:tensorflow:global_step/sec: 107.843
# INFO:tensorflow:loss = 0.105542, step = 21501 (0.927 sec)
# INFO:tensorflow:global_step/sec: 105.169
# INFO:tensorflow:loss = 0.111389, step = 21601 (0.951 sec)
# INFO:tensorflow:global_step/sec: 102.882
# INFO:tensorflow:loss = 0.326141, step = 21701 (0.974 sec)
# INFO:tensorflow:global_step/sec: 95.2166
# INFO:tensorflow:loss = 0.120178, step = 21801 (1.049 sec)
# INFO:tensorflow:global_step/sec: 97.6824
# INFO:tensorflow:loss = 0.117379, step = 21901 (1.023 sec)
# INFO:tensorflow:global_step/sec: 107.228
# INFO:tensorflow:loss = 0.118527, step = 22001 (0.934 sec)
# INFO:tensorflow:global_step/sec: 106.54
# INFO:tensorflow:loss = 0.110286, step = 22101 (0.937 sec)
# INFO:tensorflow:global_step/sec: 108.051
# INFO:tensorflow:loss = 0.11279, step = 22201 (0.925 sec)
# INFO:tensorflow:global_step/sec: 105.734
# INFO:tensorflow:loss = 0.155398, step = 22301 (0.946 sec)
# INFO:tensorflow:global_step/sec: 109.549
# INFO:tensorflow:loss = 0.146713, step = 22401 (0.913 sec)
# INFO:tensorflow:global_step/sec: 107.16
# INFO:tensorflow:loss = 0.114539, step = 22501 (0.935 sec)
# INFO:tensorflow:global_step/sec: 102.06
# INFO:tensorflow:loss = 0.269368, step = 22601 (0.978 sec)
# INFO:tensorflow:global_step/sec: 109.682
# INFO:tensorflow:loss = 0.165812, step = 22701 (0.912 sec)
# INFO:tensorflow:global_step/sec: 110.789
# INFO:tensorflow:loss = 0.148622, step = 22801 (0.903 sec)
# INFO:tensorflow:global_step/sec: 109.782
# INFO:tensorflow:loss = 0.22988, step = 22901 (0.911 sec)
# INFO:tensorflow:global_step/sec: 109.652
# INFO:tensorflow:loss = 0.109411, step = 23001 (0.912 sec)
# INFO:tensorflow:global_step/sec: 109.442
# INFO:tensorflow:loss = 0.162587, step = 23101 (0.914 sec)
# INFO:tensorflow:global_step/sec: 108.054
# INFO:tensorflow:loss = 0.114201, step = 23201 (0.926 sec)
# INFO:tensorflow:global_step/sec: 110.496
# INFO:tensorflow:loss = 0.130637, step = 23301 (0.905 sec)
# INFO:tensorflow:global_step/sec: 109.989
# INFO:tensorflow:loss = 0.112309, step = 23401 (0.909 sec)
# INFO:tensorflow:global_step/sec: 107.925
# INFO:tensorflow:loss = 0.106149, step = 23501 (0.927 sec)
# INFO:tensorflow:global_step/sec: 107.103
# INFO:tensorflow:loss = 0.175841, step = 23601 (0.934 sec)
# INFO:tensorflow:global_step/sec: 107.072
# INFO:tensorflow:loss = 0.0940646, step = 23701 (0.934 sec)
# INFO:tensorflow:global_step/sec: 104.86
# INFO:tensorflow:loss = 0.120021, step = 23801 (0.954 sec)
# INFO:tensorflow:global_step/sec: 103.936
# INFO:tensorflow:loss = 0.120508, step = 23901 (0.962 sec)
# INFO:tensorflow:global_step/sec: 99.8155
# INFO:tensorflow:loss = 0.114374, step = 24001 (1.003 sec)
# INFO:tensorflow:global_step/sec: 107.082
# INFO:tensorflow:loss = 0.0985424, step = 24101 (0.933 sec)
# INFO:tensorflow:Saving checkpoints for 24106 into /tmp/tf_bow_sst_20180325-2308/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.106428.
# INFO:tensorflow:Starting evaluation at 2018-03-25-23:12:20
# INFO:tensorflow:Restoring parameters from /tmp/tf_bow_sst_20180325-2308/model.ckpt-24106
# INFO:tensorflow:Finished evaluation at 2018-03-25-23:12:27
# INFO:tensorflow:Saving dict for global step 24106: accuracy = 0.942424, cross_entropy_loss = 0.177372, global_step = 24106, loss = 0.320757
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/tf_bow_sst_20180325-2308/model.ckpt-24106
# INFO:tensorflow:Saving checkpoints for 24107 into /tmp/tf_bow_sst_20180325-2308/model.ckpt.
# INFO:tensorflow:loss = 0.100028, step = 24107
# INFO:tensorflow:global_step/sec: 89.8264
# INFO:tensorflow:loss = 0.107103, step = 24207 (1.118 sec)
# INFO:tensorflow:global_step/sec: 82.7453
# INFO:tensorflow:loss = 0.0955718, step = 24307 (1.209 sec)
# INFO:tensorflow:global_step/sec: 93.099
# INFO:tensorflow:loss = 0.121115, step = 24407 (1.074 sec)
# INFO:tensorflow:global_step/sec: 89.673
# INFO:tensorflow:loss = 0.122107, step = 24507 (1.116 sec)
# INFO:tensorflow:global_step/sec: 83.7169
# INFO:tensorflow:loss = 0.0967545, step = 24607 (1.194 sec)
# INFO:tensorflow:global_step/sec: 93.2496
# INFO:tensorflow:loss = 0.11393, step = 24707 (1.071 sec)
# INFO:tensorflow:global_step/sec: 100.272
# INFO:tensorflow:loss = 0.172731, step = 24807 (0.996 sec)
# INFO:tensorflow:global_step/sec: 100.846
# INFO:tensorflow:loss = 0.139004, step = 24907 (0.992 sec)
# INFO:tensorflow:global_step/sec: 103.266
# INFO:tensorflow:loss = 0.141494, step = 25007 (0.968 sec)
# INFO:tensorflow:global_step/sec: 106.988
# INFO:tensorflow:loss = 0.132128, step = 25107 (0.935 sec)
# INFO:tensorflow:global_step/sec: 107.013
# INFO:tensorflow:loss = 0.156165, step = 25207 (0.935 sec)
# INFO:tensorflow:global_step/sec: 107.285
# INFO:tensorflow:loss = 0.296807, step = 25307 (0.932 sec)
# INFO:tensorflow:global_step/sec: 105.951
# INFO:tensorflow:loss = 0.173869, step = 25407 (0.944 sec)
# INFO:tensorflow:global_step/sec: 108.867
# INFO:tensorflow:loss = 0.178095, step = 25507 (0.919 sec)
# INFO:tensorflow:global_step/sec: 107.009
# INFO:tensorflow:loss = 0.129129, step = 25607 (0.935 sec)
# INFO:tensorflow:global_step/sec: 108.26
# INFO:tensorflow:loss = 0.16966, step = 25707 (0.924 sec)
# INFO:tensorflow:global_step/sec: 111.248
# INFO:tensorflow:loss = 0.14969, step = 25807 (0.899 sec)
# INFO:tensorflow:global_step/sec: 108.356
# INFO:tensorflow:loss = 0.0996003, step = 25907 (0.923 sec)
# INFO:tensorflow:global_step/sec: 107.623
# INFO:tensorflow:loss = 0.22143, step = 26007 (0.929 sec)
# INFO:tensorflow:global_step/sec: 108.854
# INFO:tensorflow:loss = 0.106312, step = 26107 (0.919 sec)
# INFO:tensorflow:global_step/sec: 99.5137
# INFO:tensorflow:loss = 0.140256, step = 26207 (1.006 sec)
# INFO:tensorflow:global_step/sec: 96.1171
# INFO:tensorflow:loss = 0.146213, step = 26307 (1.039 sec)
# INFO:tensorflow:global_step/sec: 101.892
# INFO:tensorflow:loss = 0.108853, step = 26407 (0.982 sec)
# INFO:tensorflow:global_step/sec: 99.6108
# INFO:tensorflow:loss = 0.107669, step = 26507 (1.004 sec)
# INFO:tensorflow:global_step/sec: 106.596
# INFO:tensorflow:loss = 0.121546, step = 26607 (0.938 sec)
# INFO:tensorflow:global_step/sec: 107.04
# INFO:tensorflow:loss = 0.136654, step = 26707 (0.934 sec)
# INFO:tensorflow:global_step/sec: 106.989
# INFO:tensorflow:loss = 0.127425, step = 26807 (0.935 sec)
# INFO:tensorflow:global_step/sec: 103.839
# INFO:tensorflow:loss = 0.107633, step = 26907 (0.963 sec)
# INFO:tensorflow:global_step/sec: 99.3922
# INFO:tensorflow:loss = 0.106133, step = 27007 (1.006 sec)
# INFO:tensorflow:global_step/sec: 104.179
# INFO:tensorflow:loss = 0.175119, step = 27107 (0.960 sec)
# INFO:tensorflow:global_step/sec: 107.883
# INFO:tensorflow:loss = 0.133659, step = 27207 (0.927 sec)
# INFO:tensorflow:global_step/sec: 104.572
# INFO:tensorflow:loss = 0.116433, step = 27307 (0.956 sec)
# INFO:tensorflow:global_step/sec: 106.219
# INFO:tensorflow:loss = 0.154015, step = 27407 (0.942 sec)
# INFO:tensorflow:global_step/sec: 105.408
# INFO:tensorflow:loss = 0.119957, step = 27507 (0.949 sec)
# INFO:tensorflow:global_step/sec: 108.6
# INFO:tensorflow:loss = 0.157019, step = 27607 (0.921 sec)
# INFO:tensorflow:global_step/sec: 105.64
# INFO:tensorflow:loss = 0.291515, step = 27707 (0.946 sec)
# INFO:tensorflow:global_step/sec: 106.481
# INFO:tensorflow:loss = 0.14774, step = 27807 (0.939 sec)
# INFO:tensorflow:global_step/sec: 94.3154
# INFO:tensorflow:loss = 0.11198, step = 27907 (1.061 sec)
# INFO:tensorflow:global_step/sec: 94.9871
# INFO:tensorflow:loss = 0.110513, step = 28007 (1.055 sec)
# INFO:tensorflow:global_step/sec: 88.2198
# INFO:tensorflow:loss = 0.103837, step = 28107 (1.132 sec)
# INFO:tensorflow:global_step/sec: 96.5936
# INFO:tensorflow:loss = 0.110951, step = 28207 (1.035 sec)
# INFO:tensorflow:global_step/sec: 93.8058
# INFO:tensorflow:loss = 0.112822, step = 28307 (1.066 sec)
# INFO:tensorflow:global_step/sec: 94.2409
# INFO:tensorflow:loss = 0.118163, step = 28407 (1.060 sec)
# INFO:tensorflow:global_step/sec: 104.869
# INFO:tensorflow:loss = 0.106216, step = 28507 (0.954 sec)
# INFO:tensorflow:global_step/sec: 104.237
# INFO:tensorflow:loss = 0.10748, step = 28607 (0.959 sec)
# INFO:tensorflow:global_step/sec: 102.209
# INFO:tensorflow:loss = 0.102285, step = 28707 (0.978 sec)
# INFO:tensorflow:global_step/sec: 100.732
# INFO:tensorflow:loss = 0.105729, step = 28807 (0.994 sec)
# INFO:tensorflow:global_step/sec: 88.3595
# INFO:tensorflow:loss = 0.160316, step = 28907 (1.132 sec)
# INFO:tensorflow:global_step/sec: 93.4913
# INFO:tensorflow:loss = 0.111744, step = 29007 (1.070 sec)
# INFO:tensorflow:global_step/sec: 97.6489
# INFO:tensorflow:loss = 0.13505, step = 29107 (1.023 sec)
# INFO:tensorflow:global_step/sec: 104.492
# INFO:tensorflow:loss = 0.104008, step = 29207 (0.957 sec)
# INFO:tensorflow:global_step/sec: 105.846
# INFO:tensorflow:loss = 0.103895, step = 29307 (0.944 sec)
# INFO:tensorflow:global_step/sec: 104.949
# INFO:tensorflow:loss = 0.0891869, step = 29407 (0.953 sec)
# INFO:tensorflow:global_step/sec: 102.301
# INFO:tensorflow:loss = 0.110474, step = 29507 (0.977 sec)
# INFO:tensorflow:global_step/sec: 104.85
# INFO:tensorflow:loss = 0.124571, step = 29607 (0.954 sec)
# INFO:tensorflow:global_step/sec: 103.724
# INFO:tensorflow:loss = 0.124822, step = 29707 (0.964 sec)
# INFO:tensorflow:global_step/sec: 107.208
# INFO:tensorflow:loss = 0.133869, step = 29807 (0.933 sec)
# INFO:tensorflow:global_step/sec: 104.692
# INFO:tensorflow:loss = 0.204755, step = 29907 (0.956 sec)
# INFO:tensorflow:global_step/sec: 106.393
# INFO:tensorflow:loss = 0.126167, step = 30007 (0.940 sec)
# INFO:tensorflow:global_step/sec: 107.033
# INFO:tensorflow:loss = 0.156535, step = 30107 (0.934 sec)
# INFO:tensorflow:global_step/sec: 106.214
# INFO:tensorflow:loss = 0.107456, step = 30207 (0.942 sec)
# INFO:tensorflow:global_step/sec: 104.52
# INFO:tensorflow:loss = 0.126459, step = 30307 (0.957 sec)
# INFO:tensorflow:global_step/sec: 105.774
# INFO:tensorflow:loss = 0.222826, step = 30407 (0.945 sec)
# INFO:tensorflow:global_step/sec: 107.463
# INFO:tensorflow:loss = 0.111856, step = 30507 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.911
# INFO:tensorflow:loss = 0.112341, step = 30607 (0.927 sec)
# INFO:tensorflow:global_step/sec: 109.994
# INFO:tensorflow:loss = 0.100813, step = 30707 (0.909 sec)
# INFO:tensorflow:global_step/sec: 110.479
# INFO:tensorflow:loss = 0.120641, step = 30807 (0.905 sec)
# INFO:tensorflow:global_step/sec: 99.3536
# INFO:tensorflow:loss = 0.109839, step = 30907 (1.008 sec)
# INFO:tensorflow:global_step/sec: 90.847
# INFO:tensorflow:loss = 0.11938, step = 31007 (1.101 sec)
# INFO:tensorflow:global_step/sec: 92.0024
# INFO:tensorflow:loss = 0.111527, step = 31107 (1.088 sec)
# INFO:tensorflow:global_step/sec: 84.5629
# INFO:tensorflow:loss = 0.110173, step = 31207 (1.182 sec)
# INFO:tensorflow:global_step/sec: 88.6135
# INFO:tensorflow:loss = 0.294878, step = 31307 (1.129 sec)
# INFO:tensorflow:global_step/sec: 93.467
# INFO:tensorflow:loss = 0.109458, step = 31407 (1.069 sec)
# INFO:tensorflow:global_step/sec: 90.6601
# INFO:tensorflow:loss = 0.109188, step = 31507 (1.103 sec)
# INFO:tensorflow:global_step/sec: 92.665
# INFO:tensorflow:loss = 0.114042, step = 31607 (1.079 sec)
# INFO:tensorflow:global_step/sec: 89.2356
# INFO:tensorflow:loss = 0.0948665, step = 31707 (1.121 sec)
# INFO:tensorflow:global_step/sec: 93.3143
# INFO:tensorflow:loss = 0.357645, step = 31807 (1.072 sec)
# INFO:tensorflow:global_step/sec: 90.7509
# INFO:tensorflow:loss = 0.103664, step = 31907 (1.102 sec)
# INFO:tensorflow:global_step/sec: 92.216
# INFO:tensorflow:loss = 0.136901, step = 32007 (1.084 sec)
# INFO:tensorflow:global_step/sec: 101
# INFO:tensorflow:loss = 0.174701, step = 32107 (0.989 sec)
# INFO:tensorflow:global_step/sec: 101.506
# INFO:tensorflow:loss = 0.126956, step = 32207 (0.986 sec)
# INFO:tensorflow:global_step/sec: 103.125
# INFO:tensorflow:loss = 0.153762, step = 32307 (0.969 sec)
# INFO:tensorflow:global_step/sec: 104.706
# INFO:tensorflow:loss = 0.300897, step = 32407 (0.958 sec)
# INFO:tensorflow:global_step/sec: 105.264
# INFO:tensorflow:loss = 0.149189, step = 32507 (0.947 sec)
# INFO:tensorflow:global_step/sec: 105.496
# INFO:tensorflow:loss = 0.123068, step = 32607 (0.948 sec)
# INFO:tensorflow:global_step/sec: 104.083
# INFO:tensorflow:loss = 0.251721, step = 32707 (0.961 sec)
# INFO:tensorflow:global_step/sec: 103.22
# INFO:tensorflow:loss = 0.10959, step = 32807 (0.969 sec)
# INFO:tensorflow:global_step/sec: 101.778
# INFO:tensorflow:loss = 0.0976814, step = 32907 (0.983 sec)
# INFO:tensorflow:global_step/sec: 105.586
# INFO:tensorflow:loss = 0.102822, step = 33007 (0.946 sec)
# INFO:tensorflow:global_step/sec: 104.204
# INFO:tensorflow:loss = 0.117636, step = 33107 (0.960 sec)
# INFO:tensorflow:global_step/sec: 103.443
# INFO:tensorflow:loss = 0.11982, step = 33207 (0.967 sec)
# INFO:tensorflow:global_step/sec: 104.353
# INFO:tensorflow:loss = 0.117432, step = 33307 (0.958 sec)
# INFO:tensorflow:global_step/sec: 101.862
# INFO:tensorflow:loss = 0.1149, step = 33407 (0.983 sec)
# INFO:tensorflow:global_step/sec: 91.7465
# INFO:tensorflow:loss = 0.123707, step = 33507 (1.091 sec)
# INFO:tensorflow:global_step/sec: 89.9788
# INFO:tensorflow:loss = 0.143416, step = 33607 (1.111 sec)
# INFO:tensorflow:global_step/sec: 98.2533
# INFO:tensorflow:loss = 0.505717, step = 33707 (1.017 sec)
# INFO:tensorflow:global_step/sec: 95.7408
# INFO:tensorflow:loss = 0.125159, step = 33807 (1.044 sec)
# INFO:tensorflow:global_step/sec: 97.2178
# INFO:tensorflow:loss = 0.118025, step = 33907 (1.029 sec)
# INFO:tensorflow:global_step/sec: 100.249
# INFO:tensorflow:loss = 0.100252, step = 34007 (0.996 sec)
# INFO:tensorflow:global_step/sec: 105.226
# INFO:tensorflow:loss = 0.115858, step = 34107 (0.951 sec)
# INFO:tensorflow:global_step/sec: 103.651
# INFO:tensorflow:loss = 0.109713, step = 34207 (0.965 sec)
# INFO:tensorflow:global_step/sec: 105.462
# INFO:tensorflow:loss = 0.114408, step = 34307 (0.948 sec)
# INFO:tensorflow:global_step/sec: 105.881
# INFO:tensorflow:loss = 0.0957683, step = 34407 (0.945 sec)
# INFO:tensorflow:global_step/sec: 102.652
# INFO:tensorflow:loss = 0.11012, step = 34507 (0.974 sec)
# INFO:tensorflow:global_step/sec: 105.721
# INFO:tensorflow:loss = 0.126488, step = 34607 (0.946 sec)
# INFO:tensorflow:global_step/sec: 105.533
# INFO:tensorflow:loss = 0.100003, step = 34707 (0.948 sec)
# INFO:tensorflow:global_step/sec: 103.736
# INFO:tensorflow:loss = 0.145263, step = 34807 (0.964 sec)
# INFO:tensorflow:global_step/sec: 107.837
# INFO:tensorflow:loss = 0.194504, step = 34907 (0.928 sec)
# INFO:tensorflow:global_step/sec: 102.093
# INFO:tensorflow:loss = 0.219533, step = 35007 (0.980 sec)
# INFO:tensorflow:global_step/sec: 109.647
# INFO:tensorflow:loss = 0.148126, step = 35107 (0.911 sec)
# INFO:tensorflow:global_step/sec: 106.056
# INFO:tensorflow:loss = 0.112737, step = 35207 (0.943 sec)
# INFO:tensorflow:global_step/sec: 98.8805
# INFO:tensorflow:loss = 0.113638, step = 35307 (1.012 sec)
# INFO:tensorflow:global_step/sec: 89.8322
# INFO:tensorflow:loss = 0.117837, step = 35407 (1.115 sec)
# INFO:tensorflow:global_step/sec: 98.7077
# INFO:tensorflow:loss = 0.102196, step = 35507 (1.013 sec)
# INFO:tensorflow:global_step/sec: 102.171
# INFO:tensorflow:loss = 0.116672, step = 35607 (0.980 sec)
# INFO:tensorflow:global_step/sec: 94.1143
# INFO:tensorflow:loss = 0.107101, step = 35707 (1.060 sec)
# INFO:tensorflow:global_step/sec: 102.317
# INFO:tensorflow:loss = 0.101098, step = 35807 (0.977 sec)
# INFO:tensorflow:global_step/sec: 104.847
# INFO:tensorflow:loss = 0.0961267, step = 35907 (0.954 sec)
# INFO:tensorflow:global_step/sec: 102.004
# INFO:tensorflow:loss = 0.119361, step = 36007 (0.980 sec)
# INFO:tensorflow:global_step/sec: 107.769
# INFO:tensorflow:loss = 0.107103, step = 36107 (0.928 sec)
# INFO:tensorflow:global_step/sec: 104.767
# INFO:tensorflow:loss = 0.13027, step = 36207 (0.954 sec)
# INFO:tensorflow:global_step/sec: 100.197
# INFO:tensorflow:loss = 0.145897, step = 36307 (0.998 sec)
# INFO:tensorflow:global_step/sec: 103.239
# INFO:tensorflow:loss = 0.100038, step = 36407 (0.970 sec)
# INFO:tensorflow:global_step/sec: 107.185
# INFO:tensorflow:loss = 0.142741, step = 36507 (0.931 sec)
# INFO:tensorflow:global_step/sec: 102.509
# INFO:tensorflow:loss = 0.101149, step = 36607 (0.975 sec)
# INFO:tensorflow:global_step/sec: 100.23
# INFO:tensorflow:loss = 0.10764, step = 36707 (1.000 sec)
# INFO:tensorflow:global_step/sec: 103.21
# INFO:tensorflow:loss = 0.119864, step = 36807 (0.967 sec)
# INFO:tensorflow:global_step/sec: 106.135
# INFO:tensorflow:loss = 0.146109, step = 36907 (0.942 sec)
# INFO:tensorflow:global_step/sec: 105.804
# INFO:tensorflow:loss = 0.127845, step = 37007 (0.945 sec)
# INFO:tensorflow:global_step/sec: 102.761
# INFO:tensorflow:loss = 0.136783, step = 37107 (0.973 sec)
# INFO:tensorflow:global_step/sec: 108.351
# INFO:tensorflow:loss = 0.226122, step = 37207 (0.923 sec)
# INFO:tensorflow:global_step/sec: 99.5467
# INFO:tensorflow:loss = 0.159774, step = 37307 (1.005 sec)
# INFO:tensorflow:global_step/sec: 100.033
# INFO:tensorflow:loss = 0.132633, step = 37407 (0.999 sec)
# INFO:tensorflow:global_step/sec: 100.381
# INFO:tensorflow:loss = 0.123561, step = 37507 (0.997 sec)
# INFO:tensorflow:global_step/sec: 86.2566
# INFO:tensorflow:loss = 0.124216, step = 37607 (1.161 sec)
# INFO:tensorflow:global_step/sec: 82.4434
# INFO:tensorflow:loss = 0.111864, step = 37707 (1.211 sec)
# INFO:tensorflow:global_step/sec: 90.9085
# INFO:tensorflow:loss = 0.134125, step = 37807 (1.100 sec)
# INFO:tensorflow:global_step/sec: 101.262
# INFO:tensorflow:loss = 0.110693, step = 37907 (0.987 sec)
# INFO:tensorflow:global_step/sec: 97.2666
# INFO:tensorflow:loss = 0.100392, step = 38007 (1.028 sec)
# INFO:tensorflow:global_step/sec: 110.947
# INFO:tensorflow:loss = 0.102294, step = 38107 (0.901 sec)
# INFO:tensorflow:global_step/sec: 108.05
# INFO:tensorflow:loss = 0.132073, step = 38207 (0.925 sec)
# INFO:tensorflow:global_step/sec: 107.126
# INFO:tensorflow:loss = 0.1005, step = 38307 (0.934 sec)
# INFO:tensorflow:global_step/sec: 107.739
# INFO:tensorflow:loss = 0.0982026, step = 38407 (0.928 sec)
# INFO:tensorflow:global_step/sec: 110.607
# INFO:tensorflow:loss = 0.120226, step = 38507 (0.904 sec)
# INFO:tensorflow:global_step/sec: 108.838
# INFO:tensorflow:loss = 0.0977456, step = 38607 (0.919 sec)
# INFO:tensorflow:global_step/sec: 108.546
# INFO:tensorflow:loss = 0.102028, step = 38707 (0.922 sec)
# INFO:tensorflow:global_step/sec: 105.552
# INFO:tensorflow:loss = 0.0957184, step = 38807 (0.947 sec)
# INFO:tensorflow:global_step/sec: 108.444
# INFO:tensorflow:loss = 0.176287, step = 38907 (0.922 sec)
# INFO:tensorflow:global_step/sec: 105.129
# INFO:tensorflow:loss = 0.112439, step = 39007 (0.951 sec)
# INFO:tensorflow:global_step/sec: 106.632
# INFO:tensorflow:loss = 0.105118, step = 39107 (0.937 sec)
# INFO:tensorflow:global_step/sec: 103.019
# INFO:tensorflow:loss = 0.305533, step = 39207 (0.971 sec)
# INFO:tensorflow:global_step/sec: 110.212
# INFO:tensorflow:loss = 0.109873, step = 39307 (0.907 sec)
# INFO:tensorflow:global_step/sec: 108.113
# INFO:tensorflow:loss = 0.0951497, step = 39407 (0.925 sec)
# INFO:tensorflow:global_step/sec: 106.976
# INFO:tensorflow:loss = 0.170364, step = 39507 (0.935 sec)
# INFO:tensorflow:global_step/sec: 111.318
# INFO:tensorflow:loss = 0.11445, step = 39607 (0.899 sec)
# INFO:tensorflow:global_step/sec: 107.379
# INFO:tensorflow:loss = 0.145441, step = 39707 (0.931 sec)
# INFO:tensorflow:global_step/sec: 110.735
# INFO:tensorflow:loss = 0.141057, step = 39807 (0.903 sec)
# INFO:tensorflow:global_step/sec: 108.355
# INFO:tensorflow:loss = 0.1192, step = 39907 (0.923 sec)
# INFO:tensorflow:global_step/sec: 107.257
# INFO:tensorflow:loss = 0.111597, step = 40007 (0.932 sec)
# INFO:tensorflow:global_step/sec: 109.266
# INFO:tensorflow:loss = 0.115138, step = 40107 (0.915 sec)
# INFO:tensorflow:global_step/sec: 107.935
# INFO:tensorflow:loss = 0.105647, step = 40207 (0.926 sec)
# INFO:tensorflow:global_step/sec: 104.94
# INFO:tensorflow:loss = 0.103055, step = 40307 (0.953 sec)
# INFO:tensorflow:global_step/sec: 98.015
# INFO:tensorflow:loss = 0.107153, step = 40407 (1.020 sec)
# INFO:tensorflow:global_step/sec: 92.1642
# INFO:tensorflow:loss = 0.100801, step = 40507 (1.086 sec)
# INFO:tensorflow:global_step/sec: 86.1918
# INFO:tensorflow:loss = 0.12898, step = 40607 (1.161 sec)
# INFO:tensorflow:global_step/sec: 83.1243
# INFO:tensorflow:loss = 0.103084, step = 40707 (1.204 sec)
# INFO:tensorflow:global_step/sec: 76.5207
# INFO:tensorflow:loss = 0.101369, step = 40807 (1.306 sec)
# INFO:tensorflow:global_step/sec: 98.6839
# INFO:tensorflow:loss = 0.110486, step = 40907 (1.013 sec)
# INFO:tensorflow:global_step/sec: 102.757
# INFO:tensorflow:loss = 0.113144, step = 41007 (0.973 sec)
# INFO:tensorflow:global_step/sec: 86.8673
# INFO:tensorflow:loss = 0.109162, step = 41107 (1.152 sec)
# INFO:tensorflow:global_step/sec: 95.6158
# INFO:tensorflow:loss = 0.104547, step = 41207 (1.046 sec)
# INFO:tensorflow:global_step/sec: 98.1655
# INFO:tensorflow:loss = 0.102264, step = 41307 (1.018 sec)
# INFO:tensorflow:global_step/sec: 90.523
# INFO:tensorflow:loss = 0.11154, step = 41407 (1.105 sec)
# INFO:tensorflow:global_step/sec: 76.7631
# INFO:tensorflow:loss = 0.094945, step = 41507 (1.304 sec)
# INFO:tensorflow:global_step/sec: 75.804
# INFO:tensorflow:loss = 0.171353, step = 41607 (1.320 sec)
# INFO:tensorflow:global_step/sec: 75.1444
# INFO:tensorflow:loss = 0.118525, step = 41707 (1.329 sec)
# INFO:tensorflow:global_step/sec: 94.4104
# INFO:tensorflow:loss = 0.115927, step = 41807 (1.059 sec)
# INFO:tensorflow:global_step/sec: 95.321
# INFO:tensorflow:loss = 0.114904, step = 41907 (1.050 sec)
# INFO:tensorflow:global_step/sec: 93.9738
# INFO:tensorflow:loss = 0.247236, step = 42007 (1.063 sec)
# INFO:tensorflow:global_step/sec: 91.4807
# INFO:tensorflow:loss = 0.151955, step = 42107 (1.094 sec)
# INFO:tensorflow:global_step/sec: 92.449
# INFO:tensorflow:loss = 0.105331, step = 42207 (1.081 sec)
# INFO:tensorflow:global_step/sec: 92.5863
# INFO:tensorflow:loss = 0.112997, step = 42307 (1.080 sec)
# INFO:tensorflow:global_step/sec: 90.6647
# INFO:tensorflow:loss = 0.136446, step = 42407 (1.102 sec)
# INFO:tensorflow:global_step/sec: 87.9198
# INFO:tensorflow:loss = 0.110059, step = 42507 (1.138 sec)
# INFO:tensorflow:global_step/sec: 89.1234
# INFO:tensorflow:loss = 0.133996, step = 42607 (1.124 sec)
# INFO:tensorflow:global_step/sec: 91.5484
# INFO:tensorflow:loss = 0.10465, step = 42707 (1.091 sec)
# INFO:tensorflow:global_step/sec: 93.9182
# INFO:tensorflow:loss = 0.10786, step = 42807 (1.064 sec)
# INFO:tensorflow:global_step/sec: 95.3328
# INFO:tensorflow:loss = 0.0964728, step = 42907 (1.050 sec)
# INFO:tensorflow:global_step/sec: 99.5833
# INFO:tensorflow:loss = 0.10472, step = 43007 (1.004 sec)
# INFO:tensorflow:global_step/sec: 100.923
# INFO:tensorflow:loss = 0.138691, step = 43107 (0.990 sec)
# INFO:tensorflow:global_step/sec: 104.445
# INFO:tensorflow:loss = 0.11397, step = 43207 (0.957 sec)
# INFO:tensorflow:global_step/sec: 109.748
# INFO:tensorflow:loss = 0.125989, step = 43307 (0.911 sec)
# INFO:tensorflow:global_step/sec: 107.055
# INFO:tensorflow:loss = 0.126592, step = 43407 (0.935 sec)
# INFO:tensorflow:global_step/sec: 94.6602
# INFO:tensorflow:loss = 0.111925, step = 43507 (1.057 sec)
# INFO:tensorflow:global_step/sec: 98.1571
# INFO:tensorflow:loss = 0.102956, step = 43607 (1.018 sec)
# INFO:tensorflow:global_step/sec: 100.981
# INFO:tensorflow:loss = 0.101086, step = 43707 (0.990 sec)
# INFO:tensorflow:global_step/sec: 100.36
# INFO:tensorflow:loss = 0.169591, step = 43807 (0.997 sec)
# INFO:tensorflow:global_step/sec: 97.9339
# INFO:tensorflow:loss = 0.121183, step = 43907 (1.021 sec)
# INFO:tensorflow:global_step/sec: 99.4113
# INFO:tensorflow:loss = 0.122447, step = 44007 (1.006 sec)
# INFO:tensorflow:global_step/sec: 100.506
# INFO:tensorflow:loss = 0.0988074, step = 44107 (0.995 sec)
# INFO:tensorflow:global_step/sec: 95.0078
# INFO:tensorflow:loss = 0.101012, step = 44207 (1.055 sec)
# INFO:tensorflow:global_step/sec: 68.9831
# INFO:tensorflow:loss = 0.0941037, step = 44307 (1.449 sec)
# INFO:tensorflow:global_step/sec: 89.035
# INFO:tensorflow:loss = 0.100279, step = 44407 (1.122 sec)
# INFO:tensorflow:global_step/sec: 97.5023
# INFO:tensorflow:loss = 0.169786, step = 44507 (1.025 sec)
# INFO:tensorflow:global_step/sec: 98.1753
# INFO:tensorflow:loss = 0.278971, step = 44607 (1.021 sec)
# INFO:tensorflow:global_step/sec: 85.3805
# INFO:tensorflow:loss = 0.124882, step = 44707 (1.171 sec)
# INFO:tensorflow:global_step/sec: 90.0109
# INFO:tensorflow:loss = 0.151818, step = 44807 (1.109 sec)
# INFO:tensorflow:global_step/sec: 95.2879
# INFO:tensorflow:loss = 0.175345, step = 44907 (1.050 sec)
# INFO:tensorflow:global_step/sec: 96.7864
# INFO:tensorflow:loss = 0.12137, step = 45007 (1.033 sec)
# INFO:tensorflow:global_step/sec: 91.9295
# INFO:tensorflow:loss = 0.114599, step = 45107 (1.089 sec)
# INFO:tensorflow:global_step/sec: 70.7836
# INFO:tensorflow:loss = 0.13092, step = 45207 (1.413 sec)
# INFO:tensorflow:global_step/sec: 86.7484
# INFO:tensorflow:loss = 0.122722, step = 45307 (1.152 sec)
# INFO:tensorflow:global_step/sec: 90.1339
# INFO:tensorflow:loss = 0.127457, step = 45407 (1.108 sec)
# INFO:tensorflow:global_step/sec: 96.743
# INFO:tensorflow:loss = 0.0942702, step = 45507 (1.034 sec)
# INFO:tensorflow:global_step/sec: 95.8023
# INFO:tensorflow:loss = 0.105131, step = 45607 (1.044 sec)
# INFO:tensorflow:global_step/sec: 92.8342
# INFO:tensorflow:loss = 0.108446, step = 45707 (1.077 sec)
# INFO:tensorflow:global_step/sec: 98.1727
# INFO:tensorflow:loss = 0.224149, step = 45807 (1.019 sec)
# INFO:tensorflow:global_step/sec: 98.3797
# INFO:tensorflow:loss = 0.110996, step = 45907 (1.018 sec)
# INFO:tensorflow:global_step/sec: 85.9696
# INFO:tensorflow:loss = 0.114869, step = 46007 (1.160 sec)
# INFO:tensorflow:global_step/sec: 107.544
# INFO:tensorflow:loss = 0.116646, step = 46107 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.591
# INFO:tensorflow:loss = 0.110859, step = 46207 (0.929 sec)
# INFO:tensorflow:global_step/sec: 102.658
# INFO:tensorflow:loss = 0.110484, step = 46307 (0.975 sec)
# INFO:tensorflow:global_step/sec: 103.274
# INFO:tensorflow:loss = 0.163572, step = 46407 (0.968 sec)
# INFO:tensorflow:global_step/sec: 102.685
# INFO:tensorflow:loss = 0.133887, step = 46507 (0.973 sec)
# INFO:tensorflow:global_step/sec: 104.03
# INFO:tensorflow:loss = 0.111637, step = 46607 (0.961 sec)
# INFO:tensorflow:global_step/sec: 103.571
# INFO:tensorflow:loss = 0.142992, step = 46707 (0.967 sec)
# INFO:tensorflow:global_step/sec: 100.656
# INFO:tensorflow:loss = 0.156846, step = 46807 (0.993 sec)
# INFO:tensorflow:global_step/sec: 100.922
# INFO:tensorflow:loss = 0.145291, step = 46907 (0.990 sec)
# INFO:tensorflow:global_step/sec: 100.961
# INFO:tensorflow:loss = 0.214893, step = 47007 (0.990 sec)
# INFO:tensorflow:global_step/sec: 100.555
# INFO:tensorflow:loss = 0.100902, step = 47107 (0.994 sec)
# INFO:tensorflow:global_step/sec: 104.398
# INFO:tensorflow:loss = 0.145603, step = 47207 (0.958 sec)
# INFO:tensorflow:global_step/sec: 105.767
# INFO:tensorflow:loss = 0.103391, step = 47307 (0.945 sec)
# INFO:tensorflow:global_step/sec: 107.257
# INFO:tensorflow:loss = 0.126449, step = 47407 (0.932 sec)
# INFO:tensorflow:global_step/sec: 106.67
# INFO:tensorflow:loss = 0.109222, step = 47507 (0.937 sec)
# INFO:tensorflow:global_step/sec: 108.096
# INFO:tensorflow:loss = 0.10537, step = 47607 (0.925 sec)
# INFO:tensorflow:global_step/sec: 109.499
# INFO:tensorflow:loss = 0.173542, step = 47707 (0.914 sec)
# INFO:tensorflow:global_step/sec: 108.582
# ...
# INFO:tensorflow:loss = 0.121016, step = 80819 (0.990 sec)
# INFO:tensorflow:global_step/sec: 99.279
# INFO:tensorflow:loss = 0.207154, step = 80919 (1.005 sec)
# INFO:tensorflow:global_step/sec: 97.1464
# INFO:tensorflow:loss = 0.104691, step = 81019 (1.031 sec)
# INFO:tensorflow:global_step/sec: 100.254
# INFO:tensorflow:loss = 0.098243, step = 81119 (0.996 sec)
# INFO:tensorflow:global_step/sec: 104.481
# INFO:tensorflow:loss = 0.0998117, step = 81219 (0.957 sec)
# INFO:tensorflow:global_step/sec: 105.966
# INFO:tensorflow:loss = 0.109417, step = 81319 (0.944 sec)
# INFO:tensorflow:global_step/sec: 104.007
# INFO:tensorflow:loss = 0.110884, step = 81419 (0.961 sec)
# INFO:tensorflow:global_step/sec: 102.622
# INFO:tensorflow:loss = 0.112138, step = 81519 (0.975 sec)
# INFO:tensorflow:global_step/sec: 100.875
# INFO:tensorflow:loss = 0.113501, step = 81619 (0.991 sec)
# INFO:tensorflow:global_step/sec: 105.693
# INFO:tensorflow:loss = 0.117258, step = 81719 (0.946 sec)
# INFO:tensorflow:global_step/sec: 106
# INFO:tensorflow:loss = 0.13023, step = 81819 (0.944 sec)
# INFO:tensorflow:global_step/sec: 105.13
# INFO:tensorflow:loss = 0.554687, step = 81919 (0.951 sec)
# INFO:tensorflow:global_step/sec: 106.06
# INFO:tensorflow:loss = 0.127022, step = 82019 (0.943 sec)
# INFO:tensorflow:global_step/sec: 103.974
# INFO:tensorflow:loss = 0.112818, step = 82119 (0.962 sec)
# INFO:tensorflow:global_step/sec: 101.593
# INFO:tensorflow:loss = 0.100499, step = 82219 (0.984 sec)
# INFO:tensorflow:global_step/sec: 101.846
# INFO:tensorflow:loss = 0.114307, step = 82319 (0.983 sec)
# INFO:tensorflow:global_step/sec: 100.989
# INFO:tensorflow:loss = 0.107958, step = 82419 (0.989 sec)
# INFO:tensorflow:global_step/sec: 97.5067
# INFO:tensorflow:loss = 0.111783, step = 82519 (1.026 sec)
# INFO:tensorflow:global_step/sec: 97.3923
# INFO:tensorflow:loss = 0.091405, step = 82619 (1.026 sec)
# INFO:tensorflow:global_step/sec: 89.8961
# INFO:tensorflow:loss = 0.103951, step = 82719 (1.112 sec)
# INFO:tensorflow:global_step/sec: 101.462
# INFO:tensorflow:loss = 0.120371, step = 82819 (0.986 sec)
# INFO:tensorflow:global_step/sec: 101.209
# INFO:tensorflow:loss = 0.0974809, step = 82919 (0.988 sec)
# INFO:tensorflow:global_step/sec: 97.5351
# INFO:tensorflow:loss = 0.140736, step = 83019 (1.025 sec)
# INFO:tensorflow:global_step/sec: 102.282
# INFO:tensorflow:loss = 0.175099, step = 83119 (0.978 sec)
# INFO:tensorflow:global_step/sec: 94.5516
# INFO:tensorflow:loss = 0.212723, step = 83219 (1.057 sec)
# INFO:tensorflow:global_step/sec: 101.219
# INFO:tensorflow:loss = 0.143841, step = 83319 (0.987 sec)
# INFO:tensorflow:global_step/sec: 98.3536
# INFO:tensorflow:loss = 0.113594, step = 83419 (1.018 sec)
# INFO:tensorflow:global_step/sec: 95.8149
# INFO:tensorflow:loss = 0.109246, step = 83519 (1.043 sec)
# INFO:tensorflow:global_step/sec: 100.807
# INFO:tensorflow:loss = 0.118943, step = 83619 (0.992 sec)
# INFO:tensorflow:global_step/sec: 100.713
# INFO:tensorflow:loss = 0.101171, step = 83719 (0.993 sec)
# INFO:tensorflow:global_step/sec: 94.8786
# INFO:tensorflow:loss = 0.115118, step = 83819 (1.054 sec)
# INFO:tensorflow:global_step/sec: 88.4159
# INFO:tensorflow:loss = 0.100726, step = 83919 (1.131 sec)
# INFO:tensorflow:global_step/sec: 102.489
# INFO:tensorflow:loss = 0.097121, step = 84019 (0.976 sec)
# INFO:tensorflow:global_step/sec: 99.3007
# INFO:tensorflow:loss = 0.095406, step = 84119 (1.006 sec)
# INFO:tensorflow:global_step/sec: 100.908
# INFO:tensorflow:loss = 0.120069, step = 84219 (0.991 sec)
# INFO:tensorflow:global_step/sec: 99.9576
# INFO:tensorflow:loss = 0.104438, step = 84319 (1.000 sec)
# INFO:tensorflow:global_step/sec: 103.392
# INFO:tensorflow:loss = 0.130331, step = 84419 (0.967 sec)
# INFO:tensorflow:global_step/sec: 99.5056
# INFO:tensorflow:loss = 0.132298, step = 84519 (1.005 sec)
# INFO:tensorflow:global_step/sec: 91.3083
# INFO:tensorflow:loss = 0.0973609, step = 84619 (1.096 sec)
# INFO:tensorflow:global_step/sec: 86.9551
# INFO:tensorflow:loss = 0.137657, step = 84719 (1.149 sec)
# INFO:tensorflow:global_step/sec: 102.776
# INFO:tensorflow:loss = 0.0962927, step = 84819 (0.973 sec)
# INFO:tensorflow:global_step/sec: 100.944
# INFO:tensorflow:loss = 0.101949, step = 84919 (0.991 sec)
# INFO:tensorflow:global_step/sec: 103.36
# INFO:tensorflow:loss = 0.120073, step = 85019 (0.968 sec)
# INFO:tensorflow:global_step/sec: 98.0612
# INFO:tensorflow:loss = 0.141681, step = 85119 (1.019 sec)
# INFO:tensorflow:global_step/sec: 101.81
# INFO:tensorflow:loss = 0.121005, step = 85219 (0.983 sec)
# INFO:tensorflow:global_step/sec: 103.047
# INFO:tensorflow:loss = 0.135611, step = 85319 (0.970 sec)
# INFO:tensorflow:global_step/sec: 100.101
# INFO:tensorflow:loss = 0.211426, step = 85419 (0.999 sec)
# INFO:tensorflow:global_step/sec: 100.563
# INFO:tensorflow:loss = 0.161142, step = 85519 (0.995 sec)
# INFO:tensorflow:global_step/sec: 97.9037
# INFO:tensorflow:loss = 0.131447, step = 85619 (1.020 sec)
# INFO:tensorflow:global_step/sec: 94.5607
# INFO:tensorflow:loss = 0.114428, step = 85719 (1.059 sec)
# INFO:tensorflow:global_step/sec: 85.1988
# INFO:tensorflow:loss = 0.116387, step = 85819 (1.175 sec)
# INFO:tensorflow:global_step/sec: 81.342
# INFO:tensorflow:loss = 0.112257, step = 85919 (1.228 sec)
# INFO:tensorflow:global_step/sec: 89.0769
# INFO:tensorflow:loss = 0.12932, step = 86019 (1.123 sec)
# INFO:tensorflow:global_step/sec: 99.2351
# INFO:tensorflow:loss = 0.106657, step = 86119 (1.007 sec)
# INFO:tensorflow:global_step/sec: 95.8521
# INFO:tensorflow:loss = 0.0963312, step = 86219 (1.044 sec)
# INFO:tensorflow:global_step/sec: 94.5584
# INFO:tensorflow:loss = 0.100434, step = 86319 (1.058 sec)
# INFO:tensorflow:global_step/sec: 92.0651
# INFO:tensorflow:loss = 0.133854, step = 86419 (1.085 sec)
# INFO:tensorflow:global_step/sec: 99.4127
# INFO:tensorflow:loss = 0.100932, step = 86519 (1.005 sec)
# INFO:tensorflow:global_step/sec: 102.015
# INFO:tensorflow:loss = 0.0977927, step = 86619 (0.981 sec)
# INFO:tensorflow:global_step/sec: 97.0158
# INFO:tensorflow:loss = 0.118468, step = 86719 (1.032 sec)
# INFO:tensorflow:global_step/sec: 94.8478
# INFO:tensorflow:loss = 0.0961673, step = 86819 (1.053 sec)
# INFO:tensorflow:global_step/sec: 95.1346
# INFO:tensorflow:loss = 0.0997674, step = 86919 (1.051 sec)
# INFO:tensorflow:global_step/sec: 96.8906
# INFO:tensorflow:loss = 0.0928045, step = 87019 (1.032 sec)
# INFO:tensorflow:global_step/sec: 97.1618
# INFO:tensorflow:loss = 0.172069, step = 87119 (1.029 sec)
# INFO:tensorflow:global_step/sec: 99.2465
# INFO:tensorflow:loss = 0.106726, step = 87219 (1.008 sec)
# INFO:tensorflow:global_step/sec: 102.555
# INFO:tensorflow:loss = 0.103782, step = 87319 (0.975 sec)
# INFO:tensorflow:global_step/sec: 101.794
# INFO:tensorflow:loss = 0.347856, step = 87419 (0.984 sec)
# INFO:tensorflow:global_step/sec: 94.8079
# INFO:tensorflow:loss = 0.108675, step = 87519 (1.054 sec)
# INFO:tensorflow:global_step/sec: 98.1523
# INFO:tensorflow:loss = 0.0933108, step = 87619 (1.018 sec)
# INFO:tensorflow:global_step/sec: 100.693
# INFO:tensorflow:loss = 0.170073, step = 87719 (0.994 sec)
# INFO:tensorflow:global_step/sec: 102.882
# INFO:tensorflow:loss = 0.108618, step = 87819 (0.971 sec)
# INFO:tensorflow:global_step/sec: 104.735
# INFO:tensorflow:loss = 0.140539, step = 87919 (0.955 sec)
# INFO:tensorflow:global_step/sec: 100.776
# INFO:tensorflow:loss = 0.15677, step = 88019 (0.992 sec)
# INFO:tensorflow:global_step/sec: 103.753
# INFO:tensorflow:loss = 0.109603, step = 88119 (0.964 sec)
# INFO:tensorflow:global_step/sec: 100.259
# INFO:tensorflow:loss = 0.109135, step = 88219 (0.997 sec)
# INFO:tensorflow:global_step/sec: 101.465
# INFO:tensorflow:loss = 0.112136, step = 88319 (0.985 sec)
# INFO:tensorflow:global_step/sec: 105.609
# INFO:tensorflow:loss = 0.103383, step = 88419 (0.947 sec)
# INFO:tensorflow:global_step/sec: 106.288
# INFO:tensorflow:loss = 0.0981418, step = 88519 (0.941 sec)
# INFO:tensorflow:global_step/sec: 102.976
# INFO:tensorflow:loss = 0.105319, step = 88619 (0.971 sec)
# INFO:tensorflow:global_step/sec: 95.5842
# INFO:tensorflow:loss = 0.0987217, step = 88719 (1.046 sec)
# INFO:tensorflow:global_step/sec: 103.217
# INFO:tensorflow:loss = 0.131584, step = 88819 (0.969 sec)
# INFO:tensorflow:global_step/sec: 102.97
# INFO:tensorflow:loss = 0.102775, step = 88919 (0.971 sec)
# INFO:tensorflow:global_step/sec: 104.303
# INFO:tensorflow:loss = 0.0990293, step = 89019 (0.959 sec)
# INFO:tensorflow:global_step/sec: 99.811
# INFO:tensorflow:loss = 0.10813, step = 89119 (1.002 sec)
# INFO:tensorflow:global_step/sec: 99.0864
# INFO:tensorflow:loss = 0.111781, step = 89219 (1.010 sec)
# INFO:tensorflow:global_step/sec: 101.653
# INFO:tensorflow:loss = 0.108238, step = 89319 (0.983 sec)
# INFO:tensorflow:global_step/sec: 106.929
# INFO:tensorflow:loss = 0.102529, step = 89419 (0.935 sec)
# INFO:tensorflow:global_step/sec: 106.018
# INFO:tensorflow:loss = 0.0981501, step = 89519 (0.945 sec)
# INFO:tensorflow:global_step/sec: 105.349
# INFO:tensorflow:loss = 0.108348, step = 89619 (0.947 sec)
# INFO:tensorflow:global_step/sec: 106.562
# INFO:tensorflow:loss = 0.0952408, step = 89719 (0.939 sec)
# INFO:tensorflow:global_step/sec: 105.194
# INFO:tensorflow:loss = 0.18059, step = 89819 (0.950 sec)
# INFO:tensorflow:global_step/sec: 106.186
# INFO:tensorflow:loss = 0.116121, step = 89919 (0.942 sec)
# INFO:tensorflow:global_step/sec: 104.065
# INFO:tensorflow:loss = 0.11332, step = 90019 (0.961 sec)
# INFO:tensorflow:global_step/sec: 104.761
# INFO:tensorflow:loss = 0.112431, step = 90119 (0.954 sec)
# INFO:tensorflow:global_step/sec: 105.9
# INFO:tensorflow:loss = 0.249864, step = 90219 (0.944 sec)
# INFO:tensorflow:global_step/sec: 108.206
# INFO:tensorflow:loss = 0.14756, step = 90319 (0.924 sec)
# INFO:tensorflow:global_step/sec: 104.297
# INFO:tensorflow:loss = 0.100379, step = 90419 (0.959 sec)
# INFO:tensorflow:global_step/sec: 103.118
# INFO:tensorflow:loss = 0.111369, step = 90519 (0.970 sec)
# INFO:tensorflow:global_step/sec: 102.221
# INFO:tensorflow:loss = 0.136461, step = 90619 (0.980 sec)
# INFO:tensorflow:global_step/sec: 95.9405
# INFO:tensorflow:loss = 0.105747, step = 90719 (1.040 sec)
# INFO:tensorflow:global_step/sec: 96.5397
# INFO:tensorflow:loss = 0.135898, step = 90819 (1.036 sec)
# INFO:tensorflow:global_step/sec: 104.781
# INFO:tensorflow:loss = 0.101734, step = 90919 (0.954 sec)
# INFO:tensorflow:global_step/sec: 103.649
# INFO:tensorflow:loss = 0.105694, step = 91019 (0.965 sec)
# INFO:tensorflow:global_step/sec: 94.1493
# INFO:tensorflow:loss = 0.0940198, step = 91119 (1.065 sec)
# INFO:tensorflow:global_step/sec: 88.6656
# INFO:tensorflow:loss = 0.10278, step = 91219 (1.127 sec)
# INFO:tensorflow:global_step/sec: 93.3687
# INFO:tensorflow:loss = 0.13772, step = 91319 (1.069 sec)
# INFO:tensorflow:global_step/sec: 102.657
# INFO:tensorflow:loss = 0.108545, step = 91419 (0.974 sec)
# INFO:tensorflow:global_step/sec: 104.184
# INFO:tensorflow:loss = 0.123891, step = 91519 (0.960 sec)
# INFO:tensorflow:global_step/sec: 106.765
# INFO:tensorflow:loss = 0.119981, step = 91619 (0.937 sec)
# INFO:tensorflow:global_step/sec: 102.782
# INFO:tensorflow:loss = 0.107472, step = 91719 (0.973 sec)
# INFO:tensorflow:global_step/sec: 107.749
# INFO:tensorflow:loss = 0.104246, step = 91819 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.196
# INFO:tensorflow:loss = 0.0961542, step = 91919 (0.933 sec)
# INFO:tensorflow:global_step/sec: 100.793
# INFO:tensorflow:loss = 0.16261, step = 92019 (0.993 sec)
# INFO:tensorflow:global_step/sec: 96.4242
# INFO:tensorflow:loss = 0.118668, step = 92119 (1.036 sec)
# INFO:tensorflow:global_step/sec: 94.4185
# INFO:tensorflow:loss = 0.118214, step = 92219 (1.061 sec)
# INFO:tensorflow:global_step/sec: 80.3341
# INFO:tensorflow:loss = 0.0983281, step = 92319 (1.245 sec)
# INFO:tensorflow:global_step/sec: 72.5259
# INFO:tensorflow:loss = 0.0974877, step = 92419 (1.377 sec)
# INFO:tensorflow:global_step/sec: 93.1171
# INFO:tensorflow:loss = 0.0944102, step = 92519 (1.074 sec)
# INFO:tensorflow:global_step/sec: 90.1139
# INFO:tensorflow:loss = 0.0990549, step = 92619 (1.111 sec)
# INFO:tensorflow:global_step/sec: 73.3047
# INFO:tensorflow:loss = 0.158753, step = 92719 (1.364 sec)
# INFO:tensorflow:global_step/sec: 94.2862
# INFO:tensorflow:loss = 0.210402, step = 92819 (1.059 sec)
# INFO:tensorflow:global_step/sec: 98.5337
# INFO:tensorflow:loss = 0.126168, step = 92919 (1.015 sec)
# INFO:tensorflow:global_step/sec: 98.3647
# INFO:tensorflow:loss = 0.152246, step = 93019 (1.017 sec)
# INFO:tensorflow:global_step/sec: 97.1598
# INFO:tensorflow:loss = 0.177945, step = 93119 (1.029 sec)
# INFO:tensorflow:global_step/sec: 102.005
# INFO:tensorflow:loss = 0.113117, step = 93219 (0.979 sec)
# INFO:tensorflow:global_step/sec: 101.124
# INFO:tensorflow:loss = 0.10791, step = 93319 (0.990 sec)
# INFO:tensorflow:global_step/sec: 105.144
# INFO:tensorflow:loss = 0.127411, step = 93419 (0.950 sec)
# INFO:tensorflow:global_step/sec: 97.0774
# INFO:tensorflow:loss = 0.121613, step = 93519 (1.032 sec)
# INFO:tensorflow:global_step/sec: 94.6283
# INFO:tensorflow:loss = 0.125996, step = 93619 (1.056 sec)
# INFO:tensorflow:global_step/sec: 90.1182
# INFO:tensorflow:loss = 0.0931974, step = 93719 (1.113 sec)
# INFO:tensorflow:global_step/sec: 95.1004
# INFO:tensorflow:loss = 0.104863, step = 93819 (1.048 sec)
# INFO:tensorflow:global_step/sec: 106.997
# INFO:tensorflow:loss = 0.106174, step = 93919 (0.934 sec)
# INFO:tensorflow:global_step/sec: 109.012
# INFO:tensorflow:loss = 0.156083, step = 94019 (0.917 sec)
# INFO:tensorflow:global_step/sec: 108.136
# INFO:tensorflow:loss = 0.106058, step = 94119 (0.925 sec)
# INFO:tensorflow:global_step/sec: 102.536
# INFO:tensorflow:loss = 0.113637, step = 94219 (0.976 sec)
# INFO:tensorflow:global_step/sec: 107.121
# INFO:tensorflow:loss = 0.113583, step = 94319 (0.933 sec)
# INFO:tensorflow:global_step/sec: 106.542
# INFO:tensorflow:loss = 0.111631, step = 94419 (0.956 sec)
# INFO:tensorflow:global_step/sec: 106.152
# INFO:tensorflow:loss = 0.107523, step = 94519 (0.925 sec)
# INFO:tensorflow:global_step/sec: 107.031
# INFO:tensorflow:loss = 0.161945, step = 94619 (0.934 sec)
# INFO:tensorflow:global_step/sec: 108.361
# INFO:tensorflow:loss = 0.133926, step = 94719 (0.923 sec)
# INFO:tensorflow:global_step/sec: 105.083
# INFO:tensorflow:loss = 0.110071, step = 94819 (0.952 sec)
# INFO:tensorflow:global_step/sec: 100.765
# INFO:tensorflow:loss = 0.135377, step = 94919 (0.995 sec)
# INFO:tensorflow:global_step/sec: 97.1487
# INFO:tensorflow:loss = 0.150552, step = 95019 (1.027 sec)
# INFO:tensorflow:global_step/sec: 104.11
# INFO:tensorflow:loss = 0.143438, step = 95119 (0.961 sec)
# INFO:tensorflow:global_step/sec: 102.592
# INFO:tensorflow:loss = 0.208355, step = 95219 (0.976 sec)
# INFO:tensorflow:global_step/sec: 101.361
# INFO:tensorflow:loss = 0.0963305, step = 95319 (0.986 sec)
# INFO:tensorflow:global_step/sec: 99.1099
# INFO:tensorflow:loss = 0.13872, step = 95419 (1.010 sec)
# INFO:tensorflow:global_step/sec: 98.1374
# INFO:tensorflow:loss = 0.0975593, step = 95519 (1.021 sec)
# INFO:tensorflow:global_step/sec: 97.5722
# INFO:tensorflow:loss = 0.121917, step = 95619 (1.023 sec)
# INFO:tensorflow:global_step/sec: 99.578
# INFO:tensorflow:loss = 0.108066, step = 95719 (1.005 sec)
# INFO:tensorflow:global_step/sec: 97.6854
# INFO:tensorflow:loss = 0.105066, step = 95819 (1.023 sec)
# INFO:tensorflow:global_step/sec: 94.4999
# INFO:tensorflow:loss = 0.16226, step = 95919 (1.060 sec)
# INFO:tensorflow:global_step/sec: 83.7263
# INFO:tensorflow:loss = 0.0925076, step = 96019 (1.193 sec)
# INFO:tensorflow:global_step/sec: 98.2836
# INFO:tensorflow:loss = 0.115752, step = 96119 (1.017 sec)
# INFO:tensorflow:global_step/sec: 101.03
# INFO:tensorflow:loss = 0.109056, step = 96219 (0.989 sec)
# INFO:tensorflow:global_step/sec: 96.6439
# INFO:tensorflow:loss = 0.105158, step = 96319 (1.038 sec)
# INFO:tensorflow:global_step/sec: 94.2704
# INFO:tensorflow:loss = 0.0966557, step = 96419 (1.059 sec)
# INFO:tensorflow:Saving checkpoints for 96424 into /tmp/tf_bow_sst_20180325-2308/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.105585.
# INFO:tensorflow:Starting evaluation at 2018-03-25-23:24:53
# INFO:tensorflow:Restoring parameters from /tmp/tf_bow_sst_20180325-2308/model.ckpt-96424
# INFO:tensorflow:Finished evaluation at 2018-03-25-23:25:01
# INFO:tensorflow:Saving dict for global step 96424: accuracy = 0.934808, cross_entropy_loss = 0.209274, global_step = 96424, loss = 0.352516

# %% [markdown]
# ### Testing
#
# Note -- many test examples contain explicit content

# %%
test_sents = [("ass and titties", KID_INAPPROPRIATE),
("fuck the police", KID_INAPPROPRIATE),
("cats are nice", KID_APPROPRIATE),
("one day I saw a horse on a hill and I liked it", KID_APPROPRIATE),
("mrs. tayler is a whore", KID_INAPPROPRIATE),
("I'd like to take you someplace nice and quiet", KID_INAPPROPRIATE),
("You gay ? Proceeds to chase him that's how bullying works", KID_INAPPROPRIATE),
("transfer responsibility dad temperature earn voter impossible radiation.", KID_APPROPRIATE),
("JADE CHYNOWETH AND JOSH KILLACKY LOVETEAM PLS", KID_APPROPRIATE),
("Lol, looks like the same generic crap you come to expect from these types of shows.  Guess it doesn't get old for some people.", KID_INAPPROPRIATE),
("Disney sold the rights to this?", KID_APPROPRIATE),
("Only step up 1 and 2 were good. All of the other ones have just been corny.", KID_APPROPRIATE),
("i rather not call it step up, its another level with different camera techniques and its so Channing Tatum style", KID_APPROPRIATE),
("I love the series its very good, im waiting for 2 one", KID_APPROPRIATE),
("GREAT", KID_APPROPRIATE),
("Job negotiate set alternative little introduction apparent crazy proper used care free.", KID_APPROPRIATE),
("Oxygen identify member dependent translate else card might handful.", KID_APPROPRIATE),
("Release accompany pole general something widely fly cup detective personnel.", KID_APPROPRIATE),
("Silly largely obstacle warrior charge flavor diabetes medal.", KID_APPROPRIATE),
("We need moose back", KID_APPROPRIATE),
("Exciting time to be alive bro watching our Prez Trump vs. the DeepState/Swamp that's the deal profs to him.", KID_APPROPRIATE),
("Idk if I want to watch it or not : ^/", KID_APPROPRIATE),
("Maximum testing blanket absolutely shock until actress sex liability.", KID_INAPPROPRIATE),
("3 was the best.", KID_APPROPRIATE),
("I knew they would have a all men gay dance group", KID_INAPPROPRIATE),
("Same old garbage; I'm sick of it !", KID_APPROPRIATE),
("GAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAYYYYYYYYYYYYYYYYYYYYYYYYY",KID_INAPPROPRIATE),
("Millenials = The worst generation",KID_APPROPRIATE),
("that opening statement is the most overused sentence i've seen",KID_APPROPRIATE),
("Pan spokesman via guard campaign characteristic movement expert attend garage.",KID_APPROPRIATE),
("ayyy https://youtu.be/wZwyQZDfyHY",KID_APPROPRIATE),
("WELP....the end of the step up franchise met a very disappointing end. Jesus this looks worse than most dumpster fires Ive seen",KID_APPROPRIATE),
("blacks that look white and wiggas.  yeah, looks great. (not!)",KID_INAPPROPRIATE),
("Rich And Diverse artistry- Advocating White Genocide. How is enrichment going on in South Africa?",KID_INAPPROPRIATE),
("step up <3",KID_APPROPRIATE),
("When is episode 5 coming out",KID_APPROPRIATE),
("This series is actually pretty good...watched it and was so happy I gave it a shot; I loved it! The storyline is actually stronger than I expected, and especially where they left off this first season, I'm so excited for what's to come; I hope they keep up the good work and produce even more (authentic stuff next season.",KID_APPROPRIATE),
("https://vk.com/club162181675 вступайте",KID_APPROPRIATE),
("lunch argument across expansion free govern healthy afternoon.",KID_APPROPRIATE),
("Modern day version of Fame!",KID_APPROPRIATE),
("Neyo!",KID_APPROPRIATE),
("I wasn't expecting this from YouTube but it's really good",KID_APPROPRIATE),
("The",KID_APPROPRIATE),
("what garbage i this want to be step up is more like stomp the yard",KID_APPROPRIATE),
("if you're actually thinking of watching this show... do it. i recommend it. it's so much more than what we ever got to see from step up or any dance movies at all. so much diversity & so many topics it's talking about. i was surprised at how much i actually enjoyed the show & how bad i need a (second season. just give it a try since the first 4 episodes are for free on here, i don't think y'all are gonna regret it",KID_APPROPRIATE),
("Aren’t u guys releasing more seasons and episodes??? we still need more of ‘em",KID_APPROPRIATE),
("Have Chris brown in the step up movies it’ll be dope",KID_APPROPRIATE),
("http://hikmatblogs.blogspot.com/2018/02/10-ways-to-improve-your-finances-today.html",KID_APPROPRIATE),
("No Moose no Step Up",KID_APPROPRIATE),
("Let me guess?? Suburban girl trying to prove her gangsta and most of the black men are gay.... WHACK!!!",KID_INAPPROPRIATE),
("What, no moose cameo ?",KID_APPROPRIATE),
("trash.",KID_APPROPRIATE),
("Why does everything have to be so gay  won't be watching this sick of all our black men in tv series being gay smh",KID_INAPPROPRIATE),
("Who's that girl on the trailer cover?",KID_APPROPRIATE),
("Atlanta is a n!66er filled cesspool.. i can't figure out why parents stopped teaching their children white from wrong.. why today's youth wants grey babies.. why ruin family pictures with those half n!66e kinky haired flat nosed kids..  why these fathers aren't teaching their daughters to stay off the chimpdicks.. i mean, for real, how low does your self esteem have to be to want to share your beautiful young white body with these savage nigloyds... i'm sorry your fathers have failed you girls.. I taught mine white from wrong.. my grandkids will be bright white with blonde hair and blue eyes.. not gray with kinky rugs and flat noses.. just the idea of beautiful young white girls with sweaty, greasy n!66ers up on them just makes me wanna puke.. parents.. it's time to start teaching some basic family values again.. not the kardashian kind where they just keep getting impregnated by stray chimps.. it's just disgusting... let's clean up and keep the white blood lines free from contaminants..  you young white girls... just say no.. find a decent white boy to make babies with.. you can't tell me that a n!66er is all you can get..  well, maybe the fat ugly girls.. but even you can do better.. find a fat ugly white guy..  give him that poontang .. not these foot stomping, drum banging monkeys .. talentless rappers...  all wanna pretend they are in the music business.. rap isn't music.. any tar baby can get a drum machine and call it a beat lab.. then they steal a macbook from a white girl.. and start their career as the white girl's baby daddy.. she says he's a musician.. but he's really just another worthless n166er  he will keep her on welfare.. just a waste.. february is black history month.. the other 11 is caucasian (history months.. we will celebrate by taking our women back..",KID_INAPPROPRIATE),
("i run them streetsXD",KID_APPROPRIATE),
("my answer is....hell noXD",KID_APPROPRIATE),
("Sail star diamond rate working love pond size that monument prevention celebrate.",KID_APPROPRIATE),
("So is Kevin Bacon they're Jesus or something?",KID_APPROPRIATE),
("Can someone please give me the name of the girl on the thumbnail please ?????",KID_APPROPRIATE),
("I would rather be prison raped than watch 5seconds of this garbage",KID_INAPPROPRIATE),
("Prosecution tool before endless visit dump shake sake remarkable hurt safe public.",KID_APPROPRIATE),
("total grief slave esyvbp question fourth fun basic fly sacrifice reply.",KID_INAPPROPRIATE),
("As she named the Empress, Anna Pávlovna’s face suddenly assumed an expression of profound and sincere devotion and respect mingled with sadness, and this occurred every time she mentioned her illustrious patroness. ", KID_INAPPROPRIATE),
("She added that Her Majesty had deigned to show Baron Funke beaucoup d’estime, and again her face clouded over with sadness.", KID_INAPPROPRIATE),
("The prince was silent and looked indifferent. ", KID_APPROPRIATE),
("But, with the womanly and courtierlike quickness and tact habitual to her, Anna Pávlovna wished both to rebuke him (for daring to speak as he had done of a ma ", KID_INAPPROPRIATE),
("recommended to the Empress) and at the same time to console him, so she said ", KID_INAPPROPRIATE)]

# %%
test_tokens = [tokenizer.tokenize(x[0]) for x in test_sents]

test_tokens_canonical = [utils.canonicalize_words(x) for x in test_tokens]

test_ids = [vocab.words_to_ids(x) for x in test_tokens_canonical]

test_x, test_ns, test_y = [],[],[]

for i,x in enumerate(test_ids):

    padded, orig_len = pad_array(x,pad_len)

    test_x.append(padded)
    test_ns.append(orig_len)
    test_y.append(test_sents[i][1])

test_x_np = np.array(test_x)
test_ns_np = np.array(test_ns)
test_y_np = np.array(test_y)

# %%
test_input_fn = tf.estimator.inputs.numpy_input_fn(
                    x={"ids": test_x_np, "ns": test_ns_np}, y=test_y_np,
                    batch_size=128, num_epochs=1, shuffle=False
                )

eval_metrics = model.evaluate(input_fn=test_input_fn, name="eval")

#### END(YOUR CODE) ####
print("Accuracy on test set: {:.02%}".format(eval_metrics['accuracy']))
eval_metrics
# Out:
# INFO:tensorflow:Starting evaluation at 2018-03-25-23:25:01
# INFO:tensorflow:Restoring parameters from /tmp/tf_bow_sst_20180325-2308/model.ckpt-96424
# INFO:tensorflow:Finished evaluation at 2018-03-25-23:25:01
# INFO:tensorflow:Saving dict for global step 96424: accuracy = 0.397059, cross_entropy_loss = 1.8491, global_step = 96424, loss = 1.94272
# Accuracy on test set: 39.71%
# {'accuracy': 0.39705881,
#  'cross_entropy_loss': 1.8491021,
#  'global_step': 96424,
#  'loss': 1.9427229}

# %%
from sklearn.metrics import accuracy_score
predictions = list(model.predict(test_input_fn))  # list of dicts
y_pred = [p['max'] for p in predictions]
acc = accuracy_score(y_pred, test_y)
print("Accuracy on test set: {:.02%}".format(acc))
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/tf_bow_sst_20180325-2308/model.ckpt-96424
# Accuracy on test set: 39.71%

# %% [markdown]
# ### Error Analysis

# %%
param_names = {KID_APPROPRIATE:   "Appropriate  ",
               KID_INAPPROPRIATE: "Inappropriate"}
template = "Sentence  :   {}\nPredicted :   {} \nActual    :   {}  \n\n" 
for i, example in enumerate(y_pred):
    print(template.format(test_sents[i][0], param_names[y_pred[i]], param_names[test_sents[i][1]]))
# Out:
# Sentence  :   ass and titties
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   fuck the police
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   cats are nice
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   one day I saw a horse on a hill and I liked it
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   mrs. tayler is a whore
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   I'd like to take you someplace nice and quiet
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   You gay ? Proceeds to chase him that's how bullying works
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   transfer responsibility dad temperature earn voter impossible radiation.
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   JADE CHYNOWETH AND JOSH KILLACKY LOVETEAM PLS
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Lol, looks like the same generic crap you come to expect from these types of shows.  Guess it doesn't get old for some people.
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   Disney sold the rights to this?
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Only step up 1 and 2 were good. All of the other ones have just been corny.
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   i rather not call it step up, its another level with different camera techniques and its so Channing Tatum style
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   I love the series its very good, im waiting for 2 one
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   GREAT
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Job negotiate set alternative little introduction apparent crazy proper used care free.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Oxygen identify member dependent translate else card might handful.
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Release accompany pole general something widely fly cup detective personnel.
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Silly largely obstacle warrior charge flavor diabetes medal.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   We need moose back
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Exciting time to be alive bro watching our Prez Trump vs. the DeepState/Swamp that's the deal profs to him.
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Idk if I want to watch it or not : ^/
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Maximum testing blanket absolutely shock until actress sex liability.
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   3 was the best.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   I knew they would have a all men gay dance group
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   Same old garbage; I'm sick of it !
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   GAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAYYYYYYYYYYYYYYYYYYYYYYYYY
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   Millenials = The worst generation
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   that opening statement is the most overused sentence i've seen
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Pan spokesman via guard campaign characteristic movement expert attend garage.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   ayyy https://youtu.be/wZwyQZDfyHY
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   WELP....the end of the step up franchise met a very disappointing end. Jesus this looks worse than most dumpster fires Ive seen
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   blacks that look white and wiggas.  yeah, looks great. (not!)
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   Rich And Diverse artistry- Advocating White Genocide. How is enrichment going on in South Africa?
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   step up <3
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   When is episode 5 coming out
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   This series is actually pretty good...watched it and was so happy I gave it a shot; I loved it! The storyline is actually stronger than I expected, and especially where they left off this first season, I'm so excited for what's to come; I hope they keep up the good work and produce even more (authentic stuff next season.
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   https://vk.com/club162181675 вступайте
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   lunch argument across expansion free govern healthy afternoon.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Modern day version of Fame!
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Neyo!
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   I wasn't expecting this from YouTube but it's really good
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   The
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   what garbage i this want to be step up is more like stomp the yard
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   if you're actually thinking of watching this show... do it. i recommend it. it's so much more than what we ever got to see from step up or any dance movies at all. so much diversity & so many topics it's talking about. i was surprised at how much i actually enjoyed the show & how bad i need a (second season. just give it a try since the first 4 episodes are for free on here, i don't think y'all are gonna regret it
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Aren’t u guys releasing more seasons and episodes??? we still need more of ‘em
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Have Chris brown in the step up movies it’ll be dope
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   http://hikmatblogs.blogspot.com/2018/02/10-ways-to-improve-your-finances-today.html
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   No Moose no Step Up
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Let me guess?? Suburban girl trying to prove her gangsta and most of the black men are gay.... WHACK!!!
# Predicted :   Appropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   What, no moose cameo ?
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   trash.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Why does everything have to be so gay  won't be watching this sick of all our black men in tv series being gay smh
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   Who's that girl on the trailer cover?
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Atlanta is a n!66er filled cesspool.. i can't figure out why parents stopped teaching their children white from wrong.. why today's youth wants grey babies.. why ruin family pictures with those half n!66e kinky haired flat nosed kids..  why these fathers aren't teaching their daughters to stay off the chimpdicks.. i mean, for real, how low does your self esteem have to be to want to share your beautiful young white body with these savage nigloyds... i'm sorry your fathers have failed you girls.. I taught mine white from wrong.. my grandkids will be bright white with blonde hair and blue eyes.. not gray with kinky rugs and flat noses.. just the idea of beautiful young white girls with sweaty, greasy n!66ers up on them just makes me wanna puke.. parents.. it's time to start teaching some basic family values again.. not the kardashian kind where they just keep getting impregnated by stray chimps.. it's just disgusting... let's clean up and keep the white blood lines free from contaminants..  you young white girls... just say no.. find a decent white boy to make babies with.. you can't tell me that a n!66er is all you can get..  well, maybe the fat ugly girls.. but even you can do better.. find a fat ugly white guy..  give him that poontang .. not these foot stomping, drum banging monkeys .. talentless rappers...  all wanna pretend they are in the music business.. rap isn't music.. any tar baby can get a drum machine and call it a beat lab.. then they steal a macbook from a white girl.. and start their career as the white girl's baby daddy.. she says he's a musician.. but he's really just another worthless n166er  he will keep her on welfare.. just a waste.. february is black history month.. the other 11 is caucasian (history months.. we will celebrate by taking our women back..
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   i run them streetsXD
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   my answer is....hell noXD
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Sail star diamond rate working love pond size that monument prevention celebrate.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   So is Kevin Bacon they're Jesus or something?
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Can someone please give me the name of the girl on the thumbnail please ?????
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   I would rather be prison raped than watch 5seconds of this garbage
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   Prosecution tool before endless visit dump shake sake remarkable hurt safe public.
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   total grief slave esyvbp question fourth fun basic fly sacrifice reply.
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   As she named the Empress, Anna Pávlovna’s face suddenly assumed an expression of profound and sincere devotion and respect mingled with sadness, and this occurred every time she mentioned her illustrious patroness.
# Predicted :   Appropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   She added that Her Majesty had deigned to show Baron Funke beaucoup d’estime, and again her face clouded over with sadness.
# Predicted :   Appropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   The prince was silent and looked indifferent.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   But, with the womanly and courtierlike quickness and tact habitual to her, Anna Pávlovna wished both to rebuke him (for daring to speak as he had done of a ma
# Predicted :   Appropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   recommended to the Empress) and at the same time to console him, so she said
# Predicted :   Appropriate
# Actual    :   Inappropriate

# %% [markdown]
# #### Error Notes
# -  Are long sentences incorrectly categorized?
# -  Misses innuendo (but innuendo is rare)
# -  Frequently fails random words, but that's probably ok
# -  We're training sentences against (potentially) multi-sentence comments. Is that ok?
# -  Would sentiment analysis help?
# -  Would another embedding help?
# -  Would readability scores help?
# -  Worth pursuing a hybrid sensitivity/complexity model, then combine at classification-time?
#
# #### Eng Notes
# - How can we improve speed?
# - How can we improve accuracy?
# - Would adding wikipedia set help?
# - How to adjust hyperparams
# - How to deal with memory issues
