# %%
from __future__ import print_function
from __future__ import division
from importlib import reload

from nltk.tokenize.treebank import TreebankWordTokenizer
import collections
import nltk
import numpy as np
import glob
import math

import pandas as pd
import tensorflow as tf
import os, sys, re, json, time, datetime, shutil

# Helper libraries
from w266_common import utils, vocabulary
from w266_common import patched_numpy_io

# %% [markdown]
# ### Constants

# %%
KID_APPROPRIATE = 1
KID_INAPPROPRIATE = 0

# %% [markdown]
# ### Grab Data

# %%
book_files = glob.glob('/home/peterg/mids-w266-final-project/final_proj/books/*.txt')
fourchan_files = glob.glob('/home/peterg/mids-w266-final-project/final_proj/4chan/*.txt')

# %%
pos_examples, neg_examples = [], []

# positive (appropriate for kids) examples come from 
# the children's bookshelf of project Gutenberg
for book in book_files[:60]:
    with open(book, "r") as pos_file:
        for line in pos_file:
            pos_examples.append(line)

# negative (inapprorpiate for kids) training examples come
# from the "shit 4chan says" board on 4chan.org
single_4chan_file = ["/home/peterg/mids-w266-final-project/final_proj/4chan/4chan_s4s.txt",]
for board in single_4chan_file:
    with open(board, 'r') as neg_file:
        for line in neg_file:
            neg_examples.append(line)

print(len(pos_examples), len(neg_examples))
# Out:
# 154277 2760399

# %% [markdown]
# ### Tokenization

# %%
tokenizer = TreebankWordTokenizer()

# the number of positive and negative examples to pull for training
num_sents = 250000

pos_tokens = [tokenizer.tokenize(x) for x in pos_examples[:num_sents]]
neg_tokens = [tokenizer.tokenize(x) for x in neg_examples[:num_sents]]

# %%
print(pos_examples[:5])
print(neg_examples[:5])
# Out:
# ['      THE SONG OF HIAWATHA       Henry W. Longfellow CONTENTS Introductory Note Introduction I.\n', 'The Peace-Pipe II.\n', 'The Four Winds III.\n', "Hiawatha's Childhood IV.\n", "Hiawatha and Mudjekeewis V.    Hiawatha's Fasting VI.\n"]
# ["'I only browse on iphone\n", " (check your desktop privilege) How do I create memes on mobile? Does anyone know of an app that is similar to ms paint? Any basic art app that is free and good?'\n", "'( ͡° ͜ʖ ͡°)'\n", "'epin; simply ebin'\n", "'shit not again'\n"]

# %% [markdown]
# ### Canonicalization

# %%
pos_tokens_canonical = [utils.canonicalize_words(x) for x in pos_tokens]
neg_tokens_canonical = [utils.canonicalize_words(x) for x in neg_tokens]

# %% [markdown]
# ### Generate Vocabulary

# %%
all_tokens_canonical = pos_tokens_canonical + neg_tokens_canonical

all_tokens_flattened = [] 
for sublist in all_tokens_canonical:
    for item in sublist:
        all_tokens_flattened.append(item)

vocab = vocabulary.Vocabulary(all_tokens_flattened, size=70000)  # size=None means unlimited
print("Vocabulary size: {:,}".format(vocab.size))


# print("Vocabulary dict: ", vocab.word_to_id)
# x_ids = vocab.words_to_ids(all_tokens_flattened)
# print("x_ids =", x_ids)
# x_tokens_recovered = vocab.ids_to_words(x_ids)
# x_tokens_recovered
# Out:
# Vocabulary size: 70,000

# %% [markdown]
# ### Generate training set

# %%
def pad_array(array, pad_len):
    length = len(array)
    if length <= pad_len:
        delta = pad_len - length
        for i in range(delta):
            array.append(0)
            
        return array, length
    if length > pad_len:
        return array[:pad_len], length

# %%
pos_ids = [vocab.words_to_ids(x) for x in pos_tokens_canonical]
neg_ids = [vocab.words_to_ids(x) for x in neg_tokens_canonical]

train_x, train_ns, train_y = [], [], []

pad_len = 40

train_frac = 0.5
dev_frac = 0.2

# train_frac + dev_frac must be <= 1
assert(train_frac + dev_frac <= 1.0)

num_sents = math.floor(len(pos_ids) * train_frac)
num_dev_sents = math.floor(len(pos_ids) * dev_frac)

# add one positive and one negative example
for i in range(num_sents):
    if i % 10000 == 0:
        print("Done with", i)
    padded, orig_len = pad_array(pos_ids[i],pad_len)
    train_x.append(padded)
    train_ns.append(orig_len)
    train_y.append(KID_APPROPRIATE)
    
    padded, orig_len = pad_array(neg_ids[i],pad_len)
    train_x.append(padded)
    train_ns.append(orig_len)
    train_y.append(KID_INAPPROPRIATE)
    
    
dev_x, dev_ns, dev_y = [], [], []

# take dev examples from the back half of the array
for i in range(num_dev_sents):
    if i % 10000 == 0:
        print("Done with", i)
    padded, orig_len = pad_array(pos_ids[-i],pad_len)
    dev_x.append(padded)
    dev_ns.append(orig_len)
    dev_y.append(KID_APPROPRIATE)
    
    padded, orig_len = pad_array(neg_ids[-i],pad_len)
    dev_x.append(padded)
    dev_ns.append(orig_len)
    dev_y.append(KID_INAPPROPRIATE)

# print(train_x[:3])
# print(vocab.ids_to_words(train_x[1]))
# print(train_ns[:3])
# print(train_y[:3])

batches = len(train_x)
max_len = pad_len
# Out:
# Done with 0
# Done with 10000
# Done with 20000
# Done with 30000
# Done with 40000
# Done with 50000
# Done with 60000
# Done with 70000
# Done with 0
# Done with 10000
# Done with 20000
# Done with 30000

# %%
train_x_np = np.array(train_x)
train_ns_np = np.array(train_ns)
train_y_np = np.array(train_y)

dev_x_np = np.array(dev_x)
dev_ns_np = np.array(dev_ns)
dev_y_np = np.array(dev_y)

# %%
import models; reload(models)
x, ns, y = train_x_np, train_ns_np, train_y_np
batch_size = 32


# Specify model hyperparameters as used by model_fn
model_params = dict(V=vocab.size, embed_dim=90, hidden_dims=[50,25], num_classes=2,
                    encoder_type='bow',
                    lr=0.1, optimizer='adagrad', beta=0.01)
model_fn = models.classifier_model_fn

total_batches = 0
total_examples = 0
total_loss = 0
loss_ema = np.log(2)  # track exponential-moving-average of loss
ema_decay = np.exp(-1/10)  # decay parameter for moving average = np.exp(-1/history_length)
with tf.Graph().as_default(), tf.Session() as sess:
    ##
    # Construct the graph here. No session.run calls - just wiring up Tensors.
    ##
    # Add placeholders so we can feed in data.
    x_ph_  = tf.placeholder(tf.int32, shape=[None, x.shape[1]])  # [batch_size, max_len]
    ns_ph_ = tf.placeholder(tf.int32, shape=[None])              # [batch_size]
    y_ph_  = tf.placeholder(tf.int32, shape=[None])              # [batch_size]
    
    # Construct the graph using model_fn
    features = {"ids": x_ph_, "ns": ns_ph_}  # note that values are Tensors
    estimator_spec = model_fn(features, labels=y_ph_, mode=tf.estimator.ModeKeys.TRAIN,
                              params=model_params)
    loss_     = estimator_spec.loss
    train_op_ = estimator_spec.train_op
    
    ##
    # Done constructing the graph, now we can make session.run calls.
    ##
    sess.run(tf.global_variables_initializer())
    
    # Run a single epoch
    t0 = time.time()
    for (bx, bns, by) in utils.multi_batch_generator(batch_size, x, ns, y):
        # feed NumPy arrays into the placeholder Tensors
        feed_dict = {x_ph_: bx, ns_ph_: bns, y_ph_: by}
        batch_loss, _ = sess.run([loss_, train_op_], feed_dict=feed_dict)
        
        # Compute some statistics
        total_batches += 1
        total_examples += len(bx)
        total_loss += batch_loss * len(bx)  # re-scale, since batch loss is mean
        # Compute moving average to smooth out noisy per-batch loss
        loss_ema = ema_decay * loss_ema + (1 - ema_decay) * batch_loss
        
        if (total_batches % 25 == 0):
            print("{:5,} examples, moving-average loss {:.2f}".format(total_examples, 
                                                                      loss_ema))    
    print("Completed one epoch in {:s}".format(utils.pretty_timedelta(since=t0)))
# Out:
#   800 examples, moving-average loss 1.18
# 1,600 examples, moving-average loss 0.83
# 2,400 examples, moving-average loss 0.80
# 3,200 examples, moving-average loss 0.70
# 4,000 examples, moving-average loss 0.74
# 4,800 examples, moving-average loss 0.58
# 5,600 examples, moving-average loss 0.52
# 6,400 examples, moving-average loss 0.51
# 7,200 examples, moving-average loss 0.42
# 8,000 examples, moving-average loss 0.37
# 8,800 examples, moving-average loss 0.35
# 9,600 examples, moving-average loss 0.33
# 10,400 examples, moving-average loss 0.33
# 11,200 examples, moving-average loss 0.35
# 12,000 examples, moving-average loss 0.28
# 12,800 examples, moving-average loss 0.34
# 13,600 examples, moving-average loss 0.33
# 14,400 examples, moving-average loss 0.25
# 15,200 examples, moving-average loss 0.27
# 16,000 examples, moving-average loss 0.21
# 16,800 examples, moving-average loss 0.22
# 17,600 examples, moving-average loss 0.21
# 18,400 examples, moving-average loss 0.19
# 19,200 examples, moving-average loss 0.19
# 20,000 examples, moving-average loss 0.19
# 20,800 examples, moving-average loss 0.18
# 21,600 examples, moving-average loss 0.20
# 22,400 examples, moving-average loss 0.22
# 23,200 examples, moving-average loss 0.18
# 24,000 examples, moving-average loss 0.17
# 24,800 examples, moving-average loss 0.29
# 25,600 examples, moving-average loss 0.24
# 26,400 examples, moving-average loss 0.19
# 27,200 examples, moving-average loss 0.22
# 28,000 examples, moving-average loss 0.17
# 28,800 examples, moving-average loss 0.16
# 29,600 examples, moving-average loss 0.15
# 30,400 examples, moving-average loss 0.16
# 31,200 examples, moving-average loss 0.17
# 32,000 examples, moving-average loss 0.20
# 32,800 examples, moving-average loss 0.18
# 33,600 examples, moving-average loss 0.18
# 34,400 examples, moving-average loss 0.19
# 35,200 examples, moving-average loss 0.20
# 36,000 examples, moving-average loss 0.21
# 36,800 examples, moving-average loss 0.14
# 37,600 examples, moving-average loss 0.15
# 38,400 examples, moving-average loss 0.15
# 39,200 examples, moving-average loss 0.16
# 40,000 examples, moving-average loss 0.13
# 40,800 examples, moving-average loss 0.14
# 41,600 examples, moving-average loss 0.22
# 42,400 examples, moving-average loss 0.17
# 43,200 examples, moving-average loss 0.15
# 44,000 examples, moving-average loss 0.16
# 44,800 examples, moving-average loss 0.16
# 45,600 examples, moving-average loss 0.16
# 46,400 examples, moving-average loss 0.19
# 47,200 examples, moving-average loss 0.19
# 48,000 examples, moving-average loss 0.22
# 48,800 examples, moving-average loss 0.18
# 49,600 examples, moving-average loss 0.15
# 50,400 examples, moving-average loss 0.23
# 51,200 examples, moving-average loss 0.16
# 52,000 examples, moving-average loss 0.15
# 52,800 examples, moving-average loss 0.13
# 53,600 examples, moving-average loss 0.14
# 54,400 examples, moving-average loss 0.13
# 55,200 examples, moving-average loss 0.15
# 56,000 examples, moving-average loss 0.15
# 56,800 examples, moving-average loss 0.13
# 57,600 examples, moving-average loss 0.13
# 58,400 examples, moving-average loss 0.14
# 59,200 examples, moving-average loss 0.17
# 60,000 examples, moving-average loss 0.20
# 60,800 examples, moving-average loss 0.18
# 61,600 examples, moving-average loss 0.18
# 62,400 examples, moving-average loss 0.16
# 63,200 examples, moving-average loss 0.20
# 64,000 examples, moving-average loss 0.19
# 64,800 examples, moving-average loss 0.17
# 65,600 examples, moving-average loss 0.21
# 66,400 examples, moving-average loss 0.23
# 67,200 examples, moving-average loss 0.26
# 68,000 examples, moving-average loss 0.27
# 68,800 examples, moving-average loss 0.23
# 69,600 examples, moving-average loss 0.22
# 70,400 examples, moving-average loss 0.20
# 71,200 examples, moving-average loss 0.19
# 72,000 examples, moving-average loss 0.15
# 72,800 examples, moving-average loss 0.19
# 73,600 examples, moving-average loss 0.17
# 74,400 examples, moving-average loss 0.17
# 75,200 examples, moving-average loss 0.15
# 76,000 examples, moving-average loss 0.13
# 76,800 examples, moving-average loss 0.19
# 77,600 examples, moving-average loss 0.17
# 78,400 examples, moving-average loss 0.16
# 79,200 examples, moving-average loss 0.15
# 80,000 examples, moving-average loss 0.13
# 80,800 examples, moving-average loss 0.13
# 81,600 examples, moving-average loss 0.14
# 82,400 examples, moving-average loss 0.14
# 83,200 examples, moving-average loss 0.14
# 84,000 examples, moving-average loss 0.15
# 84,800 examples, moving-average loss 0.16
# 85,600 examples, moving-average loss 0.12
# 86,400 examples, moving-average loss 0.15
# 87,200 examples, moving-average loss 0.13
# 88,000 examples, moving-average loss 0.16
# 88,800 examples, moving-average loss 0.14
# 89,600 examples, moving-average loss 0.19
# 90,400 examples, moving-average loss 0.15
# 91,200 examples, moving-average loss 0.17
# 92,000 examples, moving-average loss 0.16
# 92,800 examples, moving-average loss 0.14
# 93,600 examples, moving-average loss 0.13
# 94,400 examples, moving-average loss 0.11
# 95,200 examples, moving-average loss 0.12
# 96,000 examples, moving-average loss 0.13
# 96,800 examples, moving-average loss 0.15
# 97,600 examples, moving-average loss 0.13
# 98,400 examples, moving-average loss 0.14
# 99,200 examples, moving-average loss 0.14
# 100,000 examples, moving-average loss 0.13
# 100,800 examples, moving-average loss 0.16
# 101,600 examples, moving-average loss 0.14
# 102,400 examples, moving-average loss 0.14
# 103,200 examples, moving-average loss 0.13
# 104,000 examples, moving-average loss 0.12
# 104,800 examples, moving-average loss 0.12
# 105,600 examples, moving-average loss 0.19
# 106,400 examples, moving-average loss 0.17
# 107,200 examples, moving-average loss 0.17
# 108,000 examples, moving-average loss 0.15
# 108,800 examples, moving-average loss 0.15
# 109,600 examples, moving-average loss 0.13
# 110,400 examples, moving-average loss 0.16
# 111,200 examples, moving-average loss 0.16
# 112,000 examples, moving-average loss 0.13
# 112,800 examples, moving-average loss 0.13
# 113,600 examples, moving-average loss 0.15
# 114,400 examples, moving-average loss 0.13
# 115,200 examples, moving-average loss 0.12
# 116,000 examples, moving-average loss 0.23
# 116,800 examples, moving-average loss 0.16
# 117,600 examples, moving-average loss 0.17
# 118,400 examples, moving-average loss 0.15
# 119,200 examples, moving-average loss 0.15
# 120,000 examples, moving-average loss 0.12
# 120,800 examples, moving-average loss 0.12
# 121,600 examples, moving-average loss 0.22
# 122,400 examples, moving-average loss 0.16
# 123,200 examples, moving-average loss 0.16
# 124,000 examples, moving-average loss 0.13
# 124,800 examples, moving-average loss 0.12
# 125,600 examples, moving-average loss 0.14
# 126,400 examples, moving-average loss 0.14
# 127,200 examples, moving-average loss 0.15
# 128,000 examples, moving-average loss 0.14
# 128,800 examples, moving-average loss 0.12
# 129,600 examples, moving-average loss 0.16
# 130,400 examples, moving-average loss 0.15
# 131,200 examples, moving-average loss 0.15
# 132,000 examples, moving-average loss 0.14
# 132,800 examples, moving-average loss 0.13
# 133,600 examples, moving-average loss 0.16
# 134,400 examples, moving-average loss 0.13
# 135,200 examples, moving-average loss 0.17
# 136,000 examples, moving-average loss 0.13
# 136,800 examples, moving-average loss 0.13
# 137,600 examples, moving-average loss 0.14
# 138,400 examples, moving-average loss 0.12
# 139,200 examples, moving-average loss 0.16
# 140,000 examples, moving-average loss 0.22
# 140,800 examples, moving-average loss 0.19
# 141,600 examples, moving-average loss 0.19
# 142,400 examples, moving-average loss 0.20
# 143,200 examples, moving-average loss 0.18
# 144,000 examples, moving-average loss 0.19
# 144,800 examples, moving-average loss 0.22
# 145,600 examples, moving-average loss 0.20
# 146,400 examples, moving-average loss 0.21
# 147,200 examples, moving-average loss 0.19
# 148,000 examples, moving-average loss 0.13
# 148,800 examples, moving-average loss 0.15
# 149,600 examples, moving-average loss 0.14
# 150,400 examples, moving-average loss 0.26
# 151,200 examples, moving-average loss 0.19
# 152,000 examples, moving-average loss 0.18
# 152,800 examples, moving-average loss 0.15
# 153,600 examples, moving-average loss 0.20
# Completed one epoch in 0:01:13

# %%
import models; reload(models)

# Specify model hyperparameters as used by model_fn
model_params = dict(V=vocab.size, embed_dim=70, hidden_dims=[75,50,25], num_classes=2,
                    encoder_type='bow',
                    lr=0.1, optimizer='adagrad', beta=0.01)

checkpoint_dir = "/tmp/tf_bow_sst_" + datetime.datetime.now().strftime("%Y%m%d-%H%M")
if os.path.isdir(checkpoint_dir):
    shutil.rmtree(checkpoint_dir)
# Write vocabulary to file, so TensorBoard can label embeddings.
# creates checkpoint_dir/projector_config.pbtxt and checkpoint_dir/metadata.tsv
vocab.write_projector_config(checkpoint_dir, "Encoder/Embedding_Layer/W_embed")

model = tf.estimator.Estimator(model_fn=models.classifier_model_fn, 
                               params=model_params,
                               model_dir=checkpoint_dir)
print("")
print("To view training (once it starts), run:\n")
print("    tensorboard --logdir='{:s}' --port 6006".format(checkpoint_dir))
print("\nThen in your browser, open: http://localhost:6006")
# Out:
# Vocabulary (70,000 words) written to '/tmp/tf_bow_sst_20180407-1945/metadata.tsv'
# Projector config written to /tmp/tf_bow_sst_20180407-1945/projector_config.pbtxt
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tf_bow_sst_20180407-1945', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1b714061d0>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
#
# To view training (once it starts), run:
#
#     tensorboard --logdir='/tmp/tf_bow_sst_20180407-1945' --port 6006
#
# Then in your browser, open: http://localhost:6006

# %% [markdown]
# ### Training

# %%
# Training params, just used in this cell for the input_fn-s
train_params = dict(batch_size=32, total_epochs=20, eval_every=5)
assert(train_params['total_epochs'] % train_params['eval_every'] == 0)

# Construct and train the model, saving checkpoints to the directory above.
# Input function for training set batches
# Do 'eval_every' epochs at once, followed by evaluating on the dev set.
# NOTE: use patch_numpy_io.numpy_input_fn instead of tf.estimator.inputs.numpy_input_fn
train_input_fn = patched_numpy_io.numpy_input_fn(
                    x={"ids": train_x_np, "ns": train_ns_np}, y=train_y_np,
                    batch_size=train_params['batch_size'], 
                    num_epochs=train_params['eval_every'], shuffle=True, seed=42
                 )

# %%
# Input function for dev set batches. As above, but:
# - Don't randomize order
# - Iterate exactly once (one epoch)
dev_input_fn = tf.estimator.inputs.numpy_input_fn(
                    x={"ids": dev_x_np, "ns": dev_ns_np}, y=dev_y_np,
                    batch_size=128, num_epochs=1, shuffle=False
                )

for _ in range(train_params['total_epochs'] // train_params['eval_every']):
    # Train for a few epochs, then evaluate on dev
    model.train(input_fn=train_input_fn)
    eval_metrics = model.evaluate(input_fn=dev_input_fn, name="dev")
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tf_bow_sst_20180407-1945/model.ckpt.
# INFO:tensorflow:loss = 1.8212612, step = 1
# INFO:tensorflow:global_step/sec: 70.1104
# INFO:tensorflow:loss = 0.73191017, step = 101 (1.430 sec)
# INFO:tensorflow:global_step/sec: 72.2771
# INFO:tensorflow:loss = 0.4183992, step = 201 (1.383 sec)
# INFO:tensorflow:global_step/sec: 71.1118
# INFO:tensorflow:loss = 0.2924765, step = 301 (1.406 sec)
# INFO:tensorflow:global_step/sec: 72.6891
# INFO:tensorflow:loss = 0.26893952, step = 401 (1.376 sec)
# INFO:tensorflow:global_step/sec: 73.063
# INFO:tensorflow:loss = 0.21890113, step = 501 (1.368 sec)
# INFO:tensorflow:global_step/sec: 69.1736
# INFO:tensorflow:loss = 0.17921704, step = 601 (1.446 sec)
# INFO:tensorflow:global_step/sec: 72.4554
# INFO:tensorflow:loss = 0.3353104, step = 701 (1.381 sec)
# INFO:tensorflow:global_step/sec: 72.8401
# INFO:tensorflow:loss = 0.1396102, step = 801 (1.372 sec)
# INFO:tensorflow:global_step/sec: 69.1243
# INFO:tensorflow:loss = 0.14780177, step = 901 (1.447 sec)
# INFO:tensorflow:global_step/sec: 72.9347
# INFO:tensorflow:loss = 0.37153417, step = 1001 (1.372 sec)
# INFO:tensorflow:global_step/sec: 72.7831
# INFO:tensorflow:loss = 0.316922, step = 1101 (1.374 sec)
# INFO:tensorflow:global_step/sec: 72.6797
# INFO:tensorflow:loss = 0.43769315, step = 1201 (1.376 sec)
# INFO:tensorflow:global_step/sec: 72.167
# INFO:tensorflow:loss = 0.38826445, step = 1301 (1.386 sec)
# INFO:tensorflow:global_step/sec: 69.3937
# INFO:tensorflow:loss = 0.16888607, step = 1401 (1.443 sec)
# INFO:tensorflow:global_step/sec: 68.5632
# INFO:tensorflow:loss = 0.1561003, step = 1501 (1.457 sec)
# INFO:tensorflow:global_step/sec: 71.0724
# INFO:tensorflow:loss = 0.19897527, step = 1601 (1.407 sec)
# INFO:tensorflow:global_step/sec: 67.6899
# INFO:tensorflow:loss = 0.20975287, step = 1701 (1.477 sec)
# INFO:tensorflow:global_step/sec: 69.4721
# INFO:tensorflow:loss = 0.10522811, step = 1801 (1.440 sec)
# INFO:tensorflow:global_step/sec: 69.2425
# INFO:tensorflow:loss = 0.26529548, step = 1901 (1.444 sec)
# INFO:tensorflow:global_step/sec: 67.1128
# INFO:tensorflow:loss = 0.104504466, step = 2001 (1.489 sec)
# INFO:tensorflow:global_step/sec: 70.0451
# INFO:tensorflow:loss = 0.3593743, step = 2101 (1.428 sec)
# INFO:tensorflow:global_step/sec: 67.9565
# INFO:tensorflow:loss = 0.14282453, step = 2201 (1.472 sec)
# INFO:tensorflow:global_step/sec: 70.5041
# INFO:tensorflow:loss = 0.13091001, step = 2301 (1.418 sec)
# INFO:tensorflow:global_step/sec: 71.7565
# INFO:tensorflow:loss = 0.12659773, step = 2401 (1.393 sec)
# INFO:tensorflow:global_step/sec: 73.6276
# INFO:tensorflow:loss = 0.14334568, step = 2501 (1.358 sec)
# INFO:tensorflow:global_step/sec: 74.2731
# INFO:tensorflow:loss = 0.2554839, step = 2601 (1.347 sec)
# INFO:tensorflow:global_step/sec: 77.2937
# INFO:tensorflow:loss = 0.2753671, step = 2701 (1.293 sec)
# INFO:tensorflow:global_step/sec: 73.4335
# INFO:tensorflow:loss = 0.17511061, step = 2801 (1.363 sec)
# INFO:tensorflow:global_step/sec: 71.7587
# INFO:tensorflow:loss = 0.12446541, step = 2901 (1.393 sec)
# INFO:tensorflow:global_step/sec: 72.4528
# INFO:tensorflow:loss = 0.151604, step = 3001 (1.381 sec)
# INFO:tensorflow:global_step/sec: 73.266
# INFO:tensorflow:loss = 0.11665441, step = 3101 (1.365 sec)
# INFO:tensorflow:global_step/sec: 73.9918
# INFO:tensorflow:loss = 0.107524954, step = 3201 (1.351 sec)
# INFO:tensorflow:global_step/sec: 75.1014
# INFO:tensorflow:loss = 0.14154108, step = 3301 (1.332 sec)
# INFO:tensorflow:global_step/sec: 70.8521
# INFO:tensorflow:loss = 0.11374235, step = 3401 (1.414 sec)
# INFO:tensorflow:global_step/sec: 70.7531
# INFO:tensorflow:loss = 0.17877555, step = 3501 (1.410 sec)
# INFO:tensorflow:global_step/sec: 79.7157
# INFO:tensorflow:loss = 0.371738, step = 3601 (1.255 sec)
# INFO:tensorflow:global_step/sec: 78.8395
# INFO:tensorflow:loss = 0.19230765, step = 3701 (1.268 sec)
# INFO:tensorflow:global_step/sec: 79.2804
# INFO:tensorflow:loss = 0.1384187, step = 3801 (1.261 sec)
# INFO:tensorflow:global_step/sec: 80.2773
# INFO:tensorflow:loss = 0.118126385, step = 3901 (1.246 sec)
# INFO:tensorflow:global_step/sec: 79.4972
# INFO:tensorflow:loss = 0.31485105, step = 4001 (1.258 sec)
# INFO:tensorflow:global_step/sec: 77.5294
# INFO:tensorflow:loss = 0.1158105, step = 4101 (1.291 sec)
# INFO:tensorflow:global_step/sec: 77.6696
# INFO:tensorflow:loss = 0.14059958, step = 4201 (1.287 sec)
# INFO:tensorflow:global_step/sec: 78.1074
# INFO:tensorflow:loss = 0.12419225, step = 4301 (1.280 sec)
# INFO:tensorflow:global_step/sec: 75.6634
# INFO:tensorflow:loss = 0.09370344, step = 4401 (1.323 sec)
# INFO:tensorflow:global_step/sec: 73.37
# INFO:tensorflow:loss = 0.09809436, step = 4501 (1.362 sec)
# INFO:tensorflow:global_step/sec: 73.6141
# INFO:tensorflow:loss = 0.101499714, step = 4601 (1.358 sec)
# INFO:tensorflow:global_step/sec: 64.712
# INFO:tensorflow:loss = 0.13544501, step = 4701 (1.548 sec)
# INFO:tensorflow:global_step/sec: 62.1501
# INFO:tensorflow:loss = 0.15493752, step = 4801 (1.611 sec)
# INFO:tensorflow:global_step/sec: 64.175
# INFO:tensorflow:loss = 0.14487821, step = 4901 (1.555 sec)
# INFO:tensorflow:global_step/sec: 65.771
# INFO:tensorflow:loss = 0.54296106, step = 5001 (1.522 sec)
# INFO:tensorflow:global_step/sec: 57.3081
# INFO:tensorflow:loss = 0.106172115, step = 5101 (1.743 sec)
# INFO:tensorflow:global_step/sec: 69.1763
# INFO:tensorflow:loss = 0.14106129, step = 5201 (1.445 sec)
# INFO:tensorflow:global_step/sec: 66.6408
# INFO:tensorflow:loss = 0.09371874, step = 5301 (1.503 sec)
# INFO:tensorflow:global_step/sec: 65.7475
# INFO:tensorflow:loss = 0.10997083, step = 5401 (1.519 sec)
# INFO:tensorflow:global_step/sec: 67.5626
# INFO:tensorflow:loss = 0.21654002, step = 5501 (1.480 sec)
# INFO:tensorflow:global_step/sec: 66.397
# INFO:tensorflow:loss = 0.106976256, step = 5601 (1.506 sec)
# INFO:tensorflow:global_step/sec: 70.4074
# INFO:tensorflow:loss = 0.13293472, step = 5701 (1.421 sec)
# INFO:tensorflow:global_step/sec: 73.6932
# INFO:tensorflow:loss = 0.1784879, step = 5801 (1.360 sec)
# INFO:tensorflow:global_step/sec: 71.4522
# INFO:tensorflow:loss = 0.12715134, step = 5901 (1.399 sec)
# INFO:tensorflow:global_step/sec: 69.255
# INFO:tensorflow:loss = 0.16532731, step = 6001 (1.442 sec)
# INFO:tensorflow:global_step/sec: 71.4626
# INFO:tensorflow:loss = 0.1039055, step = 6101 (1.399 sec)
# INFO:tensorflow:global_step/sec: 70.0972
# INFO:tensorflow:loss = 0.13484715, step = 6201 (1.426 sec)
# INFO:tensorflow:global_step/sec: 57.5083
# INFO:tensorflow:loss = 0.21195167, step = 6301 (1.739 sec)
# INFO:tensorflow:global_step/sec: 77.444
# INFO:tensorflow:loss = 0.11019328, step = 6401 (1.290 sec)
# INFO:tensorflow:global_step/sec: 72.7797
# INFO:tensorflow:loss = 0.120191306, step = 6501 (1.374 sec)
# INFO:tensorflow:global_step/sec: 74.6334
# INFO:tensorflow:loss = 0.095310315, step = 6601 (1.340 sec)
# INFO:tensorflow:global_step/sec: 77.1015
# INFO:tensorflow:loss = 0.10215128, step = 6701 (1.297 sec)
# INFO:tensorflow:global_step/sec: 76.3262
# INFO:tensorflow:loss = 0.108636096, step = 6801 (1.310 sec)
# INFO:tensorflow:global_step/sec: 75.1465
# INFO:tensorflow:loss = 0.12093329, step = 6901 (1.333 sec)
# INFO:tensorflow:global_step/sec: 76.7078
# INFO:tensorflow:loss = 0.10403683, step = 7001 (1.302 sec)
# INFO:tensorflow:global_step/sec: 76.7933
# INFO:tensorflow:loss = 0.10113795, step = 7101 (1.302 sec)
# INFO:tensorflow:global_step/sec: 76.1147
# INFO:tensorflow:loss = 0.30890802, step = 7201 (1.314 sec)
# INFO:tensorflow:global_step/sec: 75.849
# INFO:tensorflow:loss = 0.096226476, step = 7301 (1.319 sec)
# INFO:tensorflow:global_step/sec: 71.415
# INFO:tensorflow:loss = 0.1472467, step = 7401 (1.403 sec)
# INFO:tensorflow:global_step/sec: 69.6721
# INFO:tensorflow:loss = 0.113654554, step = 7501 (1.432 sec)
# INFO:tensorflow:global_step/sec: 72.9497
# INFO:tensorflow:loss = 0.088710494, step = 7601 (1.371 sec)
# INFO:tensorflow:global_step/sec: 71.6819
# INFO:tensorflow:loss = 0.3885924, step = 7701 (1.398 sec)
# INFO:tensorflow:global_step/sec: 72.8489
# INFO:tensorflow:loss = 0.106454946, step = 7801 (1.370 sec)
# INFO:tensorflow:global_step/sec: 77.3034
# INFO:tensorflow:loss = 0.15656665, step = 7901 (1.293 sec)
# INFO:tensorflow:global_step/sec: 77.1005
# INFO:tensorflow:loss = 0.16449204, step = 8001 (1.298 sec)
# INFO:tensorflow:global_step/sec: 79.4083
# INFO:tensorflow:loss = 0.12845513, step = 8101 (1.259 sec)
# INFO:tensorflow:global_step/sec: 77.3291
# INFO:tensorflow:loss = 0.12246691, step = 8201 (1.293 sec)
# INFO:tensorflow:global_step/sec: 73.3492
# INFO:tensorflow:loss = 0.30651557, step = 8301 (1.364 sec)
# INFO:tensorflow:global_step/sec: 74.7583
# INFO:tensorflow:loss = 0.11857522, step = 8401 (1.337 sec)
# INFO:tensorflow:global_step/sec: 76.6271
# INFO:tensorflow:loss = 0.127384, step = 8501 (1.305 sec)
# INFO:tensorflow:global_step/sec: 76.3148
# INFO:tensorflow:loss = 0.29164302, step = 8601 (1.311 sec)
# INFO:tensorflow:global_step/sec: 72.77
# INFO:tensorflow:loss = 0.092764914, step = 8701 (1.374 sec)
# INFO:tensorflow:global_step/sec: 71.418
# INFO:tensorflow:loss = 0.1693297, step = 8801 (1.401 sec)
# INFO:tensorflow:global_step/sec: 76.2913
# INFO:tensorflow:loss = 0.09479257, step = 8901 (1.311 sec)
# INFO:tensorflow:global_step/sec: 70.7773
# INFO:tensorflow:loss = 0.11026623, step = 9001 (1.413 sec)
# INFO:tensorflow:global_step/sec: 73.5978
# INFO:tensorflow:loss = 0.10946289, step = 9101 (1.359 sec)
# INFO:tensorflow:global_step/sec: 69.7597
# INFO:tensorflow:loss = 0.10423384, step = 9201 (1.435 sec)
# INFO:tensorflow:global_step/sec: 72.06
# INFO:tensorflow:loss = 0.104886964, step = 9301 (1.385 sec)
# INFO:tensorflow:global_step/sec: 78.2698
# INFO:tensorflow:loss = 0.10896474, step = 9401 (1.278 sec)
# INFO:tensorflow:global_step/sec: 72.5934
# INFO:tensorflow:loss = 0.13868362, step = 9501 (1.379 sec)
# INFO:tensorflow:global_step/sec: 69.5772
# INFO:tensorflow:loss = 0.38374048, step = 9601 (1.437 sec)
# INFO:tensorflow:global_step/sec: 71.5439
# INFO:tensorflow:loss = 0.11164965, step = 9701 (1.400 sec)
# INFO:tensorflow:global_step/sec: 71.1658
# INFO:tensorflow:loss = 0.16116643, step = 9801 (1.403 sec)
# INFO:tensorflow:global_step/sec: 73.1549
# INFO:tensorflow:loss = 0.08997712, step = 9901 (1.366 sec)
# INFO:tensorflow:global_step/sec: 73.308
# INFO:tensorflow:loss = 0.10636413, step = 10001 (1.366 sec)
# INFO:tensorflow:global_step/sec: 68.8874
# INFO:tensorflow:loss = 0.09720855, step = 10101 (1.450 sec)
# INFO:tensorflow:global_step/sec: 69.7064
# INFO:tensorflow:loss = 0.10907398, step = 10201 (1.435 sec)
# INFO:tensorflow:global_step/sec: 70.793
# INFO:tensorflow:loss = 0.092780255, step = 10301 (1.413 sec)
# INFO:tensorflow:global_step/sec: 71.6706
# INFO:tensorflow:loss = 0.10148478, step = 10401 (1.395 sec)
# INFO:tensorflow:global_step/sec: 67.8312
# INFO:tensorflow:loss = 0.111212, step = 10501 (1.473 sec)
# INFO:tensorflow:global_step/sec: 70.9598
# INFO:tensorflow:loss = 0.09271617, step = 10601 (1.413 sec)
# INFO:tensorflow:global_step/sec: 63.2102
# INFO:tensorflow:loss = 0.1676187, step = 10701 (1.582 sec)
# INFO:tensorflow:global_step/sec: 63.7227
# INFO:tensorflow:loss = 0.17718892, step = 10801 (1.569 sec)
# INFO:tensorflow:global_step/sec: 54.3632
# INFO:tensorflow:loss = 0.19085082, step = 10901 (1.837 sec)
# INFO:tensorflow:global_step/sec: 70.5676
# INFO:tensorflow:loss = 0.14675024, step = 11001 (1.416 sec)
# INFO:tensorflow:global_step/sec: 72.1655
# INFO:tensorflow:loss = 0.09981366, step = 11101 (1.387 sec)
# INFO:tensorflow:global_step/sec: 67.2354
# INFO:tensorflow:loss = 0.10763456, step = 11201 (1.487 sec)
# INFO:tensorflow:global_step/sec: 70.5774
# INFO:tensorflow:loss = 0.114014834, step = 11301 (1.416 sec)
# INFO:tensorflow:global_step/sec: 68.184
# INFO:tensorflow:loss = 0.092481256, step = 11401 (1.468 sec)
# INFO:tensorflow:global_step/sec: 58.0025
# INFO:tensorflow:loss = 0.12554045, step = 11501 (1.723 sec)
# INFO:tensorflow:global_step/sec: 67.5292
# INFO:tensorflow:loss = 0.104281865, step = 11601 (1.481 sec)
# INFO:tensorflow:global_step/sec: 71.5937
# INFO:tensorflow:loss = 0.09413482, step = 11701 (1.396 sec)
# INFO:tensorflow:global_step/sec: 67.0525
# INFO:tensorflow:loss = 0.0866424, step = 11801 (1.491 sec)
# INFO:tensorflow:global_step/sec: 70.9314
# INFO:tensorflow:loss = 0.10871555, step = 11901 (1.410 sec)
# INFO:tensorflow:global_step/sec: 61.3215
# INFO:tensorflow:loss = 0.09877516, step = 12001 (1.631 sec)
# INFO:tensorflow:global_step/sec: 68.7828
# INFO:tensorflow:loss = 0.11190548, step = 12101 (1.453 sec)
# INFO:tensorflow:global_step/sec: 68.5263
# INFO:tensorflow:loss = 0.14165336, step = 12201 (1.459 sec)
# INFO:tensorflow:global_step/sec: 69.1126
# INFO:tensorflow:loss = 0.09611076, step = 12301 (1.448 sec)
# INFO:tensorflow:global_step/sec: 71.0648
# INFO:tensorflow:loss = 0.13226493, step = 12401 (1.406 sec)
# INFO:tensorflow:global_step/sec: 78.1363
# INFO:tensorflow:loss = 0.0919967, step = 12501 (1.279 sec)
# INFO:tensorflow:global_step/sec: 73.4035
# INFO:tensorflow:loss = 0.102541536, step = 12601 (1.362 sec)
# INFO:tensorflow:global_step/sec: 76.4233
# INFO:tensorflow:loss = 0.104782015, step = 12701 (1.308 sec)
# INFO:tensorflow:global_step/sec: 69.3909
# INFO:tensorflow:loss = 0.14992991, step = 12801 (1.443 sec)
# INFO:tensorflow:global_step/sec: 70.2616
# INFO:tensorflow:loss = 0.15265009, step = 12901 (1.422 sec)
# INFO:tensorflow:global_step/sec: 73.979
# INFO:tensorflow:loss = 0.13428031, step = 13001 (1.352 sec)
# INFO:tensorflow:global_step/sec: 72.6318
# INFO:tensorflow:loss = 0.25700325, step = 13101 (1.378 sec)
# INFO:tensorflow:global_step/sec: 75.6914
# INFO:tensorflow:loss = 0.12750585, step = 13201 (1.320 sec)
# INFO:tensorflow:global_step/sec: 59.1577
# INFO:tensorflow:loss = 0.12081273, step = 13301 (1.693 sec)
# INFO:tensorflow:global_step/sec: 56.7317
# INFO:tensorflow:loss = 0.11057173, step = 13401 (1.760 sec)
# INFO:tensorflow:global_step/sec: 67.0667
# INFO:tensorflow:loss = 0.117077634, step = 13501 (1.492 sec)
# INFO:tensorflow:global_step/sec: 62.618
# INFO:tensorflow:loss = 0.092360064, step = 13601 (1.596 sec)
# INFO:tensorflow:global_step/sec: 75.6956
# INFO:tensorflow:loss = 0.12715128, step = 13701 (1.321 sec)
# INFO:tensorflow:global_step/sec: 77.6111
# INFO:tensorflow:loss = 0.09568885, step = 13801 (1.288 sec)
# INFO:tensorflow:global_step/sec: 60.844
# INFO:tensorflow:loss = 0.09174862, step = 13901 (1.646 sec)
# INFO:tensorflow:global_step/sec: 65.8025
# INFO:tensorflow:loss = 0.09591872, step = 14001 (1.519 sec)
# INFO:tensorflow:global_step/sec: 69.227
# INFO:tensorflow:loss = 0.10631907, step = 14101 (1.443 sec)
# INFO:tensorflow:global_step/sec: 70.3631
# INFO:tensorflow:loss = 0.08912389, step = 14201 (1.422 sec)
# INFO:tensorflow:global_step/sec: 61.4141
# INFO:tensorflow:loss = 0.09220872, step = 14301 (1.627 sec)
# INFO:tensorflow:global_step/sec: 72.2196
# INFO:tensorflow:loss = 0.10761608, step = 14401 (1.385 sec)
# INFO:tensorflow:global_step/sec: 71.9436
# INFO:tensorflow:loss = 0.08788278, step = 14501 (1.390 sec)
# INFO:tensorflow:global_step/sec: 74.4296
# INFO:tensorflow:loss = 0.09192537, step = 14601 (1.344 sec)
# INFO:tensorflow:global_step/sec: 74.7105
# INFO:tensorflow:loss = 0.08902875, step = 14701 (1.337 sec)
# INFO:tensorflow:global_step/sec: 79.6835
# INFO:tensorflow:loss = 0.13420814, step = 14801 (1.255 sec)
# INFO:tensorflow:global_step/sec: 73.4423
# INFO:tensorflow:loss = 0.10407859, step = 14901 (1.362 sec)
# INFO:tensorflow:global_step/sec: 72.155
# INFO:tensorflow:loss = 0.093472816, step = 15001 (1.386 sec)
# INFO:tensorflow:global_step/sec: 74.6958
# INFO:tensorflow:loss = 0.3528456, step = 15101 (1.340 sec)
# INFO:tensorflow:global_step/sec: 77.283
# INFO:tensorflow:loss = 0.10170698, step = 15201 (1.293 sec)
# INFO:tensorflow:global_step/sec: 74.619
# INFO:tensorflow:loss = 0.09168065, step = 15301 (1.341 sec)
# INFO:tensorflow:global_step/sec: 72.6976
# INFO:tensorflow:loss = 0.15318975, step = 15401 (1.376 sec)
# INFO:tensorflow:global_step/sec: 70.5577
# INFO:tensorflow:loss = 0.10614356, step = 15501 (1.420 sec)
# INFO:tensorflow:global_step/sec: 66.9401
# INFO:tensorflow:loss = 0.11424597, step = 15601 (1.492 sec)
# INFO:tensorflow:global_step/sec: 74.4982
# INFO:tensorflow:loss = 0.11430641, step = 15701 (1.342 sec)
# INFO:tensorflow:global_step/sec: 72.9382
# INFO:tensorflow:loss = 0.103211485, step = 15801 (1.371 sec)
# INFO:tensorflow:global_step/sec: 73.1963
# INFO:tensorflow:loss = 0.0938747, step = 15901 (1.366 sec)
# INFO:tensorflow:global_step/sec: 72.3124
# INFO:tensorflow:loss = 0.10110517, step = 16001 (1.382 sec)
# INFO:tensorflow:global_step/sec: 76.7256
# INFO:tensorflow:loss = 0.09113667, step = 16101 (1.304 sec)
# INFO:tensorflow:global_step/sec: 78.5136
# INFO:tensorflow:loss = 0.09098213, step = 16201 (1.273 sec)
# INFO:tensorflow:global_step/sec: 78.9299
# INFO:tensorflow:loss = 0.095389076, step = 16301 (1.268 sec)
# INFO:tensorflow:global_step/sec: 76.9318
# INFO:tensorflow:loss = 0.09070624, step = 16401 (1.299 sec)
# INFO:tensorflow:global_step/sec: 75.9481
# INFO:tensorflow:loss = 0.11203512, step = 16501 (1.317 sec)
# INFO:tensorflow:global_step/sec: 77.5254
# INFO:tensorflow:loss = 0.09458701, step = 16601 (1.290 sec)
# INFO:tensorflow:global_step/sec: 78.7782
# INFO:tensorflow:loss = 0.09208614, step = 16701 (1.270 sec)
# INFO:tensorflow:global_step/sec: 72.0388
# INFO:tensorflow:loss = 0.10202843, step = 16801 (1.388 sec)
# INFO:tensorflow:global_step/sec: 74.4737
# INFO:tensorflow:loss = 0.09511693, step = 16901 (1.344 sec)
# INFO:tensorflow:global_step/sec: 76.1341
# INFO:tensorflow:loss = 0.09512192, step = 17001 (1.312 sec)
# INFO:tensorflow:global_step/sec: 75.4755
# INFO:tensorflow:loss = 0.0940232, step = 17101 (1.326 sec)
# INFO:tensorflow:global_step/sec: 74.5323
# INFO:tensorflow:loss = 0.092890345, step = 17201 (1.340 sec)
# INFO:tensorflow:global_step/sec: 74.8635
# INFO:tensorflow:loss = 0.098310485, step = 17301 (1.337 sec)
# INFO:tensorflow:global_step/sec: 75.8571
# INFO:tensorflow:loss = 0.088376746, step = 17401 (1.317 sec)
# INFO:tensorflow:global_step/sec: 74.7244
# INFO:tensorflow:loss = 0.1214537, step = 17501 (1.338 sec)
# INFO:tensorflow:global_step/sec: 71.5157
# INFO:tensorflow:loss = 0.10366082, step = 17601 (1.398 sec)
# INFO:tensorflow:global_step/sec: 76.0373
# INFO:tensorflow:loss = 0.09724749, step = 17701 (1.316 sec)
# INFO:tensorflow:global_step/sec: 76.129
# INFO:tensorflow:loss = 0.11086356, step = 17801 (1.313 sec)
# INFO:tensorflow:global_step/sec: 74.2986
# INFO:tensorflow:loss = 0.27507544, step = 17901 (1.347 sec)
# INFO:tensorflow:global_step/sec: 71.4611
# INFO:tensorflow:loss = 0.1382846, step = 18001 (1.398 sec)
# INFO:tensorflow:global_step/sec: 75.4901
# INFO:tensorflow:loss = 0.098125145, step = 18101 (1.325 sec)
# INFO:tensorflow:global_step/sec: 58.772
# INFO:tensorflow:loss = 0.09532812, step = 18201 (1.704 sec)
# INFO:tensorflow:global_step/sec: 71.6189
# INFO:tensorflow:loss = 0.12449375, step = 18301 (1.394 sec)
# INFO:tensorflow:global_step/sec: 71.1526
# INFO:tensorflow:loss = 0.09383379, step = 18401 (1.407 sec)
# INFO:tensorflow:global_step/sec: 69.9535
# INFO:tensorflow:loss = 0.124688625, step = 18501 (1.428 sec)
# INFO:tensorflow:global_step/sec: 78.3274
# INFO:tensorflow:loss = 0.09643081, step = 18601 (1.277 sec)
# INFO:tensorflow:global_step/sec: 75.7895
# INFO:tensorflow:loss = 0.093649454, step = 18701 (1.319 sec)
# INFO:tensorflow:global_step/sec: 76.7471
# INFO:tensorflow:loss = 0.088496335, step = 18801 (1.303 sec)
# INFO:tensorflow:global_step/sec: 73.4295
# INFO:tensorflow:loss = 0.09265518, step = 18901 (1.362 sec)
# INFO:tensorflow:global_step/sec: 69.5053
# INFO:tensorflow:loss = 0.13041241, step = 19001 (1.438 sec)
# INFO:tensorflow:global_step/sec: 69.3904
# INFO:tensorflow:loss = 0.10193518, step = 19101 (1.441 sec)
# INFO:tensorflow:global_step/sec: 69.4801
# INFO:tensorflow:loss = 0.10513715, step = 19201 (1.439 sec)
# INFO:tensorflow:global_step/sec: 70.5931
# INFO:tensorflow:loss = 0.12144699, step = 19301 (1.417 sec)
# INFO:tensorflow:global_step/sec: 73.4488
# INFO:tensorflow:loss = 0.099365816, step = 19401 (1.363 sec)
# INFO:tensorflow:global_step/sec: 71.4293
# INFO:tensorflow:loss = 0.089105494, step = 19501 (1.398 sec)
# INFO:tensorflow:global_step/sec: 69.6021
# INFO:tensorflow:loss = 0.09725635, step = 19601 (1.437 sec)
# INFO:tensorflow:global_step/sec: 66.7572
# INFO:tensorflow:loss = 0.13845548, step = 19701 (1.498 sec)
# INFO:tensorflow:global_step/sec: 70.2352
# INFO:tensorflow:loss = 0.10721117, step = 19801 (1.423 sec)
# INFO:tensorflow:global_step/sec: 70.8076
# INFO:tensorflow:loss = 0.15942472, step = 19901 (1.412 sec)
# INFO:tensorflow:global_step/sec: 71.2162
# INFO:tensorflow:loss = 0.092567265, step = 20001 (1.405 sec)
# INFO:tensorflow:global_step/sec: 68.9272
# INFO:tensorflow:loss = 0.08956325, step = 20101 (1.451 sec)
# INFO:tensorflow:global_step/sec: 71.3843
# INFO:tensorflow:loss = 0.086375065, step = 20201 (1.399 sec)
# INFO:tensorflow:global_step/sec: 67.7298
# INFO:tensorflow:loss = 0.08994928, step = 20301 (1.478 sec)
# INFO:tensorflow:global_step/sec: 70.2782
# INFO:tensorflow:loss = 0.14934748, step = 20401 (1.422 sec)
# INFO:tensorflow:global_step/sec: 70.6776
# INFO:tensorflow:loss = 0.4462594, step = 20501 (1.414 sec)
# INFO:tensorflow:global_step/sec: 70.4543
# INFO:tensorflow:loss = 0.11133793, step = 20601 (1.419 sec)
# INFO:tensorflow:global_step/sec: 68.9152
# INFO:tensorflow:loss = 0.12755617, step = 20701 (1.452 sec)
# INFO:tensorflow:global_step/sec: 72.9368
# INFO:tensorflow:loss = 0.14742641, step = 20801 (1.371 sec)
# INFO:tensorflow:global_step/sec: 71.7522
# INFO:tensorflow:loss = 0.10577391, step = 20901 (1.393 sec)
# INFO:tensorflow:global_step/sec: 70.8648
# INFO:tensorflow:loss = 0.10347147, step = 21001 (1.411 sec)
# INFO:tensorflow:global_step/sec: 71.2288
# INFO:tensorflow:loss = 0.118580155, step = 21101 (1.404 sec)
# INFO:tensorflow:global_step/sec: 74.5773
# INFO:tensorflow:loss = 0.100418516, step = 21201 (1.341 sec)
# INFO:tensorflow:global_step/sec: 74.9339
# INFO:tensorflow:loss = 0.10807355, step = 21301 (1.335 sec)
# INFO:tensorflow:global_step/sec: 72.3301
# INFO:tensorflow:loss = 0.087578505, step = 21401 (1.382 sec)
# INFO:tensorflow:global_step/sec: 72.8645
# INFO:tensorflow:loss = 0.09620805, step = 21501 (1.374 sec)
# INFO:tensorflow:global_step/sec: 69.1239
# INFO:tensorflow:loss = 0.092061654, step = 21601 (1.445 sec)
# INFO:tensorflow:global_step/sec: 76.4326
# INFO:tensorflow:loss = 0.29775655, step = 21701 (1.309 sec)
# INFO:tensorflow:global_step/sec: 73.4014
# INFO:tensorflow:loss = 0.10086, step = 21801 (1.364 sec)
# INFO:tensorflow:global_step/sec: 76.0668
# INFO:tensorflow:loss = 0.09979209, step = 21901 (1.314 sec)
# INFO:tensorflow:global_step/sec: 73.583
# INFO:tensorflow:loss = 0.102582335, step = 22001 (1.359 sec)
# INFO:tensorflow:global_step/sec: 76.1093
# INFO:tensorflow:loss = 0.09764455, step = 22101 (1.313 sec)
# INFO:tensorflow:global_step/sec: 75.5473
# INFO:tensorflow:loss = 0.09441367, step = 22201 (1.323 sec)
# INFO:tensorflow:global_step/sec: 75.2037
# INFO:tensorflow:loss = 0.107262984, step = 22301 (1.331 sec)
# INFO:tensorflow:global_step/sec: 80.1066
# INFO:tensorflow:loss = 0.11613837, step = 22401 (1.246 sec)
# INFO:tensorflow:global_step/sec: 79.0658
# INFO:tensorflow:loss = 0.0925853, step = 22501 (1.265 sec)
# INFO:tensorflow:global_step/sec: 74.9148
# INFO:tensorflow:loss = 0.2796595, step = 22601 (1.334 sec)
# INFO:tensorflow:global_step/sec: 75.5108
# INFO:tensorflow:loss = 0.15679689, step = 22701 (1.324 sec)
# INFO:tensorflow:global_step/sec: 77.0845
# INFO:tensorflow:loss = 0.12797931, step = 22801 (1.297 sec)
# INFO:tensorflow:global_step/sec: 77.3482
# INFO:tensorflow:loss = 0.20210832, step = 22901 (1.293 sec)
# INFO:tensorflow:global_step/sec: 75.5847
# INFO:tensorflow:loss = 0.09054974, step = 23001 (1.323 sec)
# INFO:tensorflow:global_step/sec: 73.4227
# INFO:tensorflow:loss = 0.117399424, step = 23101 (1.362 sec)
# INFO:tensorflow:global_step/sec: 73.1311
# INFO:tensorflow:loss = 0.09402397, step = 23201 (1.367 sec)
# INFO:tensorflow:global_step/sec: 72.687
# INFO:tensorflow:loss = 0.10701019, step = 23301 (1.376 sec)
# INFO:tensorflow:global_step/sec: 76.1123
# INFO:tensorflow:loss = 0.094240725, step = 23401 (1.315 sec)
# INFO:tensorflow:global_step/sec: 75.7346
# INFO:tensorflow:loss = 0.092495896, step = 23501 (1.319 sec)
# INFO:tensorflow:global_step/sec: 78.4654
# INFO:tensorflow:loss = 0.12243921, step = 23601 (1.275 sec)
# INFO:tensorflow:global_step/sec: 80.0669
# INFO:tensorflow:loss = 0.086977154, step = 23701 (1.249 sec)
# INFO:tensorflow:global_step/sec: 79.2053
# INFO:tensorflow:loss = 0.108500525, step = 23801 (1.263 sec)
# INFO:tensorflow:global_step/sec: 75.9968
# INFO:tensorflow:loss = 0.09876949, step = 23901 (1.316 sec)
# INFO:tensorflow:global_step/sec: 77.3096
# INFO:tensorflow:loss = 0.0952194, step = 24001 (1.293 sec)
# INFO:tensorflow:global_step/sec: 73.3714
# INFO:tensorflow:loss = 0.08649135, step = 24101 (1.364 sec)
# INFO:tensorflow:Saving checkpoints for 24106 into /tmp/tf_bow_sst_20180407-1945/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.09276241.
# INFO:tensorflow:Starting evaluation at 2018-04-07-19:51:14
# INFO:tensorflow:Restoring parameters from /tmp/tf_bow_sst_20180407-1945/model.ckpt-24106
# INFO:tensorflow:Finished evaluation at 2018-04-07-19:51:24
# INFO:tensorflow:Saving dict for global step 24106: accuracy = 0.9432831, cross_entropy_loss = 0.18783706, global_step = 24106, loss = 0.3112657
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from /tmp/tf_bow_sst_20180407-1945/model.ckpt-24106
# INFO:tensorflow:Saving checkpoints for 24107 into /tmp/tf_bow_sst_20180407-1945/model.ckpt.
# INFO:tensorflow:loss = 0.08814412, step = 24107
# INFO:tensorflow:global_step/sec: 73.0021
# INFO:tensorflow:loss = 0.09928262, step = 24207 (1.373 sec)
# INFO:tensorflow:global_step/sec: 72.7828
# INFO:tensorflow:loss = 0.08394588, step = 24307 (1.374 sec)
# INFO:tensorflow:global_step/sec: 72.4215
# INFO:tensorflow:loss = 0.10210018, step = 24407 (1.381 sec)
# INFO:tensorflow:global_step/sec: 76.9567
# INFO:tensorflow:loss = 0.09652099, step = 24507 (1.300 sec)
# INFO:tensorflow:global_step/sec: 73.9364
# INFO:tensorflow:loss = 0.08483375, step = 24607 (1.352 sec)
# INFO:tensorflow:global_step/sec: 72.6802
# INFO:tensorflow:loss = 0.09912737, step = 24707 (1.376 sec)
# INFO:tensorflow:global_step/sec: 76.2639
# INFO:tensorflow:loss = 0.36595696, step = 24807 (1.311 sec)
# INFO:tensorflow:global_step/sec: 77.9409
# INFO:tensorflow:loss = 0.10582286, step = 24907 (1.284 sec)
# INFO:tensorflow:global_step/sec: 71.7377
# INFO:tensorflow:loss = 0.10831771, step = 25007 (1.411 sec)
# INFO:tensorflow:global_step/sec: 68.915
# INFO:tensorflow:loss = 0.123393886, step = 25107 (1.433 sec)
# INFO:tensorflow:global_step/sec: 73.3738
# INFO:tensorflow:loss = 0.13288504, step = 25207 (1.363 sec)
# INFO:tensorflow:global_step/sec: 69.2223
# INFO:tensorflow:loss = 0.44168577, step = 25307 (1.445 sec)
# INFO:tensorflow:global_step/sec: 69.4139
# INFO:tensorflow:loss = 0.16879846, step = 25407 (1.441 sec)
# INFO:tensorflow:global_step/sec: 70.2092
# INFO:tensorflow:loss = 0.14357734, step = 25507 (1.425 sec)
# INFO:tensorflow:global_step/sec: 73.0329
# INFO:tensorflow:loss = 0.09870908, step = 25607 (1.369 sec)
# INFO:tensorflow:global_step/sec: 73.3259
# INFO:tensorflow:loss = 0.1488092, step = 25707 (1.365 sec)
# INFO:tensorflow:global_step/sec: 74.6211
# INFO:tensorflow:loss = 0.115806535, step = 25807 (1.339 sec)
# INFO:tensorflow:global_step/sec: 71.8931
# INFO:tensorflow:loss = 0.08828473, step = 25907 (1.391 sec)
# INFO:tensorflow:global_step/sec: 74.3706
# INFO:tensorflow:loss = 0.22016469, step = 26007 (1.345 sec)
# INFO:tensorflow:global_step/sec: 74.9431
# INFO:tensorflow:loss = 0.091044046, step = 26107 (1.335 sec)
# INFO:tensorflow:global_step/sec: 75.3023
# INFO:tensorflow:loss = 0.11664929, step = 26207 (1.327 sec)
# INFO:tensorflow:global_step/sec: 79.1626
# INFO:tensorflow:loss = 0.11403633, step = 26307 (1.263 sec)
# INFO:tensorflow:global_step/sec: 77.6583
# INFO:tensorflow:loss = 0.091275066, step = 26407 (1.288 sec)
# INFO:tensorflow:global_step/sec: 76.7318
# INFO:tensorflow:loss = 0.08925551, step = 26507 (1.304 sec)
# INFO:tensorflow:global_step/sec: 68.5828
# INFO:tensorflow:loss = 0.106357194, step = 26607 (1.460 sec)
# INFO:tensorflow:global_step/sec: 68.8643
# INFO:tensorflow:loss = 0.10966337, step = 26707 (1.452 sec)
# INFO:tensorflow:global_step/sec: 73.7111
# INFO:tensorflow:loss = 0.12780307, step = 26807 (1.356 sec)
# INFO:tensorflow:global_step/sec: 66.4911
# INFO:tensorflow:loss = 0.08976067, step = 26907 (1.505 sec)
# INFO:tensorflow:global_step/sec: 75.1261
# INFO:tensorflow:loss = 0.09038764, step = 27007 (1.329 sec)
# INFO:tensorflow:global_step/sec: 77.6841
# INFO:tensorflow:loss = 0.13160929, step = 27107 (1.287 sec)
# INFO:tensorflow:global_step/sec: 79.3071
# INFO:tensorflow:loss = 0.108286865, step = 27207 (1.261 sec)
# INFO:tensorflow:global_step/sec: 79.9268
# INFO:tensorflow:loss = 0.09653993, step = 27307 (1.251 sec)
# INFO:tensorflow:global_step/sec: 75.8175
# INFO:tensorflow:loss = 0.12257436, step = 27407 (1.319 sec)
# INFO:tensorflow:global_step/sec: 73.659
# INFO:tensorflow:loss = 0.09891467, step = 27507 (1.358 sec)
# INFO:tensorflow:global_step/sec: 74.3376
# INFO:tensorflow:loss = 0.15895075, step = 27607 (1.346 sec)
# INFO:tensorflow:global_step/sec: 74.3619
# INFO:tensorflow:loss = 0.4430026, step = 27707 (1.345 sec)
# INFO:tensorflow:global_step/sec: 57.045
# INFO:tensorflow:loss = 0.119641036, step = 27807 (1.755 sec)
# INFO:tensorflow:global_step/sec: 67.718
# INFO:tensorflow:loss = 0.09276618, step = 27907 (1.475 sec)
# INFO:tensorflow:global_step/sec: 68.5715
# INFO:tensorflow:loss = 0.09458304, step = 28007 (1.459 sec)
# INFO:tensorflow:global_step/sec: 67.2139
# INFO:tensorflow:loss = 0.09125805, step = 28107 (1.489 sec)
# INFO:tensorflow:global_step/sec: 68.3781
# INFO:tensorflow:loss = 0.09717156, step = 28207 (1.461 sec)
# INFO:tensorflow:global_step/sec: 69.4017
# INFO:tensorflow:loss = 0.092889495, step = 28307 (1.441 sec)
# INFO:tensorflow:global_step/sec: 67.8168
# INFO:tensorflow:loss = 0.09870568, step = 28407 (1.474 sec)
# INFO:tensorflow:global_step/sec: 59.0987
# INFO:tensorflow:loss = 0.09311267, step = 28507 (1.693 sec)
# INFO:tensorflow:global_step/sec: 62.3921
# INFO:tensorflow:loss = 0.100138426, step = 28607 (1.602 sec)
# INFO:tensorflow:global_step/sec: 73.7925
# INFO:tensorflow:loss = 0.088327244, step = 28707 (1.355 sec)
# INFO:tensorflow:global_step/sec: 73.4811
# INFO:tensorflow:loss = 0.088251024, step = 28807 (1.361 sec)
# INFO:tensorflow:global_step/sec: 69.9847
# INFO:tensorflow:loss = 0.15537816, step = 28907 (1.428 sec)
# INFO:tensorflow:global_step/sec: 67.9837
# INFO:tensorflow:loss = 0.09119446, step = 29007 (1.471 sec)
# INFO:tensorflow:global_step/sec: 67.6594
# INFO:tensorflow:loss = 0.35928357, step = 29107 (1.477 sec)
# INFO:tensorflow:global_step/sec: 60.4145
# INFO:tensorflow:loss = 0.09245822, step = 29207 (1.657 sec)
# INFO:tensorflow:global_step/sec: 63.14
# INFO:tensorflow:loss = 0.09017873, step = 29307 (1.584 sec)
# INFO:tensorflow:global_step/sec: 69.8091
# INFO:tensorflow:loss = 0.082449675, step = 29407 (1.431 sec)
# INFO:tensorflow:global_step/sec: 65.8315
# INFO:tensorflow:loss = 0.09256793, step = 29507 (1.520 sec)
# INFO:tensorflow:global_step/sec: 69.0926
# INFO:tensorflow:loss = 0.110600755, step = 29607 (1.446 sec)
# INFO:tensorflow:global_step/sec: 65.6982
# INFO:tensorflow:loss = 0.098574385, step = 29707 (1.523 sec)
# INFO:tensorflow:global_step/sec: 65.9783
# INFO:tensorflow:loss = 0.116929814, step = 29807 (1.516 sec)
# INFO:tensorflow:global_step/sec: 69.9482
# INFO:tensorflow:loss = 0.15163302, step = 29907 (1.428 sec)
# INFO:tensorflow:global_step/sec: 69.1923
# INFO:tensorflow:loss = 0.116587624, step = 30007 (1.446 sec)
# INFO:tensorflow:global_step/sec: 70.1231
# INFO:tensorflow:loss = 0.13110386, step = 30107 (1.426 sec)
# INFO:tensorflow:global_step/sec: 67.5097
# INFO:tensorflow:loss = 0.09841798, step = 30207 (1.481 sec)
# INFO:tensorflow:global_step/sec: 72.1584
# INFO:tensorflow:loss = 0.12180775, step = 30307 (1.387 sec)
# INFO:tensorflow:global_step/sec: 68.0089
# INFO:tensorflow:loss = 0.19032407, step = 30407 (1.469 sec)
# INFO:tensorflow:global_step/sec: 73.139
# INFO:tensorflow:loss = 0.09351367, step = 30507 (1.367 sec)
# INFO:tensorflow:global_step/sec: 73.1022
# INFO:tensorflow:loss = 0.095712304, step = 30607 (1.368 sec)
# INFO:tensorflow:global_step/sec: 72.1149
# INFO:tensorflow:loss = 0.088576086, step = 30707 (1.386 sec)
# INFO:tensorflow:global_step/sec: 73.302
# INFO:tensorflow:loss = 0.107561156, step = 30807 (1.365 sec)
# INFO:tensorflow:global_step/sec: 71.277
# INFO:tensorflow:loss = 0.094719335, step = 30907 (1.402 sec)
# INFO:tensorflow:global_step/sec: 65.4116
# INFO:tensorflow:loss = 0.110959046, step = 31007 (1.530 sec)
# INFO:tensorflow:global_step/sec: 73.0929
# INFO:tensorflow:loss = 0.096957505, step = 31107 (1.368 sec)
# INFO:tensorflow:global_step/sec: 72.5327
# INFO:tensorflow:loss = 0.09236795, step = 31207 (1.379 sec)
# INFO:tensorflow:global_step/sec: 71.6772
# INFO:tensorflow:loss = 0.242645, step = 31307 (1.395 sec)
# INFO:tensorflow:global_step/sec: 73.6942
# INFO:tensorflow:loss = 0.09142099, step = 31407 (1.357 sec)
# INFO:tensorflow:global_step/sec: 66.7565
# INFO:tensorflow:loss = 0.09255201, step = 31507 (1.498 sec)
# INFO:tensorflow:global_step/sec: 71.4305
# INFO:tensorflow:loss = 0.09461984, step = 31607 (1.401 sec)
# INFO:tensorflow:global_step/sec: 70.6776
# INFO:tensorflow:loss = 0.086056486, step = 31707 (1.414 sec)
# INFO:tensorflow:global_step/sec: 73.5362
# INFO:tensorflow:loss = 0.42173088, step = 31807 (1.359 sec)
# INFO:tensorflow:global_step/sec: 73.242
# INFO:tensorflow:loss = 0.095132865, step = 31907 (1.366 sec)
# INFO:tensorflow:global_step/sec: 69.9948
# INFO:tensorflow:loss = 0.10588285, step = 32007 (1.429 sec)
# INFO:tensorflow:global_step/sec: 66.8518
# INFO:tensorflow:loss = 0.15578082, step = 32107 (1.496 sec)
# INFO:tensorflow:global_step/sec: 72.7154
# INFO:tensorflow:loss = 0.11114587, step = 32207 (1.375 sec)
# INFO:tensorflow:global_step/sec: 73.3189
# INFO:tensorflow:loss = 0.13507344, step = 32307 (1.365 sec)
# INFO:tensorflow:global_step/sec: 75.5054
# INFO:tensorflow:loss = 0.30450794, step = 32407 (1.324 sec)
# INFO:tensorflow:global_step/sec: 72.5039
# INFO:tensorflow:loss = 0.13073687, step = 32507 (1.379 sec)
# INFO:tensorflow:global_step/sec: 73.3795
# INFO:tensorflow:loss = 0.102515236, step = 32607 (1.363 sec)
# INFO:tensorflow:global_step/sec: 72.4624
# INFO:tensorflow:loss = 0.16718143, step = 32707 (1.380 sec)
# INFO:tensorflow:global_step/sec: 70.7979
# INFO:tensorflow:loss = 0.095002726, step = 32807 (1.413 sec)
# INFO:tensorflow:global_step/sec: 71.0342
# INFO:tensorflow:loss = 0.091852985, step = 32907 (1.407 sec)
# INFO:tensorflow:global_step/sec: 69.7184
# INFO:tensorflow:loss = 0.09142783, step = 33007 (1.434 sec)
# INFO:tensorflow:global_step/sec: 73.3415
# INFO:tensorflow:loss = 0.10093134, step = 33107 (1.364 sec)
# INFO:tensorflow:global_step/sec: 71.7556
# INFO:tensorflow:loss = 0.095201574, step = 33207 (1.393 sec)
# INFO:tensorflow:global_step/sec: 78.0912
# INFO:tensorflow:loss = 0.09375622, step = 33307 (1.281 sec)
# INFO:tensorflow:global_step/sec: 76.8705
# INFO:tensorflow:loss = 0.10718467, step = 33407 (1.301 sec)
# INFO:tensorflow:global_step/sec: 70.538
# INFO:tensorflow:loss = 0.10827376, step = 33507 (1.419 sec)
# INFO:tensorflow:global_step/sec: 71.4444
# INFO:tensorflow:loss = 0.122482836, step = 33607 (1.399 sec)
# INFO:tensorflow:global_step/sec: 75.2036
# INFO:tensorflow:loss = 0.39002693, step = 33707 (1.330 sec)
# INFO:tensorflow:global_step/sec: 75.0367
# INFO:tensorflow:loss = 0.11973234, step = 33807 (1.332 sec)
# INFO:tensorflow:global_step/sec: 72.7204
# INFO:tensorflow:loss = 0.09656002, step = 33907 (1.376 sec)
# INFO:tensorflow:global_step/sec: 71.8373
# INFO:tensorflow:loss = 0.0882629, step = 34007 (1.392 sec)
# INFO:tensorflow:global_step/sec: 69.5449
# INFO:tensorflow:loss = 0.102303535, step = 34107 (1.438 sec)
# INFO:tensorflow:global_step/sec: 72.3217
# INFO:tensorflow:loss = 0.09367536, step = 34207 (1.382 sec)
# INFO:tensorflow:global_step/sec: 72.713
# INFO:tensorflow:loss = 0.10019678, step = 34307 (1.375 sec)
# INFO:tensorflow:global_step/sec: 75.4291
# INFO:tensorflow:loss = 0.08609284, step = 34407 (1.326 sec)
# INFO:tensorflow:global_step/sec: 74.5469
# INFO:tensorflow:loss = 0.09319544, step = 34507 (1.341 sec)
# INFO:tensorflow:global_step/sec: 77.9751
# INFO:tensorflow:loss = 0.1037651, step = 34607 (1.283 sec)
# INFO:tensorflow:global_step/sec: 73.4435
# INFO:tensorflow:loss = 0.09175764, step = 34707 (1.361 sec)
# INFO:tensorflow:global_step/sec: 73.8646
# INFO:tensorflow:loss = 0.12931937, step = 34807 (1.354 sec)
# INFO:tensorflow:global_step/sec: 70.5182
# INFO:tensorflow:loss = 0.15273575, step = 34907 (1.419 sec)
# INFO:tensorflow:global_step/sec: 72.289
# INFO:tensorflow:loss = 0.14740098, step = 35007 (1.383 sec)
# INFO:tensorflow:global_step/sec: 66.8493
# INFO:tensorflow:loss = 0.12848505, step = 35107 (1.497 sec)
# INFO:tensorflow:global_step/sec: 66.7517
# INFO:tensorflow:loss = 0.095125936, step = 35207 (1.498 sec)
# INFO:tensorflow:global_step/sec: 67.2427
# INFO:tensorflow:loss = 0.09542717, step = 35307 (1.487 sec)
# INFO:tensorflow:global_step/sec: 64.5185
# INFO:tensorflow:loss = 0.10916478, step = 35407 (1.552 sec)
# INFO:tensorflow:global_step/sec: 67.7366
# INFO:tensorflow:loss = 0.09001324, step = 35507 (1.475 sec)
# INFO:tensorflow:global_step/sec: 68.7038
# INFO:tensorflow:loss = 0.10380068, step = 35607 (1.454 sec)
# INFO:tensorflow:global_step/sec: 70.3067
# INFO:tensorflow:loss = 0.09039604, step = 35707 (1.424 sec)
# INFO:tensorflow:global_step/sec: 70.0053
# INFO:tensorflow:loss = 0.08920291, step = 35807 (1.426 sec)
# INFO:tensorflow:global_step/sec: 64.9817
# INFO:tensorflow:loss = 0.085548714, step = 35907 (1.538 sec)
# INFO:tensorflow:global_step/sec: 73.5162
# INFO:tensorflow:loss = 0.10254218, step = 36007 (1.360 sec)
# INFO:tensorflow:global_step/sec: 60.9552
# INFO:tensorflow:loss = 0.093241, step = 36107 (1.642 sec)
# INFO:tensorflow:global_step/sec: 73.1185
# INFO:tensorflow:loss = 0.112568565, step = 36207 (1.367 sec)
# INFO:tensorflow:global_step/sec: 73.2898
# INFO:tensorflow:loss = 0.117710724, step = 36307 (1.365 sec)
# INFO:tensorflow:global_step/sec: 72.0867
# INFO:tensorflow:loss = 0.088923216, step = 36407 (1.387 sec)
# INFO:tensorflow:global_step/sec: 71.3482
# INFO:tensorflow:loss = 0.1255882, step = 36507 (1.401 sec)
# INFO:tensorflow:global_step/sec: 68.5269
# INFO:tensorflow:loss = 0.086197816, step = 36607 (1.462 sec)
# INFO:tensorflow:global_step/sec: 62.0801
# INFO:tensorflow:loss = 0.09519836, step = 36707 (1.611 sec)
# INFO:tensorflow:global_step/sec: 68.6412
# INFO:tensorflow:loss = 0.10350099, step = 36807 (1.456 sec)
# INFO:tensorflow:global_step/sec: 73.2888
# INFO:tensorflow:loss = 0.14032115, step = 36907 (1.362 sec)
# INFO:tensorflow:global_step/sec: 74.5397
# INFO:tensorflow:loss = 0.12254347, step = 37007 (1.342 sec)
# INFO:tensorflow:global_step/sec: 67.1345
# INFO:tensorflow:loss = 0.13875967, step = 37107 (1.489 sec)
# INFO:tensorflow:global_step/sec: 76.9826
# INFO:tensorflow:loss = 0.23152249, step = 37207 (1.299 sec)
# INFO:tensorflow:global_step/sec: 76.266
# INFO:tensorflow:loss = 0.13530277, step = 37307 (1.311 sec)
# INFO:tensorflow:global_step/sec: 75.5976
# INFO:tensorflow:loss = 0.124984674, step = 37407 (1.324 sec)
# INFO:tensorflow:global_step/sec: 73.5757
# INFO:tensorflow:loss = 0.097107045, step = 37507 (1.358 sec)
# INFO:tensorflow:global_step/sec: 77.4363
# INFO:tensorflow:loss = 0.101411656, step = 37607 (1.292 sec)
# INFO:tensorflow:global_step/sec: 73.9007
# INFO:tensorflow:loss = 0.09929028, step = 37707 (1.353 sec)
# INFO:tensorflow:global_step/sec: 77.8589
# INFO:tensorflow:loss = 0.11119461, step = 37807 (1.284 sec)
# INFO:tensorflow:global_step/sec: 77.8538
# INFO:tensorflow:loss = 0.09166143, step = 37907 (1.285 sec)
# INFO:tensorflow:global_step/sec: 76.1237
# INFO:tensorflow:loss = 0.08867741, step = 38007 (1.313 sec)
# INFO:tensorflow:global_step/sec: 77.8433
# INFO:tensorflow:loss = 0.088963546, step = 38107 (1.285 sec)
# INFO:tensorflow:global_step/sec: 78.5073
# INFO:tensorflow:loss = 0.10261318, step = 38207 (1.274 sec)
# INFO:tensorflow:global_step/sec: 73.4266
# INFO:tensorflow:loss = 0.088907495, step = 38307 (1.362 sec)
# INFO:tensorflow:global_step/sec: 76.675
# INFO:tensorflow:loss = 0.09039802, step = 38407 (1.304 sec)
# INFO:tensorflow:global_step/sec: 78.6459
# INFO:tensorflow:loss = 0.10187659, step = 38507 (1.273 sec)
# INFO:tensorflow:global_step/sec: 78.1371
# INFO:tensorflow:loss = 0.086019814, step = 38607 (1.278 sec)
# INFO:tensorflow:global_step/sec: 66.6472
# INFO:tensorflow:loss = 0.089316644, step = 38707 (1.501 sec)
# INFO:tensorflow:global_step/sec: 60.159
# INFO:tensorflow:loss = 0.08498314, step = 38807 (1.664 sec)
# INFO:tensorflow:global_step/sec: 72.8967
# INFO:tensorflow:loss = 0.14727303, step = 38907 (1.369 sec)
# INFO:tensorflow:global_step/sec: 74.4201
# INFO:tensorflow:loss = 0.091873795, step = 39007 (1.344 sec)
# INFO:tensorflow:global_step/sec: 78.3553
# INFO:tensorflow:loss = 0.09052983, step = 39107 (1.277 sec)
# INFO:tensorflow:global_step/sec: 77.0106
# INFO:tensorflow:loss = 0.35484296, step = 39207 (1.298 sec)
# INFO:tensorflow:global_step/sec: 76.4232
# INFO:tensorflow:loss = 0.09376649, step = 39307 (1.309 sec)
# INFO:tensorflow:global_step/sec: 72.2262
# INFO:tensorflow:loss = 0.085290425, step = 39407 (1.386 sec)
# INFO:tensorflow:global_step/sec: 73.1718
# INFO:tensorflow:loss = 0.1464074, step = 39507 (1.366 sec)
# INFO:tensorflow:global_step/sec: 74.0352
# INFO:tensorflow:loss = 0.09793321, step = 39607 (1.350 sec)
# INFO:tensorflow:global_step/sec: 72.1567
# INFO:tensorflow:loss = 0.1193281, step = 39707 (1.386 sec)
# INFO:tensorflow:global_step/sec: 75.0531
# INFO:tensorflow:loss = 0.11186431, step = 39807 (1.332 sec)
# INFO:tensorflow:global_step/sec: 73.0336
# INFO:tensorflow:loss = 0.09487443, step = 39907 (1.371 sec)
# INFO:tensorflow:global_step/sec: 70.6777
# INFO:tensorflow:loss = 0.1017332, step = 40007 (1.413 sec)
# INFO:tensorflow:global_step/sec: 65.3758
# INFO:tensorflow:loss = 0.09847071, step = 40107 (1.530 sec)
# INFO:tensorflow:global_step/sec: 70.1457
# INFO:tensorflow:loss = 0.08969128, step = 40207 (1.425 sec)
# INFO:tensorflow:global_step/sec: 72.5478
# INFO:tensorflow:loss = 0.08733855, step = 40307 (1.379 sec)
# INFO:tensorflow:global_step/sec: 74.0109
# INFO:tensorflow:loss = 0.091902316, step = 40407 (1.352 sec)
# INFO:tensorflow:global_step/sec: 74.4494
# INFO:tensorflow:loss = 0.08986504, step = 40507 (1.342 sec)
# INFO:tensorflow:global_step/sec: 79.0441
# INFO:tensorflow:loss = 0.109724134, step = 40607 (1.265 sec)
# INFO:tensorflow:global_step/sec: 80.3539
# INFO:tensorflow:loss = 0.09323846, step = 40707 (1.245 sec)
# INFO:tensorflow:global_step/sec: 79.7279
# INFO:tensorflow:loss = 0.0895199, step = 40807 (1.254 sec)
# INFO:tensorflow:global_step/sec: 77.4958
# INFO:tensorflow:loss = 0.09285126, step = 40907 (1.290 sec)
# INFO:tensorflow:global_step/sec: 79.4708
# INFO:tensorflow:loss = 0.10063448, step = 41007 (1.259 sec)
# INFO:tensorflow:global_step/sec: 71.5057
# INFO:tensorflow:loss = 0.09488185, step = 41107 (1.400 sec)
# INFO:tensorflow:global_step/sec: 64.0835
# INFO:tensorflow:loss = 0.09608132, step = 41207 (1.559 sec)
# INFO:tensorflow:global_step/sec: 75.787
# INFO:tensorflow:loss = 0.08713148, step = 41307 (1.319 sec)
# INFO:tensorflow:global_step/sec: 81.4661
# INFO:tensorflow:loss = 0.09375856, step = 41407 (1.227 sec)
# INFO:tensorflow:global_step/sec: 81.1679
# INFO:tensorflow:loss = 0.08856128, step = 41507 (1.232 sec)
# INFO:tensorflow:global_step/sec: 77.1858
# INFO:tensorflow:loss = 0.15183693, step = 41607 (1.297 sec)
# INFO:tensorflow:global_step/sec: 75.304
# INFO:tensorflow:loss = 0.10499669, step = 41707 (1.327 sec)
# INFO:tensorflow:global_step/sec: 80.6491
# INFO:tensorflow:loss = 0.09611169, step = 41807 (1.240 sec)
# INFO:tensorflow:global_step/sec: 76.1657
# INFO:tensorflow:loss = 0.098359495, step = 41907 (1.313 sec)
# INFO:tensorflow:global_step/sec: 80.0172
# INFO:tensorflow:loss = 0.25057214, step = 42007 (1.250 sec)
# INFO:tensorflow:global_step/sec: 78.8858
# INFO:tensorflow:loss = 0.13185707, step = 42107 (1.268 sec)
# INFO:tensorflow:global_step/sec: 78.6648
# INFO:tensorflow:loss = 0.09122442, step = 42207 (1.272 sec)
# INFO:tensorflow:global_step/sec: 74.9505
# INFO:tensorflow:loss = 0.093780994, step = 42307 (1.334 sec)
# INFO:tensorflow:global_step/sec: 70.2691
# INFO:tensorflow:loss = 0.1224349, step = 42407 (1.424 sec)
# INFO:tensorflow:global_step/sec: 76.4435
# INFO:tensorflow:loss = 0.09140166, step = 42507 (1.308 sec)
# INFO:tensorflow:global_step/sec: 73.9414
# INFO:tensorflow:loss = 0.12154912, step = 42607 (1.352 sec)
# INFO:tensorflow:global_step/sec: 72.5849
# INFO:tensorflow:loss = 0.09314884, step = 42707 (1.377 sec)
# INFO:tensorflow:global_step/sec: 74.2554
# INFO:tensorflow:loss = 0.09937221, step = 42807 (1.347 sec)
# INFO:tensorflow:global_step/sec: 72.0731
# INFO:tensorflow:loss = 0.085313946, step = 42907 (1.388 sec)
# INFO:tensorflow:global_step/sec: 72.3892
# INFO:tensorflow:loss = 0.09063943, step = 43007 (1.382 sec)
# INFO:tensorflow:global_step/sec: 74.3539
# INFO:tensorflow:loss = 0.1308352, step = 43107 (1.344 sec)
# INFO:tensorflow:global_step/sec: 72.9444
# INFO:tensorflow:loss = 0.096176244, step = 43207 (1.371 sec)
# INFO:tensorflow:global_step/sec: 73.9273
# INFO:tensorflow:loss = 0.102626555, step = 43307 (1.353 sec)
# INFO:tensorflow:global_step/sec: 75.3502
# INFO:tensorflow:loss = 0.10683863, step = 43407 (1.326 sec)
# INFO:tensorflow:global_step/sec: 69.3691
# INFO:tensorflow:loss = 0.093106724, step = 43507 (1.444 sec)
# INFO:tensorflow:global_step/sec: 73.6395
# INFO:tensorflow:loss = 0.09153507, step = 43607 (1.357 sec)
# INFO:tensorflow:global_step/sec: 78.0568
# INFO:tensorflow:loss = 0.08929996, step = 43707 (1.281 sec)
# INFO:tensorflow:global_step/sec: 70.6562
# INFO:tensorflow:loss = 0.14147535, step = 43807 (1.416 sec)
# INFO:tensorflow:global_step/sec: 75.5316
# INFO:tensorflow:loss = 0.106400244, step = 43907 (1.323 sec)
# INFO:tensorflow:global_step/sec: 74.589
# INFO:tensorflow:loss = 0.12786564, step = 44007 (1.341 sec)
# INFO:tensorflow:global_step/sec: 71.2235
# INFO:tensorflow:loss = 0.09045112, step = 44107 (1.405 sec)
# INFO:tensorflow:global_step/sec: 71.3168
# INFO:tensorflow:loss = 0.0862751, step = 44207 (1.402 sec)
# INFO:tensorflow:global_step/sec: 73.7225
# INFO:tensorflow:loss = 0.08622828, step = 44307 (1.356 sec)
# INFO:tensorflow:global_step/sec: 74.8371
# INFO:tensorflow:loss = 0.08792485, step = 44407 (1.336 sec)
# INFO:tensorflow:global_step/sec: 76.4989
# INFO:tensorflow:loss = 0.13462956, step = 44507 (1.307 sec)
# INFO:tensorflow:global_step/sec: 78.4611
# INFO:tensorflow:loss = 0.43485817, step = 44607 (1.275 sec)
# INFO:tensorflow:global_step/sec: 74.1456
# INFO:tensorflow:loss = 0.116389915, step = 44707 (1.349 sec)
# INFO:tensorflow:global_step/sec: 69.2604
# INFO:tensorflow:loss = 0.11552297, step = 44807 (1.444 sec)
# INFO:tensorflow:global_step/sec: 72.2372
# INFO:tensorflow:loss = 0.14519405, step = 44907 (1.385 sec)
# INFO:tensorflow:global_step/sec: 72.449
# INFO:tensorflow:loss = 0.100304544, step = 45007 (1.380 sec)
# INFO:tensorflow:global_step/sec: 75.6156
# INFO:tensorflow:loss = 0.09340978, step = 45107 (1.322 sec)
# INFO:tensorflow:global_step/sec: 73.3978
# INFO:tensorflow:loss = 0.112483, step = 45207 (1.363 sec)
# INFO:tensorflow:global_step/sec: 77.0041
# INFO:tensorflow:loss = 0.09991494, step = 45307 (1.298 sec)
# INFO:tensorflow:global_step/sec: 76.9564
# INFO:tensorflow:loss = 0.10730934, step = 45407 (1.300 sec)
# INFO:tensorflow:global_step/sec: 76.5269
# INFO:tensorflow:loss = 0.086167715, step = 45507 (1.307 sec)
# INFO:tensorflow:global_step/sec: 73.7859
# INFO:tensorflow:loss = 0.09440485, step = 45607 (1.355 sec)
# INFO:tensorflow:global_step/sec: 73.559
# INFO:tensorflow:loss = 0.09277233, step = 45707 (1.360 sec)
# INFO:tensorflow:global_step/sec: 74.3827
# INFO:tensorflow:loss = 0.16122946, step = 45807 (1.344 sec)
# INFO:tensorflow:global_step/sec: 74.4722
# INFO:tensorflow:loss = 0.09492721, step = 45907 (1.343 sec)
# INFO:tensorflow:global_step/sec: 70.1924
# INFO:tensorflow:loss = 0.095644265, step = 46007 (1.425 sec)
# INFO:tensorflow:global_step/sec: 69.0344
# INFO:tensorflow:loss = 0.09984069, step = 46107 (1.448 sec)
# INFO:tensorflow:global_step/sec: 73.1927
# INFO:tensorflow:loss = 0.10011174, step = 46207 (1.367 sec)
# INFO:tensorflow:global_step/sec: 72.5165
# INFO:tensorflow:loss = 0.09157952, step = 46307 (1.379 sec)
# INFO:tensorflow:global_step/sec: 74.8278
# INFO:tensorflow:loss = 0.10789593, step = 46407 (1.337 sec)
# INFO:tensorflow:global_step/sec: 78.0988
# INFO:tensorflow:loss = 0.1063816, step = 46507 (1.280 sec)
# INFO:tensorflow:global_step/sec: 78.1035
# INFO:tensorflow:loss = 0.092540585, step = 46607 (1.280 sec)
# INFO:tensorflow:global_step/sec: 77.0081
# INFO:tensorflow:loss = 0.10747945, step = 46707 (1.299 sec)
# ...
# INFO:tensorflow:global_step/sec: 67.3491
# INFO:tensorflow:loss = 0.09008601, step = 81219 (1.483 sec)
# INFO:tensorflow:global_step/sec: 74.7427
# INFO:tensorflow:loss = 0.10076366, step = 81319 (1.338 sec)
# INFO:tensorflow:global_step/sec: 72.1439
# INFO:tensorflow:loss = 0.098999724, step = 81419 (1.387 sec)
# INFO:tensorflow:global_step/sec: 74.3183
# INFO:tensorflow:loss = 0.09274626, step = 81519 (1.344 sec)
# INFO:tensorflow:global_step/sec: 69.4876
# INFO:tensorflow:loss = 0.11025761, step = 81619 (1.439 sec)
# INFO:tensorflow:global_step/sec: 76.4121
# INFO:tensorflow:loss = 0.09894234, step = 81719 (1.309 sec)
# INFO:tensorflow:global_step/sec: 73.5944
# INFO:tensorflow:loss = 0.10376004, step = 81819 (1.359 sec)
# INFO:tensorflow:global_step/sec: 68.5581
# INFO:tensorflow:loss = 0.40099606, step = 81919 (1.459 sec)
# INFO:tensorflow:global_step/sec: 72.5467
# INFO:tensorflow:loss = 0.1256532, step = 82019 (1.379 sec)
# INFO:tensorflow:global_step/sec: 76.2087
# INFO:tensorflow:loss = 0.095372014, step = 82119 (1.312 sec)
# INFO:tensorflow:global_step/sec: 76.4153
# INFO:tensorflow:loss = 0.088132665, step = 82219 (1.309 sec)
# INFO:tensorflow:global_step/sec: 72.362
# INFO:tensorflow:loss = 0.10166124, step = 82319 (1.381 sec)
# INFO:tensorflow:global_step/sec: 75.4158
# INFO:tensorflow:loss = 0.09799849, step = 82419 (1.327 sec)
# INFO:tensorflow:global_step/sec: 76.3768
# INFO:tensorflow:loss = 0.09798184, step = 82519 (1.310 sec)
# INFO:tensorflow:global_step/sec: 73.0299
# INFO:tensorflow:loss = 0.083840735, step = 82619 (1.369 sec)
# INFO:tensorflow:global_step/sec: 59.1247
# INFO:tensorflow:loss = 0.090409145, step = 82719 (1.693 sec)
# INFO:tensorflow:global_step/sec: 68.3178
# INFO:tensorflow:loss = 0.10426258, step = 82819 (1.464 sec)
# INFO:tensorflow:global_step/sec: 65.0944
# INFO:tensorflow:loss = 0.088663146, step = 82919 (1.534 sec)
# INFO:tensorflow:global_step/sec: 66.5706
# INFO:tensorflow:loss = 0.12798828, step = 83019 (1.502 sec)
# INFO:tensorflow:global_step/sec: 64.7955
# INFO:tensorflow:loss = 0.14255285, step = 83119 (1.544 sec)
# INFO:tensorflow:global_step/sec: 67.0416
# INFO:tensorflow:loss = 0.16977388, step = 83219 (1.492 sec)
# INFO:tensorflow:global_step/sec: 57.1449
# INFO:tensorflow:loss = 0.14052406, step = 83319 (1.752 sec)
# INFO:tensorflow:global_step/sec: 61.1289
# INFO:tensorflow:loss = 0.09799015, step = 83419 (1.636 sec)
# INFO:tensorflow:global_step/sec: 65.0574
# INFO:tensorflow:loss = 0.093299836, step = 83519 (1.535 sec)
# INFO:tensorflow:global_step/sec: 69.1249
# INFO:tensorflow:loss = 0.1095066, step = 83619 (1.446 sec)
# INFO:tensorflow:global_step/sec: 68.4978
# INFO:tensorflow:loss = 0.09006203, step = 83719 (1.461 sec)
# INFO:tensorflow:global_step/sec: 71.007
# INFO:tensorflow:loss = 0.10226636, step = 83819 (1.407 sec)
# INFO:tensorflow:global_step/sec: 75.7355
# INFO:tensorflow:loss = 0.0886676, step = 83919 (1.320 sec)
# INFO:tensorflow:global_step/sec: 76.1256
# INFO:tensorflow:loss = 0.08784839, step = 84019 (1.317 sec)
# INFO:tensorflow:global_step/sec: 75.8926
# INFO:tensorflow:loss = 0.08618974, step = 84119 (1.314 sec)
# INFO:tensorflow:global_step/sec: 74.2431
# INFO:tensorflow:loss = 0.10223451, step = 84219 (1.349 sec)
# INFO:tensorflow:global_step/sec: 72.2163
# INFO:tensorflow:loss = 0.08915235, step = 84319 (1.383 sec)
# INFO:tensorflow:global_step/sec: 71.1063
# INFO:tensorflow:loss = 0.10818646, step = 84419 (1.406 sec)
# INFO:tensorflow:global_step/sec: 75.9206
# INFO:tensorflow:loss = 0.12056453, step = 84519 (1.317 sec)
# INFO:tensorflow:global_step/sec: 76.9698
# INFO:tensorflow:loss = 0.089044794, step = 84619 (1.300 sec)
# INFO:tensorflow:global_step/sec: 75.0006
# INFO:tensorflow:loss = 0.12694328, step = 84719 (1.333 sec)
# INFO:tensorflow:global_step/sec: 77.2182
# INFO:tensorflow:loss = 0.08532697, step = 84819 (1.295 sec)
# INFO:tensorflow:global_step/sec: 75.6196
# INFO:tensorflow:loss = 0.09248504, step = 84919 (1.323 sec)
# INFO:tensorflow:global_step/sec: 76.1182
# INFO:tensorflow:loss = 0.10583736, step = 85019 (1.314 sec)
# INFO:tensorflow:global_step/sec: 75.303
# INFO:tensorflow:loss = 0.11586465, step = 85119 (1.327 sec)
# INFO:tensorflow:global_step/sec: 75.278
# INFO:tensorflow:loss = 0.10991813, step = 85219 (1.328 sec)
# INFO:tensorflow:global_step/sec: 74.8549
# INFO:tensorflow:loss = 0.13228463, step = 85319 (1.337 sec)
# INFO:tensorflow:global_step/sec: 74.2082
# INFO:tensorflow:loss = 0.20995283, step = 85419 (1.347 sec)
# INFO:tensorflow:global_step/sec: 73.8636
# INFO:tensorflow:loss = 0.12996733, step = 85519 (1.356 sec)
# INFO:tensorflow:global_step/sec: 75.8832
# INFO:tensorflow:loss = 0.1154226, step = 85619 (1.317 sec)
# INFO:tensorflow:global_step/sec: 75.6356
# INFO:tensorflow:loss = 0.09470908, step = 85719 (1.322 sec)
# INFO:tensorflow:global_step/sec: 77.62
# INFO:tensorflow:loss = 0.097518325, step = 85819 (1.288 sec)
# INFO:tensorflow:global_step/sec: 70.8055
# INFO:tensorflow:loss = 0.09278084, step = 85919 (1.412 sec)
# INFO:tensorflow:global_step/sec: 75.6038
# INFO:tensorflow:loss = 0.10636053, step = 86019 (1.323 sec)
# INFO:tensorflow:global_step/sec: 68.516
# INFO:tensorflow:loss = 0.09092084, step = 86119 (1.461 sec)
# INFO:tensorflow:global_step/sec: 73.0388
# INFO:tensorflow:loss = 0.0862806, step = 86219 (1.367 sec)
# INFO:tensorflow:global_step/sec: 73.8841
# INFO:tensorflow:loss = 0.08850442, step = 86319 (1.355 sec)
# INFO:tensorflow:global_step/sec: 68.4378
# INFO:tensorflow:loss = 0.10390621, step = 86419 (1.460 sec)
# INFO:tensorflow:global_step/sec: 72.5963
# INFO:tensorflow:loss = 0.09014803, step = 86519 (1.377 sec)
# INFO:tensorflow:global_step/sec: 70.5358
# INFO:tensorflow:loss = 0.08891017, step = 86619 (1.418 sec)
# INFO:tensorflow:global_step/sec: 73.1894
# INFO:tensorflow:loss = 0.10000922, step = 86719 (1.366 sec)
# INFO:tensorflow:global_step/sec: 73.4969
# INFO:tensorflow:loss = 0.085525416, step = 86819 (1.361 sec)
# INFO:tensorflow:global_step/sec: 72.1656
# INFO:tensorflow:loss = 0.087634385, step = 86919 (1.387 sec)
# INFO:tensorflow:global_step/sec: 59.2598
# INFO:tensorflow:loss = 0.083727404, step = 87019 (1.690 sec)
# INFO:tensorflow:global_step/sec: 59.4523
# INFO:tensorflow:loss = 0.15400916, step = 87119 (1.679 sec)
# INFO:tensorflow:global_step/sec: 68.2328
# INFO:tensorflow:loss = 0.092149794, step = 87219 (1.465 sec)
# INFO:tensorflow:global_step/sec: 77.7859
# INFO:tensorflow:loss = 0.09020928, step = 87319 (1.288 sec)
# INFO:tensorflow:global_step/sec: 69.6966
# INFO:tensorflow:loss = 0.36181876, step = 87419 (1.432 sec)
# INFO:tensorflow:global_step/sec: 75.977
# INFO:tensorflow:loss = 0.095850796, step = 87519 (1.317 sec)
# INFO:tensorflow:global_step/sec: 73.4808
# INFO:tensorflow:loss = 0.085042864, step = 87619 (1.361 sec)
# INFO:tensorflow:global_step/sec: 72.9129
# INFO:tensorflow:loss = 0.14848384, step = 87719 (1.371 sec)
# INFO:tensorflow:global_step/sec: 74.9575
# INFO:tensorflow:loss = 0.09718335, step = 87819 (1.334 sec)
# INFO:tensorflow:global_step/sec: 75.9466
# INFO:tensorflow:loss = 0.12048769, step = 87919 (1.315 sec)
# INFO:tensorflow:global_step/sec: 72.7846
# INFO:tensorflow:loss = 0.11522512, step = 88019 (1.375 sec)
# INFO:tensorflow:global_step/sec: 77.4855
# INFO:tensorflow:loss = 0.09210886, step = 88119 (1.289 sec)
# INFO:tensorflow:global_step/sec: 79.8561
# INFO:tensorflow:loss = 0.10007846, step = 88219 (1.253 sec)
# INFO:tensorflow:global_step/sec: 67.7996
# INFO:tensorflow:loss = 0.10119109, step = 88319 (1.477 sec)
# INFO:tensorflow:global_step/sec: 55.0422
# INFO:tensorflow:loss = 0.089228615, step = 88419 (1.818 sec)
# INFO:tensorflow:global_step/sec: 63.9232
# INFO:tensorflow:loss = 0.086411834, step = 88519 (1.562 sec)
# INFO:tensorflow:global_step/sec: 66.0625
# INFO:tensorflow:loss = 0.09056377, step = 88619 (1.514 sec)
# INFO:tensorflow:global_step/sec: 72.816
# INFO:tensorflow:loss = 0.08886345, step = 88719 (1.374 sec)
# INFO:tensorflow:global_step/sec: 68.1818
# INFO:tensorflow:loss = 0.11225907, step = 88819 (1.466 sec)
# INFO:tensorflow:global_step/sec: 72.9989
# INFO:tensorflow:loss = 0.09288827, step = 88919 (1.369 sec)
# INFO:tensorflow:global_step/sec: 76.3645
# INFO:tensorflow:loss = 0.08805406, step = 89019 (1.309 sec)
# INFO:tensorflow:global_step/sec: 76.5045
# INFO:tensorflow:loss = 0.093574725, step = 89119 (1.307 sec)
# INFO:tensorflow:global_step/sec: 76.4212
# INFO:tensorflow:loss = 0.0989972, step = 89219 (1.309 sec)
# INFO:tensorflow:global_step/sec: 75.9738
# INFO:tensorflow:loss = 0.09624492, step = 89319 (1.316 sec)
# INFO:tensorflow:global_step/sec: 75.4285
# INFO:tensorflow:loss = 0.09116962, step = 89419 (1.328 sec)
# INFO:tensorflow:global_step/sec: 77.9446
# INFO:tensorflow:loss = 0.085606985, step = 89519 (1.281 sec)
# INFO:tensorflow:global_step/sec: 70.9358
# INFO:tensorflow:loss = 0.09259816, step = 89619 (1.411 sec)
# INFO:tensorflow:global_step/sec: 77.6239
# INFO:tensorflow:loss = 0.0875162, step = 89719 (1.287 sec)
# INFO:tensorflow:global_step/sec: 74.8511
# INFO:tensorflow:loss = 0.15194973, step = 89819 (1.338 sec)
# INFO:tensorflow:global_step/sec: 62.3464
# INFO:tensorflow:loss = 0.10363463, step = 89919 (1.602 sec)
# INFO:tensorflow:global_step/sec: 76.9032
# INFO:tensorflow:loss = 0.094555184, step = 90019 (1.300 sec)
# INFO:tensorflow:global_step/sec: 73.3999
# INFO:tensorflow:loss = 0.09723046, step = 90119 (1.362 sec)
# INFO:tensorflow:global_step/sec: 73.3789
# INFO:tensorflow:loss = 0.25182644, step = 90219 (1.362 sec)
# INFO:tensorflow:global_step/sec: 76.4426
# INFO:tensorflow:loss = 0.122108184, step = 90319 (1.309 sec)
# INFO:tensorflow:global_step/sec: 51.443
# INFO:tensorflow:loss = 0.09038183, step = 90419 (1.946 sec)
# INFO:tensorflow:global_step/sec: 67.7714
# INFO:tensorflow:loss = 0.093927324, step = 90519 (1.474 sec)
# INFO:tensorflow:global_step/sec: 72.651
# INFO:tensorflow:loss = 0.11604111, step = 90619 (1.375 sec)
# INFO:tensorflow:global_step/sec: 72.3339
# INFO:tensorflow:loss = 0.09117319, step = 90719 (1.383 sec)
# INFO:tensorflow:global_step/sec: 70.3036
# INFO:tensorflow:loss = 0.12485005, step = 90819 (1.422 sec)
# INFO:tensorflow:global_step/sec: 75.2961
# INFO:tensorflow:loss = 0.09111663, step = 90919 (1.328 sec)
# INFO:tensorflow:global_step/sec: 77.6609
# INFO:tensorflow:loss = 0.093528055, step = 91019 (1.288 sec)
# INFO:tensorflow:global_step/sec: 74.9172
# INFO:tensorflow:loss = 0.08418732, step = 91119 (1.335 sec)
# INFO:tensorflow:global_step/sec: 73.5805
# INFO:tensorflow:loss = 0.09064545, step = 91219 (1.359 sec)
# INFO:tensorflow:global_step/sec: 75.8804
# INFO:tensorflow:loss = 0.12825827, step = 91319 (1.318 sec)
# INFO:tensorflow:global_step/sec: 74.6247
# INFO:tensorflow:loss = 0.09153245, step = 91419 (1.340 sec)
# INFO:tensorflow:global_step/sec: 71.6564
# INFO:tensorflow:loss = 0.10154964, step = 91519 (1.396 sec)
# INFO:tensorflow:global_step/sec: 76.9488
# INFO:tensorflow:loss = 0.10310061, step = 91619 (1.299 sec)
# INFO:tensorflow:global_step/sec: 76.1999
# INFO:tensorflow:loss = 0.094866075, step = 91719 (1.313 sec)
# INFO:tensorflow:global_step/sec: 76.2791
# INFO:tensorflow:loss = 0.095635824, step = 91819 (1.311 sec)
# INFO:tensorflow:global_step/sec: 78.3468
# INFO:tensorflow:loss = 0.085460775, step = 91919 (1.277 sec)
# INFO:tensorflow:global_step/sec: 77.4288
# INFO:tensorflow:loss = 0.13389975, step = 92019 (1.291 sec)
# INFO:tensorflow:global_step/sec: 76.9825
# INFO:tensorflow:loss = 0.10487485, step = 92119 (1.299 sec)
# INFO:tensorflow:global_step/sec: 60.8954
# INFO:tensorflow:loss = 0.111108944, step = 92219 (1.646 sec)
# INFO:tensorflow:global_step/sec: 71.3384
# INFO:tensorflow:loss = 0.08991338, step = 92319 (1.398 sec)
# INFO:tensorflow:global_step/sec: 74.5734
# INFO:tensorflow:loss = 0.086751014, step = 92419 (1.341 sec)
# INFO:tensorflow:global_step/sec: 75.577
# INFO:tensorflow:loss = 0.0860547, step = 92519 (1.324 sec)
# INFO:tensorflow:global_step/sec: 74.4644
# INFO:tensorflow:loss = 0.08724266, step = 92619 (1.342 sec)
# INFO:tensorflow:global_step/sec: 75.6614
# INFO:tensorflow:loss = 0.12572083, step = 92719 (1.321 sec)
# INFO:tensorflow:global_step/sec: 76.7403
# INFO:tensorflow:loss = 0.40876526, step = 92819 (1.303 sec)
# INFO:tensorflow:global_step/sec: 75.5174
# INFO:tensorflow:loss = 0.112830795, step = 92919 (1.324 sec)
# INFO:tensorflow:global_step/sec: 76.0102
# INFO:tensorflow:loss = 0.11929607, step = 93019 (1.316 sec)
# INFO:tensorflow:global_step/sec: 67.6261
# INFO:tensorflow:loss = 0.14220774, step = 93119 (1.482 sec)
# INFO:tensorflow:global_step/sec: 71.3756
# INFO:tensorflow:loss = 0.09583376, step = 93219 (1.398 sec)
# INFO:tensorflow:global_step/sec: 78.4192
# INFO:tensorflow:loss = 0.09161213, step = 93319 (1.276 sec)
# INFO:tensorflow:global_step/sec: 74.3187
# INFO:tensorflow:loss = 0.116040975, step = 93419 (1.345 sec)
# INFO:tensorflow:global_step/sec: 71.2764
# INFO:tensorflow:loss = 0.09959836, step = 93519 (1.404 sec)
# INFO:tensorflow:global_step/sec: 65.8427
# INFO:tensorflow:loss = 0.10816117, step = 93619 (1.519 sec)
# INFO:tensorflow:global_step/sec: 58.1526
# INFO:tensorflow:loss = 0.08400552, step = 93719 (1.722 sec)
# INFO:tensorflow:global_step/sec: 60.667
# INFO:tensorflow:loss = 0.09309447, step = 93819 (1.646 sec)
# INFO:tensorflow:global_step/sec: 69.7393
# INFO:tensorflow:loss = 0.091876596, step = 93919 (1.434 sec)
# INFO:tensorflow:global_step/sec: 73.0595
# INFO:tensorflow:loss = 0.12156871, step = 94019 (1.368 sec)
# INFO:tensorflow:global_step/sec: 77.1518
# INFO:tensorflow:loss = 0.09301122, step = 94119 (1.296 sec)
# INFO:tensorflow:global_step/sec: 77.3617
# INFO:tensorflow:loss = 0.094497934, step = 94219 (1.293 sec)
# INFO:tensorflow:global_step/sec: 79.0086
# INFO:tensorflow:loss = 0.09902241, step = 94319 (1.267 sec)
# INFO:tensorflow:global_step/sec: 73.8048
# INFO:tensorflow:loss = 0.10015771, step = 94419 (1.355 sec)
# INFO:tensorflow:global_step/sec: 72.8093
# INFO:tensorflow:loss = 0.08990233, step = 94519 (1.375 sec)
# INFO:tensorflow:global_step/sec: 70.9401
# INFO:tensorflow:loss = 0.10868083, step = 94619 (1.408 sec)
# INFO:tensorflow:global_step/sec: 73.4959
# INFO:tensorflow:loss = 0.10691379, step = 94719 (1.361 sec)
# INFO:tensorflow:global_step/sec: 72.3142
# INFO:tensorflow:loss = 0.09204986, step = 94819 (1.384 sec)
# INFO:tensorflow:global_step/sec: 71.8305
# INFO:tensorflow:loss = 0.11181436, step = 94919 (1.391 sec)
# INFO:tensorflow:global_step/sec: 75.9938
# INFO:tensorflow:loss = 0.13553873, step = 95019 (1.316 sec)
# INFO:tensorflow:global_step/sec: 74.6355
# INFO:tensorflow:loss = 0.12717412, step = 95119 (1.340 sec)
# INFO:tensorflow:global_step/sec: 74.2468
# INFO:tensorflow:loss = 0.21619885, step = 95219 (1.347 sec)
# INFO:tensorflow:global_step/sec: 69.9436
# INFO:tensorflow:loss = 0.08708321, step = 95319 (1.431 sec)
# INFO:tensorflow:global_step/sec: 69.119
# INFO:tensorflow:loss = 0.1163712, step = 95419 (1.445 sec)
# INFO:tensorflow:global_step/sec: 76.2451
# INFO:tensorflow:loss = 0.08669079, step = 95519 (1.311 sec)
# INFO:tensorflow:global_step/sec: 79.6533
# INFO:tensorflow:loss = 0.10137315, step = 95619 (1.256 sec)
# INFO:tensorflow:global_step/sec: 73.9678
# INFO:tensorflow:loss = 0.097521104, step = 95719 (1.352 sec)
# INFO:tensorflow:global_step/sec: 57.1992
# INFO:tensorflow:loss = 0.09194061, step = 95819 (1.751 sec)
# INFO:tensorflow:global_step/sec: 62.2841
# INFO:tensorflow:loss = 0.12049995, step = 95919 (1.602 sec)
# INFO:tensorflow:global_step/sec: 65.6685
# INFO:tensorflow:loss = 0.085889496, step = 96019 (1.524 sec)
# INFO:tensorflow:global_step/sec: 74.9519
# INFO:tensorflow:loss = 0.10970117, step = 96119 (1.333 sec)
# INFO:tensorflow:global_step/sec: 75.5042
# INFO:tensorflow:loss = 0.09593667, step = 96219 (1.324 sec)
# INFO:tensorflow:global_step/sec: 76.1362
# INFO:tensorflow:loss = 0.09309052, step = 96319 (1.313 sec)
# INFO:tensorflow:global_step/sec: 77.226
# INFO:tensorflow:loss = 0.085669324, step = 96419 (1.295 sec)
# INFO:tensorflow:Saving checkpoints for 96424 into /tmp/tf_bow_sst_20180407-1945/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.09735316.
# INFO:tensorflow:Starting evaluation at 2018-04-07-20:08:43
# INFO:tensorflow:Restoring parameters from /tmp/tf_bow_sst_20180407-1945/model.ckpt-96424
# INFO:tensorflow:Finished evaluation at 2018-04-07-20:08:55
# INFO:tensorflow:Saving dict for global step 96424: accuracy = 0.936785, cross_entropy_loss = 0.22031271, global_step = 96424, loss = 0.33872172

# %% [markdown]
# ### Testing
#
# Note -- many test examples contain explicit content

# %%
test_sents = [("ass and titties", KID_INAPPROPRIATE),
("fuck the police", KID_INAPPROPRIATE),
("cats are nice", KID_APPROPRIATE),
("one day I saw a horse on a hill and I liked it", KID_APPROPRIATE),
("mrs. tayler is a whore", KID_INAPPROPRIATE),
("I'd like to take you someplace nice and quiet", KID_INAPPROPRIATE),
("You gay ? Proceeds to chase him that's how bullying works", KID_INAPPROPRIATE),
("transfer responsibility dad temperature earn voter impossible radiation.", KID_APPROPRIATE),
("JADE CHYNOWETH AND JOSH KILLACKY LOVETEAM PLS", KID_APPROPRIATE),
("Lol, looks like the same generic crap you come to expect from these types of shows.  Guess it doesn't get old for some people.", KID_INAPPROPRIATE),
("Disney sold the rights to this?", KID_APPROPRIATE),
("Only step up 1 and 2 were good. All of the other ones have just been corny.", KID_APPROPRIATE),
("i rather not call it step up, its another level with different camera techniques and its so Channing Tatum style", KID_APPROPRIATE),
("I love the series its very good, im waiting for 2 one", KID_APPROPRIATE),
("GREAT", KID_APPROPRIATE),
("Job negotiate set alternative little introduction apparent crazy proper used care free.", KID_APPROPRIATE),
("Oxygen identify member dependent translate else card might handful.", KID_APPROPRIATE),
("Release accompany pole general something widely fly cup detective personnel.", KID_APPROPRIATE),
("Silly largely obstacle warrior charge flavor diabetes medal.", KID_APPROPRIATE),
("We need moose back", KID_APPROPRIATE),
("Exciting time to be alive bro watching our Prez Trump vs. the DeepState/Swamp that's the deal profs to him.", KID_APPROPRIATE),
("Idk if I want to watch it or not : ^/", KID_APPROPRIATE),
("Maximum testing blanket absolutely shock until actress sex liability.", KID_INAPPROPRIATE),
("3 was the best.", KID_APPROPRIATE),
("I knew they would have a all men gay dance group", KID_INAPPROPRIATE),
("Same old garbage; I'm sick of it !", KID_APPROPRIATE),
("GAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAYYYYYYYYYYYYYYYYYYYYYYYYY",KID_INAPPROPRIATE),
("Millenials = The worst generation",KID_APPROPRIATE),
("that opening statement is the most overused sentence i've seen",KID_APPROPRIATE),
("Pan spokesman via guard campaign characteristic movement expert attend garage.",KID_APPROPRIATE),
("ayyy https://youtu.be/wZwyQZDfyHY",KID_APPROPRIATE),
("WELP....the end of the step up franchise met a very disappointing end. Jesus this looks worse than most dumpster fires Ive seen",KID_APPROPRIATE),
("blacks that look white and wiggas.  yeah, looks great. (not!)",KID_INAPPROPRIATE),
("Rich And Diverse artistry- Advocating White Genocide. How is enrichment going on in South Africa?",KID_INAPPROPRIATE),
("step up <3",KID_APPROPRIATE),
("When is episode 5 coming out",KID_APPROPRIATE),
("This series is actually pretty good...watched it and was so happy I gave it a shot; I loved it! The storyline is actually stronger than I expected, and especially where they left off this first season, I'm so excited for what's to come; I hope they keep up the good work and produce even more (authentic stuff next season.",KID_APPROPRIATE),
("https://vk.com/club162181675 вступайте",KID_APPROPRIATE),
("lunch argument across expansion free govern healthy afternoon.",KID_APPROPRIATE),
("Modern day version of Fame!",KID_APPROPRIATE),
("Neyo!",KID_APPROPRIATE),
("I wasn't expecting this from YouTube but it's really good",KID_APPROPRIATE),
("The",KID_APPROPRIATE),
("what garbage i this want to be step up is more like stomp the yard",KID_APPROPRIATE),
("if you're actually thinking of watching this show... do it. i recommend it. it's so much more than what we ever got to see from step up or any dance movies at all. so much diversity & so many topics it's talking about. i was surprised at how much i actually enjoyed the show & how bad i need a (second season. just give it a try since the first 4 episodes are for free on here, i don't think y'all are gonna regret it",KID_APPROPRIATE),
("Aren’t u guys releasing more seasons and episodes??? we still need more of ‘em",KID_APPROPRIATE),
("Have Chris brown in the step up movies it’ll be dope",KID_APPROPRIATE),
("http://hikmatblogs.blogspot.com/2018/02/10-ways-to-improve-your-finances-today.html",KID_APPROPRIATE),
("No Moose no Step Up",KID_APPROPRIATE),
("Let me guess?? Suburban girl trying to prove her gangsta and most of the black men are gay.... WHACK!!!",KID_INAPPROPRIATE),
("What, no moose cameo ?",KID_APPROPRIATE),
("trash.",KID_APPROPRIATE),
("Why does everything have to be so gay  won't be watching this sick of all our black men in tv series being gay smh",KID_INAPPROPRIATE),
("Who's that girl on the trailer cover?",KID_APPROPRIATE),
("Atlanta is a n!66er filled cesspool.. i can't figure out why parents stopped teaching their children white from wrong.. why today's youth wants grey babies.. why ruin family pictures with those half n!66e kinky haired flat nosed kids..  why these fathers aren't teaching their daughters to stay off the chimpdicks.. i mean, for real, how low does your self esteem have to be to want to share your beautiful young white body with these savage nigloyds... i'm sorry your fathers have failed you girls.. I taught mine white from wrong.. my grandkids will be bright white with blonde hair and blue eyes.. not gray with kinky rugs and flat noses.. just the idea of beautiful young white girls with sweaty, greasy n!66ers up on them just makes me wanna puke.. parents.. it's time to start teaching some basic family values again.. not the kardashian kind where they just keep getting impregnated by stray chimps.. it's just disgusting... let's clean up and keep the white blood lines free from contaminants..  you young white girls... just say no.. find a decent white boy to make babies with.. you can't tell me that a n!66er is all you can get..  well, maybe the fat ugly girls.. but even you can do better.. find a fat ugly white guy..  give him that poontang .. not these foot stomping, drum banging monkeys .. talentless rappers...  all wanna pretend they are in the music business.. rap isn't music.. any tar baby can get a drum machine and call it a beat lab.. then they steal a macbook from a white girl.. and start their career as the white girl's baby daddy.. she says he's a musician.. but he's really just another worthless n166er  he will keep her on welfare.. just a waste.. february is black history month.. the other 11 is caucasian (history months.. we will celebrate by taking our women back..",KID_INAPPROPRIATE),
("i run them streetsXD",KID_APPROPRIATE),
("my answer is....hell noXD",KID_APPROPRIATE),
("Sail star diamond rate working love pond size that monument prevention celebrate.",KID_APPROPRIATE),
("So is Kevin Bacon they're Jesus or something?",KID_APPROPRIATE),
("Can someone please give me the name of the girl on the thumbnail please ?????",KID_APPROPRIATE),
("I would rather be prison raped than watch 5seconds of this garbage",KID_INAPPROPRIATE),
("Prosecution tool before endless visit dump shake sake remarkable hurt safe public.",KID_APPROPRIATE),
("total grief slave esyvbp question fourth fun basic fly sacrifice reply.",KID_INAPPROPRIATE),
("As she named the Empress, Anna Pávlovna’s face suddenly assumed an expression of profound and sincere devotion and respect mingled with sadness, and this occurred every time she mentioned her illustrious patroness. ", KID_INAPPROPRIATE),
("She added that Her Majesty had deigned to show Baron Funke beaucoup d’estime, and again her face clouded over with sadness.", KID_INAPPROPRIATE),
("The prince was silent and looked indifferent. ", KID_APPROPRIATE),
("But, with the womanly and courtierlike quickness and tact habitual to her, Anna Pávlovna wished both to rebuke him (for daring to speak as he had done of a ma ", KID_INAPPROPRIATE),
("recommended to the Empress) and at the same time to console him, so she said ", KID_INAPPROPRIATE)]

# %%
test_tokens = [tokenizer.tokenize(x[0]) for x in test_sents]

test_tokens_canonical = [utils.canonicalize_words(x) for x in test_tokens]

test_ids = [vocab.words_to_ids(x) for x in test_tokens_canonical]

test_x, test_ns, test_y = [],[],[]

for i,x in enumerate(test_ids):

    padded, orig_len = pad_array(x,pad_len)

    test_x.append(padded)
    test_ns.append(orig_len)
    test_y.append(test_sents[i][1])

test_x_np = np.array(test_x)
test_ns_np = np.array(test_ns)
test_y_np = np.array(test_y)

# %%
test_input_fn = tf.estimator.inputs.numpy_input_fn(
                    x={"ids": test_x_np, "ns": test_ns_np}, y=test_y_np,
                    batch_size=128, num_epochs=1, shuffle=False
                )

eval_metrics = model.evaluate(input_fn=test_input_fn, name="eval")

#### END(YOUR CODE) ####
print("Accuracy on test set: {:.02%}".format(eval_metrics['accuracy']))
eval_metrics
# Out:
# INFO:tensorflow:Starting evaluation at 2018-04-07-20:08:57
# INFO:tensorflow:Restoring parameters from /tmp/tf_bow_sst_20180407-1945/model.ckpt-96424
# INFO:tensorflow:Finished evaluation at 2018-04-07-20:08:59
# INFO:tensorflow:Saving dict for global step 96424: accuracy = 0.4117647, cross_entropy_loss = 2.2264147, global_step = 96424, loss = 2.314845
# Accuracy on test set: 41.18%
# {'accuracy': 0.4117647,
#  'cross_entropy_loss': 2.2264147,
#  'global_step': 96424,
#  'loss': 2.314845}

# %%
from sklearn.metrics import accuracy_score
predictions = list(model.predict(test_input_fn))  # list of dicts
y_pred = [p['max'] for p in predictions]
acc = accuracy_score(y_pred, test_y)
print("Accuracy on test set: {:.02%}".format(acc))
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/tf_bow_sst_20180407-1945/model.ckpt-96424
# Accuracy on test set: 41.18%

# %% [markdown]
# ### Error Analysis

# %%
param_names = {KID_APPROPRIATE:   "Appropriate  ",
               KID_INAPPROPRIATE: "Inappropriate"}
template = "Sentence  :   {}\nPredicted :   {} \nActual    :   {}  \n\n" 
for i, example in enumerate(y_pred):
    print(template.format(test_sents[i][0], param_names[y_pred[i]], param_names[test_sents[i][1]]))
# Out:
# Sentence  :   ass and titties
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   fuck the police
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   cats are nice
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   one day I saw a horse on a hill and I liked it
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   mrs. tayler is a whore
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   I'd like to take you someplace nice and quiet
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   You gay ? Proceeds to chase him that's how bullying works
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   transfer responsibility dad temperature earn voter impossible radiation.
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   JADE CHYNOWETH AND JOSH KILLACKY LOVETEAM PLS
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Lol, looks like the same generic crap you come to expect from these types of shows.  Guess it doesn't get old for some people.
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   Disney sold the rights to this?
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Only step up 1 and 2 were good. All of the other ones have just been corny.
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   i rather not call it step up, its another level with different camera techniques and its so Channing Tatum style
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   I love the series its very good, im waiting for 2 one
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   GREAT
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Job negotiate set alternative little introduction apparent crazy proper used care free.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Oxygen identify member dependent translate else card might handful.
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Release accompany pole general something widely fly cup detective personnel.
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Silly largely obstacle warrior charge flavor diabetes medal.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   We need moose back
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Exciting time to be alive bro watching our Prez Trump vs. the DeepState/Swamp that's the deal profs to him.
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Idk if I want to watch it or not : ^/
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Maximum testing blanket absolutely shock until actress sex liability.
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   3 was the best.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   I knew they would have a all men gay dance group
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   Same old garbage; I'm sick of it !
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   GAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAYYYYYYYYYYYYYYYYYYYYYYYYY
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   Millenials = The worst generation
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   that opening statement is the most overused sentence i've seen
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Pan spokesman via guard campaign characteristic movement expert attend garage.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   ayyy https://youtu.be/wZwyQZDfyHY
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   WELP....the end of the step up franchise met a very disappointing end. Jesus this looks worse than most dumpster fires Ive seen
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   blacks that look white and wiggas.  yeah, looks great. (not!)
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   Rich And Diverse artistry- Advocating White Genocide. How is enrichment going on in South Africa?
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   step up <3
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   When is episode 5 coming out
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   This series is actually pretty good...watched it and was so happy I gave it a shot; I loved it! The storyline is actually stronger than I expected, and especially where they left off this first season, I'm so excited for what's to come; I hope they keep up the good work and produce even more (authentic stuff next season.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   https://vk.com/club162181675 вступайте
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   lunch argument across expansion free govern healthy afternoon.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Modern day version of Fame!
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Neyo!
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   I wasn't expecting this from YouTube but it's really good
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   The
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   what garbage i this want to be step up is more like stomp the yard
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   if you're actually thinking of watching this show... do it. i recommend it. it's so much more than what we ever got to see from step up or any dance movies at all. so much diversity & so many topics it's talking about. i was surprised at how much i actually enjoyed the show & how bad i need a (second season. just give it a try since the first 4 episodes are for free on here, i don't think y'all are gonna regret it
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Aren’t u guys releasing more seasons and episodes??? we still need more of ‘em
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Have Chris brown in the step up movies it’ll be dope
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   http://hikmatblogs.blogspot.com/2018/02/10-ways-to-improve-your-finances-today.html
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   No Moose no Step Up
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Let me guess?? Suburban girl trying to prove her gangsta and most of the black men are gay.... WHACK!!!
# Predicted :   Appropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   What, no moose cameo ?
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   trash.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Why does everything have to be so gay  won't be watching this sick of all our black men in tv series being gay smh
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   Who's that girl on the trailer cover?
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Atlanta is a n!66er filled cesspool.. i can't figure out why parents stopped teaching their children white from wrong.. why today's youth wants grey babies.. why ruin family pictures with those half n!66e kinky haired flat nosed kids..  why these fathers aren't teaching their daughters to stay off the chimpdicks.. i mean, for real, how low does your self esteem have to be to want to share your beautiful young white body with these savage nigloyds... i'm sorry your fathers have failed you girls.. I taught mine white from wrong.. my grandkids will be bright white with blonde hair and blue eyes.. not gray with kinky rugs and flat noses.. just the idea of beautiful young white girls with sweaty, greasy n!66ers up on them just makes me wanna puke.. parents.. it's time to start teaching some basic family values again.. not the kardashian kind where they just keep getting impregnated by stray chimps.. it's just disgusting... let's clean up and keep the white blood lines free from contaminants..  you young white girls... just say no.. find a decent white boy to make babies with.. you can't tell me that a n!66er is all you can get..  well, maybe the fat ugly girls.. but even you can do better.. find a fat ugly white guy..  give him that poontang .. not these foot stomping, drum banging monkeys .. talentless rappers...  all wanna pretend they are in the music business.. rap isn't music.. any tar baby can get a drum machine and call it a beat lab.. then they steal a macbook from a white girl.. and start their career as the white girl's baby daddy.. she says he's a musician.. but he's really just another worthless n166er  he will keep her on welfare.. just a waste.. february is black history month.. the other 11 is caucasian (history months.. we will celebrate by taking our women back..
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   i run them streetsXD
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   my answer is....hell noXD
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Sail star diamond rate working love pond size that monument prevention celebrate.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   So is Kevin Bacon they're Jesus or something?
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   Can someone please give me the name of the girl on the thumbnail please ?????
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   I would rather be prison raped than watch 5seconds of this garbage
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   Prosecution tool before endless visit dump shake sake remarkable hurt safe public.
# Predicted :   Inappropriate
# Actual    :   Appropriate
#
#
# Sentence  :   total grief slave esyvbp question fourth fun basic fly sacrifice reply.
# Predicted :   Inappropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   As she named the Empress, Anna Pávlovna’s face suddenly assumed an expression of profound and sincere devotion and respect mingled with sadness, and this occurred every time she mentioned her illustrious patroness.
# Predicted :   Appropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   She added that Her Majesty had deigned to show Baron Funke beaucoup d’estime, and again her face clouded over with sadness.
# Predicted :   Appropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   The prince was silent and looked indifferent.
# Predicted :   Appropriate
# Actual    :   Appropriate
#
#
# Sentence  :   But, with the womanly and courtierlike quickness and tact habitual to her, Anna Pávlovna wished both to rebuke him (for daring to speak as he had done of a ma
# Predicted :   Appropriate
# Actual    :   Inappropriate
#
#
# Sentence  :   recommended to the Empress) and at the same time to console him, so she said
# Predicted :   Appropriate
# Actual    :   Inappropriate

# %% [markdown]
# #### Error Notes
# -  Are long sentences incorrectly categorized?
# -  Misses innuendo (but innuendo is rare)
# -  Frequently fails random words, but that's probably ok
# -  We're training sentences against (potentially) multi-sentence comments. Is that ok?
# -  Would sentiment analysis help?
# -  Would another embedding help?
# -  Would readability scores help?
# -  Worth pursuing a hybrid sensitivity/complexity model, then combine at classification-time?
#
# #### Eng Notes
# - How can we improve speed?
# - How can we improve accuracy?
# - Would adding wikipedia set help?
# - How to adjust hyperparams
# - How to deal with memory issues

# %% [markdown]
# # RNN Classification

# %% [markdown]
# https://github.com/kamei86i/rnn-classifier-tf

# %%
import os
import random
import math

import tensorflow as tf
from embedding import *

from rnn_text_classifier import RnnTextClassifier
from sentence import Sentence

# Model parameters
rnn_num = 2
# cell_size = 64
embedding_size = 128
train_embedding = False
max_sent_length = 128

embedding_path = ""
model_dir = "runs"
summaries_dir = "summary"

dropout_keep_prob = 0
lam = 1

# Training parameters
batch_size = 128
num_epochs = 15
learning_rate = 0

PAD_TOKEN = '<PAD>'
UNK_TOKEN = '<UNK>'

TEST_FRAC = 0.2
DATASET_SIZE = 100000

if not os.path.exists(model_dir):
    os.mkdir(model_dir)

# %%
def pad_list(in_list, pad_len):
    length = len(in_list)
    if length <= pad_len:
        delta = pad_len - length
        for i in range(delta):
            in_list.append(PAD_TOKEN)
            
        return in_list, length
    if length > pad_len:
        return in_list[:pad_len], length

def get_dataset(length):
    num_pos_neg = length // 2 
    dataset = []
    labels = set([KID_APPROPRIATE, KID_INAPPROPRIATE])
    length = 0
    for idx in range(num_pos_neg):
        label = KID_APPROPRIATE
        sentence = " ".join(pos_tokens_canonical[idx])
        tokenized_sentence = pos_tokens_canonical[idx]
        if idx == 0:
            print(sentence)
            print(tokenized_sentence)

        dataset.append(Sentence(sentence, label, tokenized_sentence))
        label = KID_INAPPROPRIATE
        sentence = " ".join(neg_tokens_canonical[idx])
        tokenized_sentence = neg_tokens_canonical[idx]
        dataset.append(Sentence(sentence, label, tokenized_sentence))
    return dataset, length, labels


def build_vocab(dataset):
    print("Building vocab")
    vocab = dict()
    c = 0
    vocab[PAD_TOKEN] = c
    c += 1
    vocab[UNK_TOKEN] = c
    c += 1

    for d in dataset:
        for token in d.tokens:
            if token not in vocab:
                vocab[token] = c
                c += 1
    print("vocab size is: " + str(len(vocab)))
    return vocab


def build_label_dict(labels):
    ret = dict()
    i = 0
    for label in labels:
        ret[label] = i
        i += 1
    return ret


def load_data(size, max_length):
    print("Loading data...")
    dataset, _, labels = get_dataset(size)
    num_c = len(labels)
    total_count = len(dataset)
    split_index = math.floor(TEST_FRAC * total_count)
    test = dataset[:split_index]
    train = dataset[split_index:]

    vocab = build_vocab(train)
    label_dict = build_label_dict(labels)

    for example in train:
        example.pad_to(max_length, PAD_TOKEN)
        example.apply_vocabs(vocab, UNK_TOKEN, label_dict)
    for example in test:
        example.pad_to(max_length, PAD_TOKEN)
        example.apply_vocabs(vocab, UNK_TOKEN, label_dict)
    print("Data loaded")
    return train, test, vocab, max_length, labels


def shuffle(x):
    x = list(x)
    random.shuffle(x)
    return x


def split(data, factor):
    shuffled = shuffle(data)
    train_size = int(len(shuffled) * factor)
    return data[:train_size], data[train_size:]


def save(data, path):
    import pickle
    pickle.dump(data, open(path, 'wb'))


def load(data, path):
    import pickle
    vocab, max_length = pickle.load(open(path, 'wb'))
    return vocab, max_length


def get_xy(data):
    x = []
    y = []
    for d in data:
        x.append(d.tokens_ids)
        y.append(d.labels_ids)

    return np.array(x), np.array(y)


def get_training_batches(data, batch_size):
    num_batches = int(len(data) / batch_size)
    shuffled = shuffle(data)
    for batch_i in range(num_batches):
        start = batch_i * batch_size
        end = min((batch_i + 1) * batch_size, len(data))

        yield data[start: end]


def train_and_test():
    with tf.Graph().as_default():
        np.random.seed(10)
        tf.set_random_seed(10)

        all_train_data, test_data, vocab, max_len, labels = load_data(DATASET_SIZE, max_sent_length)
        num_classes = len(labels)
        save([vocab, labels, max_len], model_dir + "/params.pkl")
        train_data, valid_data = split(all_train_data, 0.8)


        sess = tf.Session()
        with sess.as_default():
            print("Initializing Embedding")
            print("max_len", max_len)

            embedding = None
            cell_size = max_len
            if embedding_path != "":
                embedding = Word2VecEmbedding(embedding_path, vocab, train_embedding)
            else:
                embedding = RandomEmbedding(len(vocab), embedding_size)

            print("Building nn_model")
            print( "embedding", embedding.get_w().shape)
            model = RnnTextClassifier(batch_size=batch_size, sentence_length=max_len,
                                      embedding=embedding, cell_layer_size=cell_size,
                                      cell_layer_num=rnn_num,
                                      num_classes=num_classes, lr=learning_rate, lam=lam)
            model.build_network()
            print("Building training operations")
            model.build_train_ops()
            model.summary()

            tf.global_variables_initializer().run()

            valid_x, valid_y = get_xy(valid_data)
            test_x, test_y = get_xy(test_data)
            saver = tf.train.Saver(max_to_keep=1)
            best_vd_accuracy = 0.0
            best_vd_loss = 0.0
            best_tt_accuracy = 0.0
            best_tt_loss = 0.0

            writer = tf.summary.FileWriter(summaries_dir + "/train",
                                           sess.graph)

            print("Start training")
            for epoch in range(num_epochs):
                batches = get_training_batches(train_data, batch_size)
                # Training on batches
                for batch in batches:
                    train_x, train_y = get_xy(batch)

                    step, loss, accuracy, summary = model.train(sess, train_x, train_y, dropout_keep_prob)
                    writer.add_summary(summary, step)
                    print("Training: epoch\t{:g}\tstep\t{:g}\tloss\t{:g}\taccuracy\t{:g}".format(epoch, step, loss,
                                                                                                 accuracy))

                # Evaluate on validation and test set
                vd_step, vd_loss, vd_accuracy, _ = model.step(sess, valid_x, valid_y)
                print("Validation: loss\t{:g}\taccuracy\t{:g}".format(vd_loss, vd_accuracy))
                tt_step, tt_loss, tt_accuracy, _ = model.step(sess, test_x, test_y)
                print("Testing: loss\t{:g}\taccuracy\t{:g}".format(tt_loss, tt_accuracy))

                if vd_accuracy > best_vd_accuracy:
                    best_vd_accuracy = vd_accuracy
                    best_vd_loss = vd_loss
                    best_tt_accuracy = tt_accuracy
                    best_tt_loss = tt_loss
                    print("Saving nn_model")
                    saver.save(sess, model_dir + "/qc_model")

            print("Best Validation: loss\t{:g}\taccuracy\t{:g}".format(best_vd_loss, best_vd_accuracy))
            print("Best Testing: loss\t{:g}\taccuracy\t{:g}".format(best_tt_loss, best_tt_accuracy))

# %%
train_and_test()
# Out:
# Loading data...
# the song of hiawatha henry w. longfellow contents introductory note introduction i .
# ['the', 'song', 'of', 'hiawatha', 'henry', 'w.', 'longfellow', 'contents', 'introductory', 'note', 'introduction', 'i', '.']
# Building vocab
# vocab size is: 55621
# Data loaded
# Initializing Embedding
# max_len 40
# Building nn_model
# embedding (55621, 128)
# {'lr': 0, 'lam': 1, 'num_classes': 2, 'cell_layer_num': 2, 'cell_layer_size': 40, 'embedding': <embedding.RandomEmbedding object at 0x7f986985b1d0>, 'sentence_length': 40, 'batch_size': 128, 'self': <rnn_text_classifier.RnnTextClassifier object at 0x7f986985b208>}
# x (?, 40) y (?, 2)
# embedding_input (?, 40, 128)
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/common_shapes.py in _call_cpp_shape_fn_impl(op, input_tensors_needed, input_tensors_as_shapes_needed, require_shape_fn)
#     685           graph_def_version, node_def_str, input_shapes, input_tensors,
# --> 686           input_tensors_as_shapes, status)
#     687   except errors.InvalidArgumentError as err:
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 473             c_api.TF_GetCode(self.status.status))
#     474     # Delete the underlying status object from memory otherwise it stays alive
#
# InvalidArgumentError: Dimensions must be equal, but are 80 and 168 for 'rnn_ops/rnn/while/rnn/multi_rnn_cell/cell_0/cell_0/gru_cell/MatMul_2' (op: 'MatMul') with input shapes: [?,80], [168,80].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-b16bbad8159f> in <module>()
#       1
# ----> 2 train_and_test()
#
# <ipython-input-45-1094712bbfa3> in train_and_test()
#     152                                       cell_layer_num=rnn_num,
#     153                                       num_classes=num_classes, lr=learning_rate, lam=lam)
# --> 154             model.build_network()
#     155             print("Building training operations")
#     156             model.build_train_ops()
#
# ~/mids-w266-final-project/final_proj/rnn_text_classifier.py in build_network(self)
#      42
#      43         # define the RNN operation
# ---> 44         with tf.name_scope('rnn_ops'):
#      45             output, state = tf.nn.dynamic_rnn(cell, embedding_input, time_major=False, dtype=self.dtype)
#      46
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/rnn.py in dynamic_rnn(cell, inputs, sequence_length, initial_state, dtype, parallel_iterations, swap_memory, time_major, scope)
#     612         swap_memory=swap_memory,
#     613         sequence_length=sequence_length,
# --> 614         dtype=dtype)
#     615
#     616     # Outputs of _dynamic_rnn_loop are always shaped [time, batch, depth].
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/rnn.py in _dynamic_rnn_loop(cell, inputs, initial_state, parallel_iterations, swap_memory, sequence_length, dtype)
#     775       loop_vars=(time, output_ta, state),
#     776       parallel_iterations=parallel_iterations,
# --> 777       swap_memory=swap_memory)
#     778
#     779   # Unpack final output if not using output tuples.
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/control_flow_ops.py in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name)
#    2814     loop_context = WhileContext(parallel_iterations, back_prop, swap_memory)  # pylint: disable=redefined-outer-name
#    2815     ops.add_to_collection(ops.GraphKeys.WHILE_CONTEXT, loop_context)
# -> 2816     result = loop_context.BuildLoop(cond, body, loop_vars, shape_invariants)
#    2817     return result
#    2818
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/control_flow_ops.py in BuildLoop(self, pred, body, loop_vars, shape_invariants)
#    2638       self.Enter()
#    2639       original_body_result, exit_vars = self._BuildLoop(
# -> 2640           pred, body, original_loop_vars, loop_vars, shape_invariants)
#    2641     finally:
#    2642       self.Exit()
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/control_flow_ops.py in _BuildLoop(self, pred, body, original_loop_vars, loop_vars, shape_invariants)
#    2588         structure=original_loop_vars,
#    2589         flat_sequence=vars_for_body_with_tensor_arrays)
# -> 2590     body_result = body(*packed_vars_for_body)
#    2591     if not nest.is_sequence(body_result):
#    2592       body_result = [body_result]
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/rnn.py in _time_step(time, output_ta_t, state)
#     760           skip_conditionals=True)
#     761     else:
# --> 762       (output, new_state) = call_cell()
#     763
#     764     # Pack state if using state tuples
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/rnn.py in <lambda>()
#     746
#     747     input_t = nest.pack_sequence_as(structure=inputs, flat_sequence=input_t)
# --> 748     call_cell = lambda: cell(input_t, state)
#     749
#     750     if sequence_length is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/rnn_cell_impl.py in __call__(self, inputs, state, scope)
#     181       with vs.variable_scope(vs.get_variable_scope(),
#     182                              custom_getter=self._rnn_get_variable):
# --> 183         return super(RNNCell, self).__call__(inputs, state)
#     184
#     185   def _rnn_get_variable(self, getter, *args, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/layers/base.py in __call__(self, inputs, *args, **kwargs)
#     573         if in_graph_mode:
#     574           self._assert_input_compatibility(inputs)
# --> 575         outputs = self.call(inputs, *args, **kwargs)
#     576
#     577         if outputs is None:
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/rnn_cell_impl.py in call(self, inputs, state)
#    1064                                       [-1, cell.state_size])
#    1065           cur_state_pos += cell.state_size
# -> 1066         cur_inp, new_state = cell(cur_inp, cur_state)
#    1067         new_states.append(new_state)
#    1068
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/rnn_cell_impl.py in __call__(self, inputs, state, scope)
#     181       with vs.variable_scope(vs.get_variable_scope(),
#     182                              custom_getter=self._rnn_get_variable):
# --> 183         return super(RNNCell, self).__call__(inputs, state)
#     184
#     185   def _rnn_get_variable(self, getter, *args, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/layers/base.py in __call__(self, inputs, *args, **kwargs)
#     573         if in_graph_mode:
#     574           self._assert_input_compatibility(inputs)
# --> 575         outputs = self.call(inputs, *args, **kwargs)
#     576
#     577         if outputs is None:
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/rnn_cell_impl.py in call(self, inputs, state)
#     320             kernel_initializer=self._kernel_initializer)
#     321
# --> 322     value = math_ops.sigmoid(self._gate_linear([inputs, state]))
#     323     r, u = array_ops.split(value=value, num_or_size_splits=2, axis=1)
#     324
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/rnn_cell_impl.py in __call__(self, args)
#    1187       res = math_ops.matmul(args[0], self._weights)
#    1188     else:
# -> 1189       res = math_ops.matmul(array_ops.concat(args, 1), self._weights)
#    1190     if self._build_bias:
#    1191       res = nn_ops.bias_add(res, self._biases)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in matmul(a, b, transpose_a, transpose_b, adjoint_a, adjoint_b, a_is_sparse, b_is_sparse, name)
#    1889     else:
#    1890       return gen_math_ops._mat_mul(
# -> 1891           a, b, transpose_a=transpose_a, transpose_b=transpose_b, name=name)
#    1892
#    1893
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py in _mat_mul(a, b, transpose_a, transpose_b, name)
#    2435     _, _, _op = _op_def_lib._apply_op_helper(
#    2436         "MatMul", a=a, b=b, transpose_a=transpose_a, transpose_b=transpose_b,
# -> 2437         name=name)
#    2438     _result = _op.outputs[:]
#    2439     _inputs_flat = _op.inputs
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     785         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     786                          input_types=input_types, attrs=attr_protos,
# --> 787                          op_def=op_def)
#     788       return output_structure, op_def.is_stateful, op
#     789
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes, compute_device)
#    2956         op_def=op_def)
#    2957     if compute_shapes:
# -> 2958       set_shapes_for_outputs(ret)
#    2959     self._add_op(ret)
#    2960     self._record_op_seen_by_control_dependencies(ret)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in set_shapes_for_outputs(op)
#    2207       shape_func = _call_cpp_shape_fn_and_require_op
#    2208
# -> 2209   shapes = shape_func(op)
#    2210   if shapes is None:
#    2211     raise RuntimeError(
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in call_with_requiring(op)
#    2157
#    2158   def call_with_requiring(op):
# -> 2159     return call_cpp_shape_fn(op, require_shape_fn=True)
#    2160
#    2161   _call_cpp_shape_fn_and_require_op = call_with_requiring
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/common_shapes.py in call_cpp_shape_fn(op, require_shape_fn)
#     625     res = _call_cpp_shape_fn_impl(op, input_tensors_needed,
#     626                                   input_tensors_as_shapes_needed,
# --> 627                                   require_shape_fn)
#     628     if not isinstance(res, dict):
#     629       # Handles the case where _call_cpp_shape_fn_impl calls unknown_shape(op).
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/common_shapes.py in _call_cpp_shape_fn_impl(op, input_tensors_needed, input_tensors_as_shapes_needed, require_shape_fn)
#     689       missing_shape_fn = True
#     690     else:
# --> 691       raise ValueError(err.message)
#     692
#     693   if missing_shape_fn:
#
# ValueError: Dimensions must be equal, but are 80 and 168 for 'rnn_ops/rnn/while/rnn/multi_rnn_cell/cell_0/cell_0/gru_cell/MatMul_2' (op: 'MatMul') with input shapes: [?,80], [168,80].

# %%
# !which python
